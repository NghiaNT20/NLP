# %% [markdown]
# 1. Search the Web for “spoof newspaper headlines,” to find such gems as: British
# Left Waffles on Falkland Islands, and Juvenile Court to Try Shooting Defendant.
# Manually tag these headlines to see whether knowledge of the part-of-speech tags
# removes the ambiguity.

# %%
import nltk

headline = 'Juvenile/NOUN Court/NOUN to/PRT Try/VERB Shooting/ADJ Defendant/NOUN'
[nltk.tag.str2tuple(t) for t in headline.split()]
# Out:
# [('Juvenile', 'NOUN'),
#  ('Court', 'NOUN'),
#  ('to', 'PRT'),
#  ('Try', 'VERB'),
#  ('Shooting', 'ADJ'),
#  ('Defendant', 'NOUN')]

# %% [markdown]
# 2. Working with someone else, take turns picking a word that can be either a noun
# or a verb (e.g., contest); the opponent has to predict which one is likely to be the
# most frequent in the Brown Corpus. Check the opponent’s prediction, and tally
# the score over several turns.

# %%
import nltk
from nltk.corpus import brown
from nltk import FreqDist

# Ensure required resources are downloaded
nltk.download('brown')

# Load Brown Corpus
def get_word_frequencies():
    """Get frequencies of nouns and verbs in the Brown Corpus."""
    # Get words and their tags from the Brown Corpus
    words = brown.tagged_words()
    # Create frequency distributions for nouns and verbs
    fdist_nouns = FreqDist(word.lower() for word, tag in words if tag.startswith('NN'))
    fdist_verbs = FreqDist(word.lower() for word, tag in words if tag.startswith('VB'))
    
    return fdist_nouns, fdist_verbs

def word_frequencies(word, fdist_nouns, fdist_verbs):
    """Get frequencies for a given word."""
    word = word.lower()
    noun_freq = fdist_nouns.get(word, 0)
    verb_freq = fdist_verbs.get(word, 0)
    
    return noun_freq, verb_freq

def play_game():
    fdist_nouns, fdist_verbs = get_word_frequencies()
    
    print("Welcome to the Word Frequency Game!")
    print("Pick a word that can be either a noun or a verb.")
    print("Your opponent will predict which form (noun or verb) is more frequent.")
    print("Let's start!")
    
    score = 0
    while True:
        word = input("Enter a word (or 'quit' to end the game): ")
        if word.lower() == 'quit':
            break
        
        # Get frequencies for the word
        noun_freq, verb_freq = word_frequencies(word, fdist_nouns, fdist_verbs)
        
        # Get opponent's prediction
        prediction = input(f"Is '{word}' more frequent as a noun or a verb? (Enter 'noun' or 'verb'): ").strip().lower()
        
        # Determine the correct answer
        correct = 'noun' if noun_freq > verb_freq else 'verb'
        
        # Check the prediction
        if prediction == correct:
            print(f"Correct! '{word}' is more frequent as a {correct}.")
            score += 1
        else:
            print(f"Incorrect. '{word}' is more frequent as a {correct}.")
        
        print(f"Current Score: {score}\n")
    
    print(f"Game over! Final Score: {score}")

if __name__ == "__main__":
    play_game()
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# Welcome to the Word Frequency Game!
# Pick a word that can be either a noun or a verb.
# Your opponent will predict which form (noun or verb) is more frequent.
# Let's start!
# Incorrect. 'noun' is more frequent as a noun.
# Current Score: 0
#
# Incorrect. '' is more frequent as a verb.
# Current Score: 0
#
# Incorrect. '' is more frequent as a verb.
# Current Score: 0
#
# Incorrect. '' is more frequent as a verb.
# Current Score: 0
#
# Incorrect. 'noun' is more frequent as a noun.
# Current Score: 0
#
# Incorrect. '' is more frequent as a verb.
# Current Score: 0
#
# Incorrect. '' is more frequent as a verb.
# Current Score: 0
#
# Incorrect. '' is more frequent as a verb.
# Current Score: 0
#
# Incorrect. '' is more frequent as a verb.
# Current Score: 0
#
# Incorrect. '' is more frequent as a verb.
# Current Score: 0
#
# Incorrect. '' is more frequent as a verb.
# Current Score: 0
#
# Incorrect. 'more frequent as a noun' is more frequent as a verb.
# Current Score: 0
#
# Incorrect. '' is more frequent as a verb.
# Current Score: 0
#
# Incorrect. '' is more frequent as a verb.
# Current Score: 0
#
# Incorrect. '' is more frequent as a verb.
# Current Score: 0
#
# Incorrect. '' is more frequent as a verb.
# Current Score: 0
#
# Incorrect. '' is more frequent as a verb.
# Current Score: 0
#
# Incorrect. '' is more frequent as a verb.
# Current Score: 0
#
# Incorrect. '' is more frequent as a verb.
# Current Score: 0

# %% [markdown]
# 3. Tokenize and tag the following sentence: They wind back the clock, while we
# chase after the wind. What different pronunciations and parts-of-speech are
# involved?

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# Ensure required resources are downloaded
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Sentence to be analyzed
sentence = "They wind back the clock, while we chase after the wind."

# Tokenize the sentence
tokens = word_tokenize(sentence)

# Tag the tokens with parts of speech
tagged_tokens = pos_tag(tokens)

# Print the tokenized and tagged output
print("Tokenized and Tagged Sentence:")
for token, tag in tagged_tokens:
    print(f"{token}: {tag}")

# Analyze different pronunciations and parts-of-speech
print("\nParts of Speech and Pronunciations:")
for token, tag in tagged_tokens:
    print(f"{token}: {tag}")

# Example of analyzing specific words
from nltk.corpus import wordnet as wn

def get_synsets(word):
    """Get synsets for a word."""
    return wn.synsets(word)

def get_word_info(word):
    """Prints the synsets and parts of speech for a word."""
    synsets = get_synsets(word)
    pos_info = {wn.synset(synset.name()).pos(): synset.name() for synset in synsets}
    return pos_info

words_of_interest = ['wind', 'chase']
for word in words_of_interest:
    print(f"\nWord: {word}")
    pos_info = get_word_info(word)
    for pos, synset in pos_info.items():
        print(f"POS: {pos}, Synset: {synset}")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# Tokenized and Tagged Sentence:
# They: PRP
# wind: VBP
# back: RB
# the: DT
# clock: NN
# ,: ,
# while: IN
# we: PRP
# chase: VBP
# after: IN
# the: DT
# wind: NN
# .: .
#
# Parts of Speech and Pronunciations:
# They: PRP
# wind: VBP
# back: RB
# the: DT
# clock: NN
# ,: ,
# while: IN
# we: PRP
# chase: VBP
# after: IN
# the: DT
# wind: NN
# .: .
#
# Word: wind
# POS: n, Synset: wind.n.08
# POS: v, Synset: hoist.v.01
#
# Word: chase
# POS: n, Synset: chase.n.03
# POS: v, Synset: furrow.v.03

# %% [markdown]
# 5.  Using the Python interpreter in interactive mode, experiment with the dictionary
# examples in this chapter. Create a dictionary d, and add some entries. What happens whether you try to access a non-existent entry, e.g., d['xyz']?

# %%
# Create a dictionary
d = {'apple': 'a fruit', 'car': 'a vehicle', 'python': 'a programming language'}

# Add some entries
d['banana'] = 'a yellow fruit'
d['dog'] = 'a domestic animal'

# Print the dictionary
print("Dictionary:", d)

# Access an existing entry
print("Accessing 'apple':", d['apple'])

# Access a non-existent entry using the get method (safe way)
print("Accessing 'xyz' using get method:", d.get('xyz', 'Not found'))

# Access a non-existent entry directly (will raise a KeyError)
try:
    print("Accessing 'xyz' directly:", d['xyz'])
except KeyError:
    print("KeyError: 'xyz' not found in dictionary")
# Out:
# Dictionary: {'apple': 'a fruit', 'car': 'a vehicle', 'python': 'a programming language', 'banana': 'a yellow fruit', 'dog': 'a domestic animal'}
# Accessing 'apple': a fruit
# Accessing 'xyz' using get method: Not found
# KeyError: 'xyz' not found in dictionary

# %% [markdown]
# 6.  Try deleting an element from a dictionary d, using the syntax del d['abc']. Check
# that the item was deleted.

# %%
# Create a dictionary
d = {'apple': 'a fruit', 'car': 'a vehicle', 'python': 'a programming language'}

# Add some entries
d['banana'] = 'a yellow fruit'
d['dog'] = 'a domestic animal'

# Print the dictionary before deletion
print("Dictionary before deletion:", d)

# Delete an entry
del d['banana']

# Print the dictionary after deletion
print("Dictionary after deletion:", d)

# Verify that the entry was deleted
# Accessing the deleted key directly will raise a KeyError
try:
    print("Accessing 'banana' directly:", d['banana'])
except KeyError:
    print("KeyError: 'banana' not found in dictionary")
# Out:
# Dictionary before deletion: {'apple': 'a fruit', 'car': 'a vehicle', 'python': 'a programming language', 'banana': 'a yellow fruit', 'dog': 'a domestic animal'}
# Dictionary after deletion: {'apple': 'a fruit', 'car': 'a vehicle', 'python': 'a programming language', 'dog': 'a domestic animal'}
# KeyError: 'banana' not found in dictionary

# %% [markdown]
# 7. Create two dictionaries, d1 and d2, and add some entries to each. Now issue the
# command d1.update(d2). What did this do? What might it be useful for?

# %%
d1 = {'hello': 1, 'world': 2, 'natural': 0}
d2 = {'natural': 3, 'language': 4, 'processing': 5}
d1.update(d2)
d1
# Out:
# {'hello': 1, 'world': 2, 'natural': 3, 'language': 4, 'processing': 5}

# %% [markdown]
# Update the dictionary with the key/value pairs from other, overwriting existing keys.
#
# Useful when merging two dictionaries.

# %% [markdown]
# 8. Create a dictionary e, to represent a single lexical entry for some word of your
# choice. Define keys such as headword, part-of-speech, sense, and example, and assign them suitable values

# %%
e = {}
e['headword'] = ['NOUN', 'a word or term placed at the beginning (as of a chapter or an entry in an encyclopedia)']
e['part-of-speech'] = ['PHRASE', 'a traditional class of words distinguished according to the kind of idea denoted and the function performed in a sentence']
e['sense'] = ['NOUN', 'a meaning conveyed or intended']
e['example'] = ['NOUN', 'one that serves as a pattern to be imitated or not to be imitated']

import pprint
pprint.pprint(e)
# Out:
# {'example': ['NOUN',
#              'one that serves as a pattern to be imitated or not to be '
#              'imitated'],
#  'headword': ['NOUN',
#               'a word or term placed at the beginning (as of a chapter or an '
#               'entry in an encyclopedia)'],
#  'part-of-speech': ['PHRASE',
#                     'a traditional class of words distinguished according to '
#                     'the kind of idea denoted and the function performed in a '
#                     'sentence'],
#  'sense': ['NOUN', 'a meaning conveyed or intended']}

# %%
# Define a dictionary representing a lexical entry
e = {
    'headword': 'run',
    'part-of-speech': 'verb',
    'senses': [
        {
            'sense_id': 1,
            'definition': 'To move swiftly on foot.',
            'example': 'She can run a mile in under six minutes.'
        },
        {
            'sense_id': 2,
            'definition': 'To operate or function.',
            'example': 'The machine runs on electricity.'
        },
        {
            'sense_id': 3,
            'definition': 'To manage or be in charge of.',
            'example': 'He runs a small business from home.'
        }
    ]
}

# Print the dictionary
import pprint
pprint.pprint(e)
# Out:
# {'headword': 'run',
#  'part-of-speech': 'verb',
#  'senses': [{'definition': 'To move swiftly on foot.',
#              'example': 'She can run a mile in under six minutes.',
#              'sense_id': 1},
#             {'definition': 'To operate or function.',
#              'example': 'The machine runs on electricity.',
#              'sense_id': 2},
#             {'definition': 'To manage or be in charge of.',
#              'example': 'He runs a small business from home.',
#              'sense_id': 3}]}

# %% [markdown]
# 9. Satisfy yourself that there are restrictions on the distribution of ** go ** and ** went **, in the sense that they cannot be freely interchanged in the kinds of contexts illustrated in (3d) in 7.
#
# 'We went on the excursion.' means the tense is past.
#
# 'We go on the excursion.' well, is it unlikely used in daily life?

# %% [markdown]
# 10. Train a unigram tagger and run it on some new text. Observe that some words
# are not assigned a tag. Why not?

# %%
from nltk.corpus import brown
import nltk

fd = nltk.FreqDist(brown.words(categories='news'))
cfd = nltk.ConditionalFreqDist(brown.tagged_words(categories='news'))
most_freq_words = fd.most_common(100)
likely_tags = dict((word, cfd[word].max()) for (word, __) in most_freq_words)
baseline_tagger = nltk.UnigramTagger(model=likely_tags)
baseline_tagger.evaluate(brown_tagged_sents)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15288\1365451109.py:9: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   baseline_tagger.evaluate(brown_tagged_sents)
# 0.45578495136941344

# %%
import nltk
from nltk.corpus import treebank
from nltk.tag import UnigramTagger
from nltk.tokenize import word_tokenize

nltk.download('treebank')

# Load training data
train_sents = treebank.tagged_sents()[:3000]
test_sents = treebank.tagged_sents()[3000:3500]

# Train a unigram tagger
tagger = UnigramTagger(train_sents)

# Define new text for tagging
new_text = "The quick brown fox jumps over the lazy dog"

# Tokenize new text
tokens = word_tokenize(new_text)

# Tag the tokens
tagged = tagger.tag(tokens)

# Print the tagged tokens
print(tagged)
# Out:
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\treebank.zip.
# [('The', 'DT'), ('quick', 'JJ'), ('brown', None), ('fox', None), ('jumps', None), ('over', 'IN'), ('the', 'DT'), ('lazy', None), ('dog', None)]

# %%
from nltk.tag import DefaultTagger, BigramTagger

# Train a default tagger for unseen words
default_tagger = DefaultTagger('NN')  # Default tag for unseen words

# Train a bigram tagger with a backoff to the unigram tagger
bigram_tagger = BigramTagger(train_sents, backoff=tagger)

# Use the bigram tagger to tag new text
tagged_with_bigrams = bigram_tagger.tag(tokens)

print(tagged_with_bigrams)
# Out:
# [('The', 'DT'), ('quick', 'JJ'), ('brown', None), ('fox', None), ('jumps', None), ('over', 'IN'), ('the', 'DT'), ('lazy', None), ('dog', None)]

# %% [markdown]
# The words doesn't appear in the training text, and therefore the tagger can't speculate the word's tag.
#
# When you train a unigram tagger and run it on new text, you might observe that some words are not assigned a tag. This occurs because a unigram tagger assigns tags based solely on the previous observation of individual words in the training data.

# %% [markdown]
# 11. Learn about the affix tagger (type help(nltk.AffixTagger)). Train an affix tagger
# and run it on some new text. Experiment with different settings for the affix length
# and the minimum word length. Discuss your findings.

# %%
import nltk
from nltk.corpus import brown
from nltk.corpus import gutenberg

text = gutenberg.words('austen-persuasion.txt')

brown_sents = brown.sents(categories='news')
brown_tagged_sents = brown.tagged_sents(categories='news')
affix_tagger = nltk.AffixTagger(train=brown_tagged_sents, affix_length=1, min_stem_length=3)
print(affix_tagger.tag(text))
# Out:
# [('[', None), ('Persuasion', 'NP'), ('by', None), ('Jane', 'NP'), ('Austen', 'NP'), ('1818', 'CD'), (']', None), ('Chapter', 'NN-TL'), ('1', None), ('Sir', None), ('Walter', 'NP'), ('Elliot', 'NP'), (',', None), ('of', None), ('Kellynch', 'NP'), ('Hall', 'NP'), (',', None), ('in', None), ('Somersetshire', 'NP'), (',', None), ('was', None), ('a', None), ('man', None), ('who', None), (',', None), ('for', None), ('his', None), ('own', None), ('amusement', 'NN'), (',', None), ('never', 'NN'), ('took', 'NN'), ('up', None), ('any', None), ('book', 'NN'), ('but', None), ('the', None), ('Baronetage', 'NP'), (';', None), ('there', 'NN'), ('he', None), ('found', 'NN'), ('occupation', 'NN'), ('for', None), ('an', None), ('idle', 'NN'), ('hour', 'NN'), (',', None), ('and', None), ('consolation', 'NN'), ('in', None), ('a', None), ('distressed', 'NN'), ('one', None), (';', None), ('there', 'NN'), ('his', None), ('faculties', 'NN'), ('were', 'MD'), ('roused', 'NN'), ('into', 'NN'), ('admiration', 'NN'), ('and', None), ('respect', 'NN'), (',', None), ('by', None), ('contemplating', 'NN'), ('the', None), ('limited', 'NN'), ('remnant', 'NN'), ('of', None), ('the', None), ('earliest', 'NN'), ('patents', 'NN'), (';', None), ('there', 'NN'), ('any', None), ('unwelcome', 'IN'), ('sensations', 'NN'), (',', None), ('arising', 'NN'), ('from', 'NN'), ('domestic', 'NN'), ('affairs', 'NN'), ('changed', 'NN'), ('naturally', 'NN'), ('into', 'NN'), ('pity', 'NN'), ('and', None), ('contempt', 'NN'), ('as', None), ('he', None), ('turned', 'NN'), ('over', 'NN'), ('the', None), ('almost', 'NN'), ('endless', 'NN'), ('creations', 'NN'), ('of', None), ('the', None), ('last', 'NN'), ('century', 'NN'), (';', None), ('and', None), ('there', 'NN'), (',', None), ('if', None), ('every', 'NN'), ('other', 'NN'), ('leaf', 'NN'), ('were', 'MD'), ('powerless', 'NN'), (',', None), ('he', None), ('could', 'NN'), ('read', 'NN'), ('his', None), ('own', None), ('history', 'NN'), ('with', 'MD'), ('an', None), ('interest', 'NN'), ('which', 'MD'), ('never', 'NN'), ('failed', 'NN'), ('.', None), ('This', 'NP'), ('was', None), ('the', None), ('page', 'NN'), ('at', None), ('which', 'MD'), ('the', None), ('favourite', 'NN'), ('volume', 'NN'), ('always', 'NN'), ('opened', 'NN'), (':', None), ('"', None), ('ELLIOT', 'NP'), ('OF', None), ('KELLYNCH', 'NP'), ('HALL', 'NP'), ('.', None), ('"', None), ('Walter', 'NP'), ('Elliot', 'NP'), (',', None), ('born', 'NN'), ('March', 'NP'), ('1', None), (',', None), ('1760', 'CD'), (',', None), ('married', 'NN'), (',', None), ('July', 'NP'), ('15', None), (',', None), ('1784', 'CD'), (',', None), ('Elizabeth', 'NP'), (',', None), ('daughter', 'NN'), ('of', None), ('James', 'NP'), ('Stevenson', 'NP'), (',', None), ('Esq', None), ('.', None), ('of', None), ('South', 'NP'), ('Park', 'NP'), (',', None), ('in', None), ('the', None), ('county', 'NN'), ('of', None), ('Gloucester', 'NP'), (',', None), ('by', None), ('which', 'MD'), ('lady', 'NN'), ('(', None), ('who', None), ('died', 'NN'), ('1800', 'CD'), (')', None), ('he', None), ('has', None), ('issue', 'NN'), ('Elizabeth', 'NP'), (',', None), ('born', 'NN'), ('June', 'NP'), ('1', None), (',', None), ('1785', 'CD'), (';', None), ('Anne', 'NP'), (',', None), ('born', 'NN'), ('August', 'NP'), ('9', None), (',', None), ('1787', 'CD'), (';', None), ('a', None), ('still', 'NN'), ('-', None), ('born', 'NN'), ('son', None), (',', None), ('November', 'NP'), ('5', None), (',', None), ('1789', 'CD'), (';', None), ('Mary', 'NP'), (',', None), ('born', 'NN'), ('November', 'NP'), ('20', None), (',', None), ('1791', 'CD'), ('."', None), ('Precisely', 'NP'), ('such', 'NN'), ('had', None), ('the', None), ('paragraph', 'NN'), ('originally', 'NN'), ('stood', 'NN'), ('from', 'NN'), ('the', None), ('printer', 'NN'), ("'", None), ('s', None), ('hands', 'NN'), (';', None), ('but', None), ('Sir', None), ('Walter', 'NP'), ('had', None), ('improved', 'NN'), ('it', None), ('by', None), ('adding', 'NN'), (',', None), ('for', None), ...

# %%
affix_tagger = nltk.AffixTagger(brown_tagged_sents, affix_length=3, min_stem_length=4)
test_text = 'Experiment with different settings for the affix length and the minimum word length'.split()
affix_tagger.tag(test_text)
# Out:
# [('Experiment', 'NN-TL'),
#  ('with', None),
#  ('different', 'JJ'),
#  ('settings', 'NN'),
#  ('for', None),
#  ('the', None),
#  ('affix', None),
#  ('length', None),
#  ('and', None),
#  ('the', None),
#  ('minimum', 'NNS'),
#  ('word', None),
#  ('length', None)]

# %% [markdown]
# 12.  Train a bigram tagger with no backoff tagger, and run it on some of the training data. Next, run it on some new data. What happens to the performance of the tagger? Why?

# %%
from nltk.corpus import gutenberg
from nltk.corpus import brown
import nltk

brown_tagged_sents = brown.tagged_sents(categories='news')
brown_sents = brown.sents(categories='news')
size = int(len(brown_tagged_sents) * 0.7)
train_sents = brown_tagged_sents[:size]
test_sents = brown_tagged_sents[size:]

bigram_tagger = nltk.BigramTagger(train_sents)
bigram_tagger.evaluate(train_sents)
bigram_tagger.evaluate(test_sents)

# the performance drops off considerably because it relies on the stastical probablity that word is a particular part of speech based on the first word in a bigram. So when it gets to a new word that it hasn't seen in a bigram before it has nothing to go on and the word is returned as unknown. The accuracy plummets.
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15288\547389458.py:12: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   bigram_tagger.evaluate(train_sents)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15288\547389458.py:13: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   bigram_tagger.evaluate(test_sents)
# 0.09032237553252369

# %%
import nltk
from nltk.corpus import treebank
from nltk.tag import BigramTagger
from nltk.tokenize import word_tokenize

# Load training and test data
train_sents = treebank.tagged_sents()[:3000]
test_sents = treebank.tagged_sents()[3000:3500]

# Train a bigram tagger with no backoff
bigram_tagger = BigramTagger(train_sents)

# Evaluate on training data
train_accuracy = bigram_tagger.evaluate(train_sents)
print(f"Training accuracy: {train_accuracy:.2f}")

# Evaluate on new data
test_text = "The quick brown fox jumps over the lazy dog"
test_tokens = word_tokenize(test_text)
tagged_tokens = bigram_tagger.tag(test_tokens)
print("Tagged tokens:", tagged_tokens)

# Evaluate on test data
test_accuracy = bigram_tagger.evaluate(test_sents)
print(f"Test accuracy: {test_accuracy:.2f}")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15288\2949640948.py:14: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   train_accuracy = bigram_tagger.evaluate(train_sents)
# Training accuracy: 0.91
# Tagged tokens: [('The', 'DT'), ('quick', None), ('brown', None), ('fox', None), ('jumps', None), ('over', None), ('the', None), ('lazy', None), ('dog', None)]
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15288\2949640948.py:24: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   test_accuracy = bigram_tagger.evaluate(test_sents)
# Test accuracy: 0.11

# %% [markdown]
# 13. We can use a dictionary to specify the values to be substituted into a formatting string. Read Python's library documentation for formatting strings http://docs.python.org/lib/typesseq-strings.html (404 NOT FOUND) ** and use this method to display today's date in two different formats.**

# %%
from datetime import datetime

# Get today's date
today = datetime.now()

# Format using f-strings
formatted_date1 = f"Today's date is {today:%Y-%m-%d}"
formatted_date2 = f"Today's date is {today:%B %d, %Y}"

print(formatted_date1)
print(formatted_date2)
# Out:
# Today's date is 2024-08-21
# Today's date is August 21, 2024

# %%
from datetime import datetime

# Get today's date
today = datetime.now()

# Format using str.format()
formatted_date1 = "Today's date is {:%Y-%m-%d}".format(today)
formatted_date2 = "Today's date is {:%B %d, %Y}".format(today)

print(formatted_date1)
print(formatted_date2)
# Out:
# Today's date is 2024-08-21
# Today's date is August 21, 2024

# %% [markdown]
# 14. Use ** sorted() ** and ** set() ** to get a sorted list of tags used in the Brown corpus, removing duplicates.

# %%
from nltk.corpus import brown

tags = brown.tagged_words()
sorted_tags = sorted(tags)
unique_tags = set(sorted_tags)
vals =[val for key, val in unique_tags]	
print(sorted(set(vals)))
# Out:
 'QLP', 'RB', 'RB$', 'RB+BEZ', 'RB+BEZ-HL', 'RB+BEZ-NC', 'RB+CS', 'RB-HL', 'RB-NC', 'RB-TL', 'RBR', 'RBR+CS', 'RBR-NC', 'RBT', 'RN', 'RP', 'RP+IN', 'RP-HL', 'RP-NC', 'RP-TL', 'TO', 'TO+VB', 'TO-HL', 'TO-NC', 'TO-TL', 'UH', 'UH-HL', 'UH-NC', 'UH-TL', 'VB', 'VB+AT', 'VB+IN', 'VB+JJ-NC', 'VB+PPO', 'VB+RP', 'VB+TO', 'VB+VB-NC', 'VB-HL', 'VB-NC', 'VB-TL', 'VBD', 'VBD-HL', 'VBD-NC', 'VBD-TL', 'VBG', 'VBG+TO', 'VBG-HL', 'VBG-NC', 'VBG-TL', 'VBN' ...

# %%
list_of_tags = sorted(set([tag for (_, tag) in brown.tagged_words()]))
print(list_of_tags)
# Out:
# ["'", "''", '(', '(-HL', ')', ')-HL', '*', '*-HL', '*-NC', '*-TL', ',', ',-HL', ',-NC', ',-TL', '--', '---HL', '.', '.-HL', '.-NC', '.-TL', ':', ':-HL', ':-TL', 'ABL', 'ABN', 'ABN-HL', 'ABN-NC', 'ABN-TL', 'ABX', 'AP', 'AP$', 'AP+AP-NC', 'AP-HL', 'AP-NC', 'AP-TL', 'AT', 'AT-HL', 'AT-NC', 'AT-TL', 'AT-TL-HL', 'BE', 'BE-HL', 'BE-TL', 'BED', 'BED*', 'BED-NC', 'BEDZ', 'BEDZ*', 'BEDZ-HL', 'BEDZ-NC', 'BEG', 'BEM', 'BEM*', 'BEM-NC', 'BEN', 'BEN-TL', 'BER', 'BER*', 'BER*-NC', 'BER-HL', 'BER-NC', 'BER-TL', 'BEZ', 'BEZ*', 'BEZ-HL', 'BEZ-NC', 'BEZ-TL', 'CC', 'CC-HL', 'CC-NC', 'CC-TL', 'CC-TL-HL', 'CD', 'CD$', 'CD-HL', 'CD-NC', 'CD-TL', 'CD-TL-HL', 'CS', 'CS-HL', 'CS-NC', 'CS-TL', 'DO', 'DO*', 'DO*-HL', 'DO+PPSS', 'DO-HL', 'DO-NC', 'DO-TL', 'DOD', 'DOD*', 'DOD*-TL', 'DOD-NC', 'DOZ', 'DOZ*', 'DOZ*-TL', 'DOZ-HL', 'DOZ-TL', 'DT', 'DT$', 'DT+BEZ', 'DT+BEZ-NC', 'DT+MD', 'DT-HL', 'DT-NC', 'DT-TL', 'DTI', 'DTI-HL', 'DTI-TL', 'DTS', 'DTS+BEZ', 'DTS-HL', 'DTX', 'EX', 'EX+BEZ', 'EX+HVD', 'EX+HVZ', 'EX+MD', 'EX-HL', 'EX-NC', 'FW-*', 'FW-*-TL', 'FW-AT', 'FW-AT+NN-TL', 'FW-AT+NP-TL', 'FW-AT-HL', 'FW-AT-TL', 'FW-BE', 'FW-BER', 'FW-BEZ', 'FW-CC', 'FW-CC-TL', 'FW-CD', 'FW-CD-TL', 'FW-CS', 'FW-DT', 'FW-DT+BEZ', 'FW-DTS', 'FW-HV', 'FW-IN', 'FW-
 'NR+MD', 'NR-HL', 'NR-NC', 'NR-TL', 'NR-TL-HL', 'NRS', 'NRS-TL', 'OD', 'OD-HL', 'OD-NC', 'OD-TL', 'PN', 'PN$', 'PN+BEZ', 'PN+HVD', 'PN+HVZ', 'PN+MD', 'PN-HL', 'PN-NC', 'PN-TL', 'PP$', 'PP$$', 'PP$-HL', 'PP$-NC', 'PP$-TL', 'PPL', 'PPL-HL', 'PPL-NC', 'PPL-TL', 'PPLS', 'PPO', 'PPO-HL', 'PPO-NC', 'PPO-TL', 'PPS', 'PPS+BEZ', 'PPS+BEZ-HL', 'PPS+BEZ-NC', 'PPS+HVD', 'PPS+HVZ', 'PPS+MD', 'PPS-HL', 'PPS-NC', 'PPS-TL', 'PPSS', 'PPSS+BEM', 'PPSS+BER', 'PPSS+BER-N', 'PPSS+BER-NC', 'PPSS+BER-TL', 'PPSS+BEZ', 'PPSS+BEZ*', 'PPSS+HV', 'PPSS+HV-TL', 'PPSS+HVD', 'PPSS+MD', 'PPSS+MD-NC', 'PPSS+VB', 'PPSS-HL', 'PPSS-NC', 'PPSS-TL', 'QL', 'QL-HL', 'QL-NC', 'QL-TL', 'QLP', 'RB', 'RB$', 'RB+BEZ', 'RB+BEZ-HL', 'RB+BEZ-NC', 'RB+CS', 'RB-HL', 'RB-NC', 'RB-TL', 'RBR', 'RBR+CS', 'RBR-NC', 'RBT', 'RN', 'RP', 'RP+IN', 'RP-HL', 'RP-NC', 'RP-TL', 'TO', 'TO+VB', 'TO-HL', 'TO-NC', 'TO-TL', 'UH', 'UH-HL', 'UH-NC', 'UH-TL', 'VB', 'VB+AT', 'VB+IN', 'VB+JJ-NC', 'VB+PPO', 'VB+RP', 'VB+TO', 'VB+VB-NC', 'VB-HL', 'VB-NC', 'VB-TL', 'VBD', 'VBD-HL', 'VBD-NC', 'VBD-TL', 'VBG', 'VBG+TO', 'VBG-HL', 'VBG-NC', 'VBG-TL', 'VBN' ...

# %% [markdown]
# 15. Write programs to process the Brown Corpus and find answers to the following
# questions:
#
# a. Which nouns are more common in their plural form, rather than their singular
# form? (Only consider regular plurals, formed with the -s suffix.)
#
# b. Which word has the greatest number of distinct tags? What are they, and what
# do they represent?
#
# c. List tags in order of decreasing frequency. What do the 20 most frequent tags
# represent?
#
# d. Which tags are nouns most commonly found after? What do these tags
# represent?

# %%
from nltk.corpus import brown

import nltk

cfd = nltk.ConditionalFreqDist(brown.tagged_words(categories='news'))
tags = brown.tagged_words(categories='news')
pos_tags = [val for key, val in tags]

#this represents the tags in decreasing order of frequency.

fd = nltk.FreqDist(pos_tags)
common_tags = fd.most_common(20)

# pulls out all the different words

conditions = cfd.conditions()
number_of_tags = []

# creates a new list with each word followed by the number of distinct tags that it has

for condition in conditions:
	number_of_tags.append((condition, len(cfd[condition])))

# makes a new list that has the words organized in decreasing order by how many tags they have. the answer is 'to' they are TO': 1222, 'IN': 880, 'TO-HL': 6, 'IN-HL': 5, 'IN-TL': 2, 'NPS': 1. it's most commonly used as a preposition

number_of_tags = list(reversed(sorted(number_of_tags, key=lambda x: x[1])))
print(number_of_tags[0:19])

# produces the list of nouns more common in their plural form than in their singular form.
# does this by looking in the frequency distribution for each word and comparing the number of
# hits for plural noun tags and singular tags

for condition in conditions:
	if cfd[condition]['NNS'] > cfd[condition]['NN']:
		print(condition)

# makes bigrams of the tag pairs in the text
word_tag_pairs = nltk.bigrams(tags)
# pulls out all the tags of the words that precede nouns
noun_preceders = [a[1] for (a, b) in word_tag_pairs if b[1] == 'NN']
# makes a frequency distribution
fdist = nltk.FreqDist(noun_preceders)
# pulls out all the most common tags
[tag for (tag, _) in fdist.most_common()]
# Out:
# [('to', 6), ('French', 5), ('cut', 5), ('3', 5), ('like', 5), ('set', 5), ('near', 5), ('for', 5), ('that', 5), ('Congolese', 4), ('First', 4), ('Place', 4), ('hit', 4), ('No', 4), ('To', 4), ('open', 4), ('half', 4), ('For', 4), ('St.', 4)]
# irregularities
# presentments
# thanks
# reports
# voters
# laws
# legislators
# topics
# departments
# practices
# governments
# offices
# personnel
# policies
# steps
# funds
# services
# homes
# items
# counties
# jurors
# taxpayers
# appraisers
# guardians
# administrators
# fees
# procedures
# recommendations
# juries
# citizens
# actions
# wards
# costs
# servants
# criticisms
# influences
# concessionaires
# prices
# deputies
# matters
# officials
# employes
# Police
# farms
# Attorneys
# responses
# petitions
# precincts
# signatures
# dissents
# courses
# names
# candidates
# relations
# years
# starts
# areas
# adjustments
# chambers
# $100
# bonds
# $30
# courts
# sales
# contracts
# highways
# $3
# $4
# ones
# authorities
# $50
# roads
# plans
# $10
# allowances
# details
# raises
# sessions
# members
# congressmen
# votes
# polls
# calls
# threats
# days
# protests
# bankers
# rules
# questions
# witnesses
# dollars
# means
# books
# permits
# accounts
# stocks
# persons
# banks
# firms
# companies
# corporations
# obligations
# depositors
# customers
# millions
# pockets
# Senators
# schools
# students
# children
# $451,500
# savings
# $157,460
# $88,000
# scholastics
# parimutuels
# folks
# letters
# people
# ponies
# faces
# cities
# bills
# committees
# acts
# districts
# senators
# gifts
# donations
# retailers
# taxes
# $1,000
# brokers
# $12
# sites
# reservoirs
# vacancies
# elections
# representatives
# two-thirds
# majorities
# Opponents
# proposals
# needs
# places
# $5,000,000
# $15,000,000
# Statements
# defenders
# methods
# hours
# teachers
# subjects
# co-signers
# regents
# Principals
# causes
# recipients
# problems
# cases
# skills
# breakups
# relatives
# parents
# projects
# defendants
# police
# statements
# observers
# attorneys
# policemen
# aspects
# others
# amounts
# drafts
# portions
# aids
# advisers
# decisions
# demands
# rights
# proceedings
# hearings
# subpenas
# individuals
# judges
# processes
# workers
# programs
# requests
# grants
# scholarships
# $37
# $4,800
# $5,000
# boosts
# Officials
# benefits
# figures
# parts
# systems
# stays
# $20
# states
# requirements
# hospitals
# doctors
# contributions
# $1,500
# $2,000
# facilities
# elements
# lines
# Legislators
# ayes
# noes
# appointments
# selections
# discussions
# meetings
# changes
# ministers
# powers
# difficulties
# tragedies
# allies
# circumstances
# troubles
# weeks
# critics
# positions
# surprises
# cars
# partners
# grips
# conferences
# Expressions
# declines
# salaries
# intangibles
# titles
# conclusions
# squabbles
# stoppages
# disputes
# sums
# $7,500,000
# abuses
# heavy-electrical-goods
# enterprises
# giants
# muscles
# survivors
# fellows
# enforcers
# managements
# facts
# scapegoats
# organizations
# penalties
# empires
# sentences
# prosecutions
# organizers
# commodities
# bags
# customs
# monopolies
# conspiracies
# employers
# combinations
# hypocrisies
# mechanics
# measures
# injunctions
# airlines
# consumers
# fronts
# offensives
# Hours
# tanks
# staffs
# battalions
# carriers
# troopships
# marines
# sorts
# drops
# transports
# gates
# noses
# liberals
# constituents
# electors
# Reprisals
# whites
# cloakrooms
# caucuses
# arenas
# chairmanships
# filibusters
# three-fifths
# pros
# holes
# teeth
# tears
# rounds
# jitters
# footnotes
# winnings
# duels
# golfers
# consequences
# treacheries
# scoreboards
# pars
# birdies
# moments
# fairways
# 180-degrees
# bogeys
# Pitchers
# Experts
# paces
# $251
# roommates
# backgrounds
# stars
# halfbacks
# minors
# backs
# shoulders
# minds
# passages
# photographers
# occasions
# gentlemen
# heroes
# ties
# cents
# stances
# swings
# bunters
# seconds
# fielders
# cats
# ensembles
# vines
# weeds
# socks
# bobby-sox
# tutors
# classmates
# rallies
# crowns
# virtues
# eulogizers
# impressions
# jetliners
# headlines
# drivers
# bellboys
# $1,500,000
# prizes
# treasures
# classrooms
# pretexts
# skins
# investigators
# plaintiffs
# grads
# statesmen
# successors
# scholars
# genes
# $139.3
# researchers
# $300
# tribes
# boundaries
# groupings
# explorers
# gunmen
# dialects
# religions
# patients
# disparities
# beneficiaries
# cartels
# carpenters
# colonies
# motivations
# provinces
# Well-wishers
# frictions
# tribesmen
# civilians
# paratroops
# wars
# mercenaries
# emissaries
# stopovers
# pirates
# guns
# skyjackers
# recruits
# hostages
# hijackers
# shadows
# slugs
# engines
# Ambulances
# stewardesses
# $100,000
# mutterers
# $46.7
# $754
# bombers
# $5.2
# smelts
# crabs
# $10,000-per-year
# Holders
# turnpikes
# Things
# streams
# speculations
# investments
# rises
# $16,000
# $32,000
# lags
# Costs
# extensions
# tolls
# opportunities
# planners
# margins
# typewriters
# exports
# textiles
# imports
# quotas
# miners
# mouths
# takings
# markets
# $2.80
# mines
# seams
# rentals
# variations
# libraries
# readers
# lovers
# budgets
# limitations
# contrasts
# advantages
# librarians
# volumes
# capita
# tools
# periodicals
# discounts
# Books
# Schools
# classics
# Workshops
# responsibilities
# conducts
# copies
# grassroots
# displays
# booklists
# brochures
# Librarians
# newcomers
# teen-agers
# co-ops
# advances
# pupils
# ['AT',
#  'JJ',
#  'NN',
#  'IN',
#  'PP$',
#  'DT',
#  'CC',
#  'AP',
#  'NP',
#  ',',
#  'VBG',
#  'CD',
#  'NN-TL',
#  'VBN',
#  'OD',
#  '.',
#  'VB',
#  'NP$',
#  'NN$',
#  'NNS',
#  'DTI',
#  'VBD',
#  'CS',
#  'NR',
#  'JJR',
#  '``',
#  'JJ-TL',
#  'JJT',
#  'NNS$',
#  'NN$-TL',
#  "''",
#  'RB',
#  'JJS',
#  'BEZ',
#  'NP-TL',
#  'VBZ',
#  'NNS-TL',
#  'BEDZ',
#  'WDT',
#  'NR$',
#  'RP',
#  '--',
#  'WP$',
#  ')',
#  'ABN',
#  'NPS$',
#  'HV',
#  'PPO',
#  'WRB',
#  'BE',
#  'VBN-TL',
#  'CD-TL',
#  'BER',
#  'NN-HL',
#  'ABX',
#  'FW-NN',
#  'NNS$-TL',
#  '(',
#  'HVZ',
#  'DTS',
#  'BED',
#  'QL',
#  'BEN',
#  ':',
#  '*',
#  'DO',
#  'NNS-HL',
#  'FW-DT',
#  'DTX',
#  "'",
#  'RB-HL',
#  'PPS+BEZ',
#  'HVD',
#  'DOZ',
#  'AP$',
#  'NP$-TL',
#  'DOD',
#  'AT-TL',
#  'RB$',
#  'NR-HL',
#  'VBN-HL',
#  'TO',
#  'CD$',
#  'PN$',
#  'HVN',
#  'OD-TL',
#  'FW-NN-TL',
#  'NR$-TL',
#  'NPS$-TL',
#  ':-HL',
#  '.-HL',
#  'HVG']

# %% [markdown]
# 16. Explore the following issues that arise in connection with the lookup tagger:
# # What happens to the tagger performance for the various model sizes when a backoff tagger is omitted?
#
# """i'd bet that it would perform better with lower sample sizes. because without a default tagging system, it would just have wide gaps with words that it had never seen before. no chance for hitting the words that it knew."""
#
# # Consider the curve in 4.2; suggest a good size for a lookup tagger that balances memory and performance. Can you come up with scenarios where it would be preferable to minimize memory usage, or to maximize performance with no regard for memory usage?
#
# """if you're on a weak server or machine and need to minimize memory usage, sure. and ditto if you're in a situation in which POS tagging is hugely important."""

# %% [markdown]
# 17. What is the upper limit of performance for a lookup tagger, assuming no limit
# to the size of its table? (Hint: write a program to work out what percentage of tokens
# of a word are assigned the most likely tag for that word, on average.)

# %%
import nltk
from nltk.corpus import brown


fd = nltk.FreqDist(brown.words(categories='news'))
cfd = nltk.ConditionalFreqDist(brown.tagged_words(categories='news'))

avgs = []
for (word, freqs) in cfd.items():
    n = float(freqs.N())
    max_tag = freqs.max()
    avg = freqs[max_tag] / n
    print('likelihood for {} = {}'.format(word, avg))
    avgs.append(avg)

print('')
print('average correct = {}'.format(sum(avgs) / len(avgs)))
# Out:
# likelihood for The = 0.9615384615384616
# likelihood for Fulton = 0.7142857142857143
# likelihood for County = 1.0
# likelihood for Grand = 0.8333333333333334
# likelihood for Jury = 1.0
# likelihood for said = 0.9502487562189055
# likelihood for Friday = 1.0
# likelihood for an = 1.0
# likelihood for investigation = 1.0
# likelihood for of = 0.9533169533169533
# likelihood for Atlanta's = 1.0
# likelihood for recent = 1.0
# likelihood for primary = 0.7647058823529411
# likelihood for election = 1.0
# likelihood for produced = 0.8333333333333334
# likelihood for `` = 1.0
# likelihood for no = 0.9541284403669725
# likelihood for evidence = 1.0
# likelihood for '' = 1.0
# likelihood for that = 0.6795511221945137
# likelihood for any = 1.0
# likelihood for irregularities = 1.0
# likelihood for took = 1.0
# likelihood for place = 0.84
# likelihood for . = 0.9955334987593052
# likelihood for jury = 0.9772727272727273
# likelihood for further = 0.625
# likelihood for in = 0.965662968832541
# likelihood for term-end = 1.0
# likelihood for presentments = 1.0
# likelihood for the = 0.9960573476702509
# likelihood for City = 0.9318181818181818
# likelihood for Executive = 0.6666666666666666
# likelihood for Committee = 0.9459459459459459
# likelihood for , = 0.9893986121819583
# likelihood for which = 1.0
# likelihood for had = 0.931899641577061
# likelihood for over-all = 1.0
# likelihood for charge = 0.9411764705882353
# likelihood for deserves = 1.0
# likelihood for praise = 1.0
# likelihood for and = 0.9855545200372786
# likelihood for thanks = 0.8333333333333334
# likelihood for Atlanta = 0.7142857142857143
# likelihood for for = 0.9597030752916225
# likelihood for manner = 1.0
# likelihood for was = 0.99860529986053
# likelihood for conducted = 0.75
# likelihood for September-October = 1.0
# likelihood for term = 1.0
# likelihood for been = 1.0
# likelihood for charged = 0.4166666666666667
# likelihood for by = 0.9919517102615694
# likelihood for Superior = 1.0
# likelihood for Court = 0.9615384615384616
# likelihood for Judge = 1.0
# likelihood for Durwood = 1.0
# likelihood for Pye = 1.0
# likelihood for to = 0.5775047258979206
# likelihood for investigate = 1.0
# likelihood for reports = 0.75
# likelihood for possible = 1.0
# likelihood for hard-fought = 1.0
# likelihood for won = 0.75
# likelihood for Mayor-nominate = 1.0
# likelihood for Ivan = 1.0
# likelihood for Allen = 1.0
# likelihood for Jr. = 1.0
# likelihood for Only = 0.625
# likelihood for a = 0.997491219267436
# likelihood for relative = 1.0
# likelihood for handful = 1.0
# likelihood for such = 0.7285714285714285
# likelihood for received = 0.696969696969697
# likelihood for considering = 0.5
# likelihood for widespread = 1.0
# likelihood for interest = 1.0
# likelihood for number = 0.96875
# likelihood for voters = 1.0
# likelihood for size = 0.875
# likelihood for this = 0.996
# likelihood for city = 1.0
# likelihood for it = 0.6115702479338843
# likelihood for did = 1.0
# likelihood for find = 1.0
# likelihood for many = 1.0
# likelihood for Georgia's = 1.0
# likelihood for registration = 1.0
# likelihood for laws = 1.0
# likelihood for are = 0.9969512195121951
# likelihood for outmoded = 1.0
# likelihood for or = 1.0
# likelihood for inadequate = 1.0
# likelihood for often = 1.0
# likelihood for ambiguous = 1.0
# likelihood for It = 1.0
# likelihood for recommended = 0.5555555555555556
# likelihood for legislators = 1.0
# likelihood for act = 0.75
# likelihood for have = 1.0
# likelihood for these = 1.0
# likelihood for studied = 0.5714285714285714
# likelihood for revised = 0.5
# likelihood for end = 0.6206896551724138
# likelihood for modernizing = 1.0
# likelihood for improving = 1.0
# likelihood for them = 1.0
# likelihood for grand = 1.0
# likelihood for commented = 0.8571428571428571
# likelihood for on = 0.9345509893455098
# likelihood for other = 1.0
# likelihood for topics = 1.0
# likelihood for among = 1.0
# likelihood for purchasing = 0.6666666666666666
# likelihood for departments = 1.0
# likelihood for well = 0.7209302325581395
# likelihood for operated = 0.5
# likelihood for follow = 1.0
# likelihood for generally = 1.0
# likelihood for accepted = 0.75
# likelihood for practices = 0.8571428571428571
# likelihood for inure = 1.0
# likelihood for best = 0.896551724137931
# likelihood for both = 1.0
# likelihood for governments = 1.0
# likelihood for Merger = 1.0
# likelihood for proposed = 0.7222222222222222
# likelihood for However = 0.8333333333333334
# likelihood for believes = 1.0
# likelihood for two = 1.0
# likelihood for offices = 1.0
# likelihood for should = 1.0
# likelihood for be = 0.9980988593155894
# likelihood for combined = 0.6666666666666666
# likelihood for achieve = 1.0
# likelihood for greater = 1.0
# likelihood for efficiency = 1.0
# likelihood for reduce = 1.0
# likelihood for cost = 0.8666666666666667
# likelihood for administration = 1.0
# likelihood for Purchasing = 1.0
# likelihood for Department = 1.0
# likelihood for is = 0.9959016393442623
# likelihood for lacking = 0.6666666666666666
# likelihood for experienced = 1.0
# likelihood for clerical = 1.0
# likelihood for personnel = 1.0
# likelihood for as = 0.814968814968815
# likelihood for result = 0.9666666666666667
# likelihood for policies = 1.0
# likelihood for urged = 0.8181818181818182
# likelihood for take = 1.0
# likelihood for steps = 1.0
# likelihood for remedy = 1.0
# likelihood for problem = 0.9487179487179487
# likelihood for Implementation = 1.0
# likelihood for automobile = 1.0
# likelihood for title = 1.0
# likelihood for law = 1.0
# likelihood for also = 1.0
# likelihood for outgoing = 1.0
# likelihood for next = 0.95
# likelihood for Legislature = 1.0
# likelihood for provide = 1.0
# likelihood for enabling = 1.0
# likelihood for funds = 0.9642857142857143
# likelihood for re-set = 1.0
# likelihood for effective = 1.0
# likelihood for date = 0.9375
# likelihood for so = 0.5373134328358209
# likelihood for orderly = 1.0
# likelihood for implementation = 1.0
# likelihood for may = 1.0
# likelihood for effected = 1.0
# likelihood for swipe = 1.0
# likelihood for at = 0.9933110367892977
# likelihood for State = 0.9365079365079365
# likelihood for Welfare = 1.0
# likelihood for Department's = 1.0
# likelihood for handling = 0.6666666666666666
# likelihood for federal = 1.0
# likelihood for granted = 1.0
# likelihood for child = 1.0
# likelihood for welfare = 0.9230769230769231
# likelihood for services = 1.0
# likelihood for foster = 1.0
# likelihood for homes = 1.0
# likelihood for This = 1.0
# likelihood for one = 0.9510869565217391
# likelihood for major = 0.9285714285714286
# likelihood for items = 1.0
# likelihood for general = 0.8275862068965517
# likelihood for assistance = 1.0
# likelihood for program = 0.9848484848484849
# likelihood for but = 0.9597701149425287
# likelihood for has = 1.0
# likelihood for seen = 1.0
# likelihood for fit = 0.3333333333333333
# likelihood for distribute = 1.0
# likelihood for through = 0.9444444444444444
# likelihood for all = 0.9263803680981595
# likelihood for counties = 1.0
# likelihood for state = 0.9777777777777777
# likelihood for with = 0.9944954128440368
# likelihood for exception = 1.0
# likelihood for receives = 1.0
# likelihood for none = 1.0
# likelihood for money = 1.0
# likelihood for jurors = 1.0
# likelihood for they = 1.0
# likelihood for realize = 1.0
# likelihood for proportionate = 1.0
# likelihood for distribution = 1.0
# likelihood for might = 0.9473684210526315
# likelihood for disable = 1.0
# likelihood for our = 1.0
# likelihood for less = 0.5
# likelihood for populous = 1.0
# likelihood for Nevertheless = 1.0
# likelihood for we = 1.0
# likelihood for feel = 0.8421052631578947
# likelihood for future = 0.64
# likelihood for receive = 1.0
# likelihood for some = 0.9894736842105263
# likelihood for portion = 1.0
# likelihood for available = 1.0
# likelihood for Failure = 1.0
# likelihood for do = 0.9841269841269841
# likelihood for will = 0.9948586118251928
# likelihood for continue = 1.0
# likelihood for disproportionate = 1.0
# likelihood for burden = 1.0
# likelihood for taxpayers = 1.0
# likelihood for ordinary's = 1.0
# likelihood for court = 0.896551724137931
# likelihood for under = 0.9879518072289156
# likelihood for fire = 1.0
# likelihood for its = 1.0
# likelihood for appointment = 1.0
# likelihood for appraisers = 1.0
# likelihood for guardians = 1.0
# likelihood for administrators = 1.0
# likelihood for awarding = 1.0
# likelihood for fees = 0.9230769230769231
# likelihood for compensation = 1.0
# likelihood for Wards = 1.0
# likelihood for protected = 1.0
# likelihood for found = 0.5
# likelihood for incorporated = 1.0
# likelihood for into = 0.9912280701754386
# likelihood for operating = 1.0
# likelihood for procedures = 1.0
# likelihood for recommendations = 1.0
# likelihood for previous = 1.0
# likelihood for juries = 1.0
# likelihood for Bar = 1.0
# likelihood for Association = 1.0
# likelihood for interim = 1.0
# likelihood for citizens = 1.0
# likelihood for committee = 1.0
# likelihood for These = 1.0
# likelihood for actions = 1.0
# likelihood for serve = 1.0
# likelihood for protect = 1.0
# likelihood for fact = 1.0
# likelihood for effect = 0.8235294117647058
# likelihood for court's = 1.0
# likelihood for wards = 1.0
# likelihood for from = 0.9883720930232558
# likelihood for undue = 1.0
# likelihood for costs = 0.9444444444444444
# likelihood for appointed = 0.8333333333333334
# likelihood for elected = 0.8181818181818182
# likelihood for servants = 1.0
# likelihood for unmeritorious = 1.0
# likelihood for criticisms = 1.0
# likelihood for Regarding = 1.0
# likelihood for new = 0.9932432432432432
# likelihood for multi-million-dollar = 1.0
# likelihood for airport = 1.0
# likelihood for when = 1.0
# likelihood for management = 1.0
# likelihood for takes = 1.0
# likelihood for Jan. = 0.7333333333333333
# likelihood for 1 = 0.851063829787234
# likelihood for eliminate = 1.0
# likelihood for political = 1.0
# likelihood for influences = 1.0
# likelihood for not = 0.9960629921259843
# likelihood for elaborate = 1.0
# likelihood for added = 0.7272727272727273
# likelihood for there = 0.8244274809160306
# likelihood for periodic = 1.0
# likelihood for surveillance = 1.0
# likelihood for pricing = 0.6666666666666666
# likelihood for concessionaires = 1.0
# likelihood for purpose = 1.0
# likelihood for keeping = 1.0
# likelihood for prices = 1.0
# likelihood for reasonable = 1.0
# likelihood for Ask = 1.0
# likelihood for jail = 0.8333333333333334
# likelihood for deputies = 0.6666666666666666
# likelihood for On = 1.0
# likelihood for matters = 1.0
# likelihood for : = 0.9194630872483222
# likelihood for ( = 0.8809523809523809
# likelihood for ) = 0.8830409356725146
# likelihood for Four = 0.4444444444444444
# likelihood for additional = 1.0
# likelihood for employed = 1.0
# likelihood for Jail = 1.0
# likelihood for doctor = 1.0
# likelihood for medical = 1.0
# likelihood for intern = 1.0
# likelihood for extern = 1.0
# likelihood for night = 1.0
# likelihood for weekend = 1.0
# likelihood for duty = 1.0
# likelihood for 2 = 0.8181818181818182
# likelihood for work = 0.6818181818181818
# likelihood for officials = 1.0
# likelihood for pass = 0.6666666666666666
# likelihood for legislation = 1.0
# likelihood for permit = 0.8333333333333334
# likelihood for establishment = 1.0
# likelihood for fair = 0.6
# likelihood for equitable = 1.0
# likelihood for pension = 1.0
# likelihood for plan = 0.9333333333333333
# likelihood for employes = 1.0
# likelihood for praised = 1.0
# likelihood for operation = 1.0
# likelihood for Police = 0.4444444444444444
# likelihood for Tax = 1.0
# likelihood for Commissioner's = 1.0
# likelihood for Office = 1.0
# likelihood for Bellwood = 1.0
# likelihood for Alpharetta = 1.0
# likelihood for prison = 1.0
# likelihood for farms = 1.0
# likelihood for Grady = 0.8
# likelihood for Hospital = 0.9047619047619048
# likelihood for Health = 1.0
# likelihood for Mayor = 0.9411764705882353
# likelihood for William = 0.9722222222222222
# likelihood for B. = 0.9354838709677419
# likelihood for Hartsfield = 1.0
# likelihood for filed = 0.5714285714285714
# likelihood for suit = 1.0
# likelihood for divorce = 0.6666666666666666
# likelihood for his = 0.9974937343358395
# likelihood for wife = 1.0
# likelihood for Pearl = 1.0
# likelihood for Williams = 1.0
# likelihood for His = 1.0
# likelihood for petition = 1.0
# likelihood for mental = 1.0
# likelihood for cruelty = 1.0
# likelihood for couple = 1.0
# likelihood for married = 1.0
# likelihood for Aug. = 1.0
# likelihood for 1913 = 1.0
# likelihood for They = 1.0
# likelihood for son = 0.9545454545454546
# likelihood for Berry = 1.0
# likelihood for daughter = 1.0
# likelihood for Mrs. = 0.9960474308300395
# likelihood for J. = 0.9761904761904762
# likelihood for M. = 1.0
# likelihood for Cheshire = 1.0
# likelihood for Griffin = 1.0
# likelihood for Attorneys = 1.0
# likelihood for mayor = 1.0
# likelihood for amicable = 1.0
# likelihood for property = 1.0
# likelihood for settlement = 1.0
# likelihood for agreed = 0.5333333333333333
# likelihood for upon = 0.782608695652174
# likelihood for listed = 0.6
# likelihood for mayor's = 1.0
# likelihood for occupation = 1.0
# likelihood for attorney = 1.0
# likelihood for age = 1.0
# likelihood for 71 = 1.0
# likelihood for wife's = 1.0
# likelihood for 74 = 1.0
# likelihood for birth = 1.0
# likelihood for Opelika = 1.0
# likelihood for Ala. = 0.8571428571428571
# likelihood for lived = 0.6666666666666666
# likelihood for together = 1.0
# likelihood for man = 1.0
# likelihood for more = 0.7134502923976608
# likelihood for than = 0.5072463768115942
# likelihood for year = 0.9927536231884058
# likelihood for home = 0.5669291338582677
# likelihood for 637 = 1.0
# likelihood for E. = 0.9411764705882353
# likelihood for Pelham = 1.0
# likelihood for Rd. = 1.0
# likelihood for Aj = 1.0
# likelihood for Henry = 1.0
# likelihood for L. = 1.0
# likelihood for Bowden = 1.0
# likelihood for brief = 1.0
# likelihood for interlude = 1.0
# likelihood for since = 0.5901639344262295
# likelihood for 1937 = 1.0
# likelihood for career = 1.0
# likelihood for goes = 1.0
# likelihood for back = 0.782608695652174
# likelihood for council = 1.0
# likelihood for 1923 = 1.0
# likelihood for present = 0.7
# likelihood for office = 1.0
# likelihood for expires = 1.0
# likelihood for He = 1.0
# likelihood for succeeded = 0.6666666666666666
# likelihood for who = 1.0
# likelihood for became = 1.0
# likelihood for candidate = 1.0
# likelihood for Sept. = 1.0
# likelihood for 13 = 1.0
# likelihood for after = 0.5433070866141733
# likelihood for announced = 0.5405405405405406
# likelihood for he = 1.0
# likelihood for would = 0.9959016393442623
# likelihood for run = 0.5714285714285714
# likelihood for reelection = 1.0
# likelihood for Georgia = 0.5555555555555556
# likelihood for Republicans = 0.9333333333333333
# likelihood for getting = 1.0
# likelihood for strong = 1.0
# likelihood for encouragement = 1.0
# likelihood for enter = 1.0
# likelihood for 1962 = 1.0
# likelihood for governor's = 1.0
# likelihood for race = 0.95
# likelihood for top = 0.6764705882352942
# likelihood for official = 0.625
# likelihood for Wednesday = 1.0
# likelihood for Robert = 1.0
# likelihood for Snodgrass = 1.0
# likelihood for GOP = 0.8
# likelihood for chairman = 1.0
# likelihood for meeting = 0.9354838709677419
# likelihood for held = 0.6341463414634146
# likelihood for Tuesday = 1.0
# likelihood for Blue = 0.8181818181818182
# likelihood for Ridge = 1.0
# likelihood for brought = 0.5714285714285714
# likelihood for enthusiastic = 1.0
# likelihood for responses = 1.0
# likelihood for audience = 1.0
# likelihood for Party = 0.8888888888888888
# likelihood for Chairman = 1.0
# likelihood for James = 0.972972972972973
# likelihood for W. = 0.9736842105263158
# likelihood for Dorsey = 1.0
# likelihood for enthusiasm = 1.0
# likelihood for picking = 1.0
# likelihood for up = 0.8869047619047619
# likelihood for rally = 1.0
# likelihood for 8 = 0.9545454545454546
# likelihood for Savannah = 1.0
# likelihood for newly = 0.8333333333333334
# likelihood for Texas = 0.5625
# likelihood for Sen. = 1.0
# likelihood for John = 0.9692307692307692
# likelihood for Tower = 1.0
# likelihood for featured = 1.0
# likelihood for speaker = 1.0
# likelihood for In = 0.984251968503937
# likelihood for warned = 0.5
# likelihood for entering = 1.0
# likelihood for governor = 1.0
# likelihood for force = 0.5714285714285714
# likelihood for petitions = 0.8333333333333334
# likelihood for out = 0.8198757763975155
# likelihood for voting = 1.0
# likelihood for precincts = 1.0
# likelihood for obtain = 1.0
# likelihood for signatures = 1.0
# likelihood for registered = 1.0
# likelihood for Despite = 1.0
# likelihood for warning = 0.75
# likelihood for unanimous = 1.0
# likelihood for vote = 0.75
# likelihood for according = 1.0
# likelihood for attended = 0.6
# likelihood for When = 1.0
# likelihood for crowd = 1.0
# likelihood for asked = 0.5588235294117647
# likelihood for whether = 1.0
# likelihood for wanted = 0.9
# likelihood for wait = 0.5
# likelihood for make = 1.0
# likelihood for voted = 1.0
# likelihood for -- = 1.0
# likelihood for were = 1.0
# likelihood for dissents = 1.0
# likelihood for largest = 1.0
# likelihood for hurdle = 1.0
# likelihood for face = 0.5789473684210527
# likelihood for says = 1.0
# likelihood for before = 0.5
# likelihood for making = 0.88
# likelihood for first = 0.8881118881118881
# likelihood for alternative = 0.5
# likelihood for courses = 1.0
# likelihood for must = 0.98
# likelihood for taken = 1.0
# likelihood for Five = 0.75
# likelihood for per = 1.0
# likelihood for cent = 1.0
# likelihood for each = 1.0
# likelihood for county = 0.9615384615384616
# likelihood for sign = 0.6666666666666666
# likelihood for requesting = 1.0
# likelihood for allowed = 0.625
# likelihood for names = 1.0
# likelihood for candidates = 1.0
# likelihood for ballot = 1.0
# likelihood for hold = 0.9
# likelihood for unit = 1.0
# likelihood for system = 1.0
# likelihood for party = 0.9411764705882353
# likelihood for opposes = 1.0
# likelihood for platform = 1.0
# likelihood for Sam = 1.0
# likelihood for Caldwell = 1.0
# likelihood for Highway = 1.0
# likelihood for public = 0.7058823529411765
# likelihood for relations = 0.9375
# likelihood for director = 1.0
# likelihood for resigned = 1.0
# likelihood for Lt. = 1.0
# likelihood for Gov. = 1.0
# likelihood for Garland = 1.0
# likelihood for Byrd's = 1.0
# likelihood for campaign = 0.8823529411764706
# likelihood for Caldwell's = 1.0
# likelihood for resignation = 1.0
# likelihood for expected = 0.875
# likelihood for time = 1.0
# likelihood for Rob = 1.0
# likelihood for Ledford = 1.0
# likelihood for Gainesville = 1.0
# likelihood for assistant = 0.9
# likelihood for three = 0.9896907216494846
# likelihood for years = 0.9901960784313726
# likelihood for gubernatorial = 1.0
# likelihood for starts = 0.6666666666666666
# likelihood for become = 0.5217391304347826
# likelihood for coordinator = 1.0
# likelihood for Byrd = 1.0
# likelihood for wind = 0.5
# likelihood for 1961 = 1.0
# likelihood for session = 1.0
# likelihood for Monday = 1.0
# likelihood for head = 0.6666666666666666
# likelihood for where = 1.0
# likelihood for highway = 1.0
# likelihood for bond = 1.0
# likelihood for approved = 0.625
# likelihood for shortly = 1.0
# likelihood for Before = 0.5714285714285714
# likelihood for adjournment = 1.0
# likelihood for afternoon = 1.0
# likelihood for Senate = 1.0
# likelihood for approve = 1.0
# likelihood for study = 0.7692307692307693
# likelihood for allotted = 0.5
# likelihood for rural = 1.0
# likelihood for urban = 1.0
# likelihood for areas = 1.0
# likelihood for determine = 1.0
# likelihood for what = 1.0
# likelihood for adjustments = 1.0
# likelihood for made = 0.5794392523364486
# likelihood for Vandiver = 1.0
# likelihood for traditional = 1.0
# likelihood for visit = 0.5
# likelihood for chambers = 1.0
# likelihood for toward = 1.0
# likelihood for likely = 0.7142857142857143
# likelihood for mention = 1.0
# likelihood for $100 = 1.0
# likelihood for million = 1.0
# likelihood for issue = 0.8
# likelihood for earlier = 0.7083333333333334
# likelihood for priority = 1.0
# likelihood for item = 1.0
# likelihood for Construction = 0.5
# likelihood for bonds = 0.9655172413793104
# likelihood for Meanwhile = 1.0
# likelihood for learned = 0.5714285714285714
# likelihood for very = 0.9090909090909091
# likelihood for near = 0.6875
# likelihood for being = 1.0
# likelihood for ready = 1.0
# likelihood for $30 = 1.0
# likelihood for worth = 0.6
# likelihood for reconstruction = 1.0
# likelihood for go = 0.975609756097561
# likelihood for courts = 1.0
# likelihood for friendly = 1.0
# likelihood for test = 0.8666666666666667
# likelihood for validity = 1.0
# likelihood for then = 1.0
# likelihood for sales = 1.0
# likelihood for begin = 1.0
# likelihood for contracts = 0.75
# likelihood for let = 0.9
# likelihood for repair = 1.0
# likelihood for most = 0.5675675675675675
# likelihood for heavily = 0.6
# likelihood for traveled = 0.5
# likelihood for highways = 1.0
# likelihood for A = 0.9051094890510949
# likelihood for source = 1.0
# likelihood for $3 = 1.0
# likelihood for $4 = 1.0
# likelihood for Rural = 1.0
# likelihood for Roads = 1.0
# likelihood for Authority = 1.0
# likelihood for road = 1.0
# likelihood for construction = 1.0
# likelihood for revolving = 0.6666666666666666
# likelihood for fund = 0.9166666666666666
# likelihood for department = 1.0
# likelihood for apparently = 1.0
# likelihood for intends = 1.0
# likelihood for issued = 0.75
# likelihood for every = 1.0
# likelihood for old = 1.0
# likelihood for ones = 1.0
# likelihood for paid = 0.6
# likelihood for off = 0.6575342465753424
# likelihood for tax = 0.9622641509433962
# likelihood for authorities = 1.0
# likelihood for opened = 0.7777777777777778
# likelihood for 1958 = 1.0
# likelihood for battle = 1.0
# likelihood for against = 0.9743589743589743
# likelihood for issuance = 1.0
# likelihood for $50 = 1.0
# likelihood for roads = 0.9
# likelihood for Marvin = 1.0
# likelihood for told = 0.8490566037735849
# likelihood for Constitution = 1.0
# likelihood for however = 1.0
# likelihood for consulted = 0.75
# likelihood for yet = 0.9
# likelihood for about = 0.625
# likelihood for plans = 0.6818181818181818
# likelihood for Schley = 1.0
# likelihood for Rep. = 1.0
# likelihood for D. = 1.0
# likelihood for offer = 0.8888888888888888
# likelihood for resolution = 1.0
# likelihood for House = 0.9577464788732394
# likelihood for rescind = 1.0
# likelihood for body's = 1.0
# likelihood for action = 1.0
# likelihood for itself = 1.0
# likelihood for $10 = 1.0
# likelihood for day = 1.0
# likelihood for increase = 0.625
# likelihood for expense = 1.0
# likelihood for allowances = 1.0
# likelihood for Sunday = 1.0
# likelihood for research = 0.9333333333333333
# likelihood for done = 1.0
# likelihood for quickie = 1.0
# likelihood for can = 1.0
# likelihood for repealed = 1.0
# likelihood for outright = 0.6666666666666666
# likelihood for notice = 0.8
# likelihood for given = 1.0
# likelihood for reconsideration = 1.0
# likelihood for sought = 0.5
# likelihood for While = 1.0
# likelihood for emphasizing = 1.0
# likelihood for technical = 1.0
# likelihood for details = 1.0
# likelihood for fully = 1.0
# likelihood for worked = 0.6666666666666666
# likelihood for seek = 1.0
# likelihood for set = 0.45098039215686275
# likelihood for aside = 1.0
# likelihood for privilege = 1.0
# likelihood for 87-31 = 1.0
# likelihood for similar = 1.0
# likelihood for passed = 0.6111111111111112
# likelihood for 29-5 = 1.0
# likelihood for As = 0.8888888888888888
# likelihood for word = 1.0
# likelihood for offered = 0.6363636363636364
# likelihood for pointed = 1.0
# likelihood for last = 0.9565217391304348
# likelihood for November = 1.0
# likelihood for rejected = 0.5
# likelihood for constitutional = 1.0
# likelihood for amendment = 1.0
# likelihood for allow = 1.0
# likelihood for pay = 0.8181818181818182
# likelihood for raises = 1.0
# likelihood for sessions = 1.0
# likelihood for veteran = 0.7272727272727273
# likelihood for Jackson = 0.6
# likelihood for legislator = 1.0
# likelihood for ask = 1.0
# likelihood for aid = 0.92
# likelihood for education = 1.0
# likelihood for something = 1.0
# likelihood for consistently = 1.0
# likelihood for opposed = 0.6666666666666666
# likelihood for past = 0.4
# likelihood for Mac = 1.0
# likelihood for Barber = 0.8
# likelihood for Commerce = 1.0
# likelihood for asking = 1.0
# likelihood for endorse = 1.0
# likelihood for increased = 0.8
# likelihood for support = 0.875
# likelihood for provided = 0.875
# likelihood for expended = 1.0
# likelihood for 13th = 1.0
# likelihood for members = 1.0
# likelihood for congressional = 1.0
# likelihood for delegation = 1.0
# likelihood for Washington = 0.625
# likelihood for like = 0.5652173913043478
# likelihood for see = 1.0
# likelihood for But = 1.0
# likelihood for congressmen = 1.0
# likelihood for specifically = 1.0
# likelihood for him = 1.0
# likelihood for tossed = 1.0
# likelihood for hopper = 1.0
# likelihood for formally = 1.0
# likelihood for read = 0.46153846153846156
# likelihood for event = 1.0
# likelihood for Congress = 0.9047619047619048
# likelihood for does = 1.0
# likelihood for Board = 0.8823529411764706
# likelihood for Education = 0.9333333333333333
# likelihood for directed = 0.875
# likelihood for give = 1.0
# likelihood for teacher = 1.0
# likelihood for Colquitt = 0.5
# likelihood for After = 0.5833333333333334
# likelihood for long = 0.6410256410256411
# likelihood for hot = 1.0
# likelihood for controversy = 1.0
# likelihood for Miller = 0.6666666666666666
# likelihood for school = 1.0
# likelihood for superintendent = 1.0
# likelihood for policeman = 1.0
# likelihood for put = 0.5185185185185185
# likelihood for coolest = 1.0
# likelihood for I = 0.994413407821229
# likelihood for ever = 1.0
# likelihood for saw = 0.8235294117647058
# likelihood for Harry = 1.0
# likelihood for Davis = 1.0
# likelihood for agriculture = 1.0
# likelihood for defeated = 0.6
# likelihood for Felix = 1.0
# likelihood for Bush = 1.0
# likelihood for principal = 0.5555555555555556
# likelihood for Democratic = 0.9459459459459459
# likelihood for 1,119 = 1.0
# likelihood for votes = 0.8571428571428571
# likelihood for Saturday's = 1.0
# likelihood for got = 0.9333333333333333
# likelihood for 402 = 1.0
# likelihood for Ordinary = 1.0
# likelihood for Carey = 0.8
# likelihood for armed = 1.0
# likelihood for pistol = 1.0
# likelihood for stood = 1.0
# likelihood for polls = 1.0
# likelihood for insure = 1.0
# likelihood for order = 0.8947368421052632
# likelihood for calmest = 1.0
# likelihood for Policeman = 1.0
# likelihood for Tom = 1.0
# likelihood for Being = 1.0
# likelihood for just = 0.7857142857142857
# likelihood for church = 0.9375
# likelihood for didn't = 1.0
# likelihood for smell = 1.0
# likelihood for drop = 0.6666666666666666
# likelihood for liquor = 1.0
# likelihood for bit = 0.8571428571428571
# likelihood for trouble = 1.0
# likelihood for leading = 1.0
# likelihood for quiet = 1.0
# likelihood for marked = 1.0
# likelihood for anonymous = 1.0
# likelihood for midnight = 1.0
# likelihood for phone = 1.0
# likelihood for calls = 0.5384615384615384
# likelihood for veiled = 1.0
# likelihood for threats = 1.0
# likelihood for violence = 1.0
# likelihood for former = 1.0
# likelihood for George = 1.0
# likelihood for P. = 0.8333333333333334
# likelihood for Callan = 1.0
# likelihood for shot = 0.7857142857142857
# likelihood for himself = 1.0
# likelihood for death = 1.0
# likelihood for March = 0.75
# likelihood for 18 = 0.8
# likelihood for four = 1.0
# likelihood for days = 0.9736842105263158
# likelihood for post = 0.9
# likelihood for dispute = 1.0
# likelihood for board = 1.0
# likelihood for During = 1.0
# likelihood for reportedly = 1.0
# likelihood for telephone = 1.0
# likelihood for too = 0.7027027027027027
# likelihood for subjected = 1.0
# likelihood for soon = 1.0
# likelihood for scheduled = 0.9285714285714286
# likelihood for Many = 0.8333333333333334
# likelihood for local = 0.8717948717948718
# likelihood for feared = 1.0
# likelihood for carry = 1.0
# likelihood for gun = 1.0
# likelihood for promised = 1.0
# likelihood for Sheriff = 1.0
# likelihood for Tabb = 1.0
# likelihood for ordinary = 0.8571428571428571
# likelihood for good = 0.9
# likelihood for promise = 0.6666666666666666
# likelihood for Everything = 1.0
# likelihood for went = 1.0
# likelihood for real = 0.875
# likelihood for smooth = 1.0
# likelihood for sheriff = 1.0
# likelihood for There = 0.9137931034482759
# likelihood for wasn't = 1.0
# likelihood for Austin = 0.6
# likelihood for approval = 1.0
# likelihood for Price = 0.6666666666666666
# likelihood for Daniel's = 1.0
# likelihood for abandoned = 0.6666666666666666
# likelihood for seemed = 1.0
# likelihood for certain = 1.0
# likelihood for Thursday = 1.0
# likelihood for despite = 1.0
# likelihood for adamant = 1.0
# likelihood for protests = 1.0
# likelihood for bankers = 1.0
# likelihood for Daniel = 1.0
# likelihood for personally = 1.0
# likelihood for led = 0.5882352941176471
# likelihood for fight = 0.7142857142857143
# likelihood for measure = 0.9230769230769231
# likelihood for watered = 1.0
# likelihood for down = 0.8
# likelihood for considerably = 0.6
# likelihood for rejection = 1.0
# likelihood for Legislatures = 1.0
# likelihood for hearing = 0.7142857142857143
# likelihood for Revenue = 0.8
# likelihood for Taxation = 1.0
# likelihood for Under = 0.875
# likelihood for rules = 0.9090909090909091
# likelihood for automatically = 1.0
# likelihood for subcommittee = 1.0
# likelihood for week = 0.9883720930232558
# likelihood for questions = 1.0
# likelihood for taunted = 1.0
# likelihood for appearing = 1.0
# likelihood for witnesses = 1.0
# likelihood for left = 0.41025641025641024
# likelihood for little = 0.42857142857142855
# likelihood for doubt = 0.8333333333333334
# likelihood for recommend = 1.0
# likelihood for passage = 1.0
# likelihood for termed = 0.5
# likelihood for extremely = 0.5
# likelihood for conservative = 1.0
# likelihood for estimate = 0.6666666666666666
# likelihood for produce = 1.0
# likelihood for 17 = 0.5714285714285714
# likelihood for dollars = 1.0
# likelihood for help = 0.5333333333333333
# likelihood for erase = 1.0
# likelihood for anticipated = 1.0
# likelihood for deficit = 1.0
# likelihood for 63 = 1.0
# likelihood for current = 1.0
# likelihood for fiscal = 1.0
# likelihood for 31 = 1.0
# likelihood for merely = 0.8
# likelihood for means = 0.7222222222222222
# likelihood for enforcing = 1.0
# likelihood for escheat = 1.0
# likelihood for books = 1.0
# likelihood for republic = 1.0
# likelihood for permits = 0.75
# likelihood for over = 0.7478260869565218
# likelihood for bank = 1.0
# likelihood for accounts = 1.0
# likelihood for stocks = 0.9
# likelihood for personal = 1.0
# likelihood for persons = 1.0
# likelihood for missing = 1.0
# likelihood for seven = 0.875
# likelihood for bill = 1.0
# likelihood for drafted = 1.0
# likelihood for banks = 1.0
# likelihood for insurance = 1.0
# likelihood for firms = 1.0
# likelihood for pipeline = 1.0
# likelihood for companies = 1.0
# likelihood for corporations = 1.0
# likelihood for report = 0.76
# likelihood for treasurer = 1.0
# likelihood for cannot = 1.0
# likelihood for enforced = 1.0
# likelihood for now = 1.0
# likelihood for because = 0.7843137254901961
# likelihood for almost = 0.7083333333333334
# likelihood for impossible = 1.0
# likelihood for locate = 1.0
# likelihood for declared = 0.8666666666666667
# likelihood for Dewey = 1.0
# likelihood for Lawrence = 0.8333333333333334
# likelihood for Tyler = 1.0
# likelihood for lawyer = 1.0
# likelihood for representing = 1.0
# likelihood for Bankers = 1.0
# likelihood for sounded = 1.0
# likelihood for opposition = 1.0
# likelihood for keynote = 0.6666666666666666
# likelihood for violate = 1.0
# likelihood for their = 1.0
# likelihood for contractual = 1.0
# likelihood for obligations = 1.0
# likelihood for depositors = 1.0
# likelihood for undermine = 1.0
# likelihood for confidence = 1.0
# likelihood for customers = 1.0
# likelihood for If = 1.0
# likelihood for you = 0.7090909090909091
# likelihood for destroy = 1.0
# likelihood for economy = 1.0
# likelihood for You = 1.0
# likelihood for circulation = 1.0
# likelihood for millions = 1.0
# likelihood for Charles = 0.9545454545454546
# likelihood for Hughes = 0.9545454545454546
# likelihood for Sherman = 0.7777777777777778
# likelihood for sponsor = 0.5
# likelihood for failure = 1.0
# likelihood for enact = 1.0
# likelihood for amount = 0.5555555555555556
# likelihood for gift = 1.0
# likelihood for taxpayers' = 1.0
# likelihood for pockets = 1.0
# likelihood for contention = 1.0
# likelihood for denied = 0.8
# likelihood for several = 1.0
# likelihood for including = 1.0
# likelihood for Scott = 1.0
# likelihood for Hudson = 1.0
# likelihood for Gaynor = 1.0
# likelihood for Jones = 0.8636363636363636
# likelihood for Houston = 1.0
# likelihood for Brady = 1.0
# likelihood for Harlingen = 1.0
# likelihood for Howard = 0.9230769230769231
# likelihood for Cox = 1.0
# likelihood for argued = 0.8571428571428571
# likelihood for probably = 1.0
# likelihood for unconstitutional = 1.0
# likelihood for impair = 1.0
# likelihood for complained = 1.0
# likelihood for enough = 0.5555555555555556
# likelihood for introduced = 0.6
# likelihood for only = 0.5145631067961165
# likelihood for Senators = 0.75
# likelihood for unanimously = 1.0
# likelihood for Parkhouse = 1.0
# likelihood for Dallas = 0.7551020408163265
# likelihood for authorizing = 1.0
# likelihood for schools = 0.972972972972973
# likelihood for deaf = 1.0
# likelihood for designed = 1.0
# likelihood for special = 0.9024390243902439
# likelihood for schooling = 0.5
# likelihood for students = 1.0
# likelihood for scholastic = 1.0
# likelihood for reduced = 0.8333333333333334
# likelihood for debate = 1.0
# likelihood for authorize = 1.0
# likelihood for Agency = 1.0
# likelihood for establish = 1.0
# likelihood for county-wide = 1.0
# likelihood for 300,000 = 1.0
# likelihood for population = 1.0
# likelihood for require = 1.0
# likelihood for children = 1.0
# likelihood for between = 1.0
# likelihood for 6 = 1.0
# likelihood for attend = 0.8823529411764706
# likelihood for permitting = 1.0
# likelihood for older = 1.0
# likelihood for residential = 1.0
# likelihood for School = 1.0
# likelihood for Deaf = 1.0
# likelihood for here = 0.9850746268656716
# likelihood for Operating = 1.0
# likelihood for budget = 1.0
# likelihood for five = 0.975609756097561
# likelihood for Harris = 0.625
# likelihood for Bexar = 1.0
# likelihood for Tarrant = 1.0
# likelihood for El = 1.0
# likelihood for Paso = 1.0
# likelihood for $451,500 = 1.0
# likelihood for savings = 1.0
# likelihood for $157,460 = 1.0
# likelihood for yearly = 1.0
# likelihood for year's = 1.0
# likelihood for capital = 1.0
# likelihood for outlay = 1.0
# likelihood for $88,000 = 1.0
# likelihood for absorbed = 1.0
# likelihood for TEA = 1.0
# likelihood for estimated = 0.5
# likelihood for 182 = 1.0
# likelihood for scholastics = 1.0
# likelihood for saving = 1.0
# likelihood for coming = 1.0
# likelihood for live = 0.8666666666666667
# likelihood for get = 1.0
# likelihood for hear = 1.0
# likelihood for horse = 1.0
# likelihood for parimutuels = 1.0
# likelihood for Reps. = 1.0
# likelihood for V. = 1.0
# likelihood for Red = 0.7142857142857143
# likelihood for Joe = 1.0
# likelihood for Ratcliff = 1.0
# likelihood for still = 0.9722222222222222
# likelihood for expects = 1.0
# likelihood for tell = 1.0
# likelihood for folks = 1.0
# likelihood for why = 1.0
# likelihood for thinks = 1.0
# likelihood for Berry's = 1.0
# likelihood for We're = 1.0
# likelihood for ' = 1.0
# likelihood for pro = 0.42857142857142855
# likelihood for letters = 1.0
# likelihood for con = 1.0
# likelihood for betting = 0.5
# likelihood for believe = 1.0
# likelihood for if = 1.0
# likelihood for people = 1.0
# likelihood for better = 0.6071428571428571
# likelihood for informed = 0.7777777777777778
# likelihood for question = 0.9473684210526315
# likelihood for oppose = 1.0
# likelihood for I'm = 1.0
# likelihood for willing = 1.0
# likelihood for stake = 1.0
# likelihood for my = 1.0
# likelihood for ex-gambler = 1.0
# likelihood for San = 0.9545454545454546
# likelihood for Antonio = 1.0
# likelihood for advocacy = 1.0
# likelihood for ponies = 1.0
# likelihood for heard = 0.7333333333333333
# likelihood for option = 1.0
# likelihood for proposal = 0.9285714285714286
# likelihood for favorable = 1.0
# likelihood for although = 1.0
# likelihood for faces = 0.5
# likelihood for hard = 0.7272727272727273
# likelihood for sledding = 1.0
# likelihood for later = 0.9705882352941176
# likelihood for house = 0.9230769230769231
# likelihood for finally = 1.0
# likelihood for sent = 0.75
# likelihood for extending = 1.0
# likelihood for authority = 1.0
# likelihood for planning = 0.6666666666666666
# likelihood for cities = 1.0
# likelihood for senate = 0.5
# likelihood for quickly = 1.0
# likelihood for whipped = 1.0
# likelihood for meager = 1.0
# likelihood for fare = 1.0
# likelihood for bills = 1.0
# likelihood for committees = 1.0
# likelihood for passing = 1.0
# likelihood for calendar = 1.0
# likelihood for One = 0.9310344827586207
# likelihood for validated = 1.0
# likelihood for acts = 1.0
# likelihood for districts = 1.0
# likelihood for Another = 1.0
# likelihood for enlarged = 1.0
# likelihood for Beaumont = 0.5
# likelihood for Navigation = 1.0
# likelihood for District = 1.0
# likelihood for third = 0.9722222222222222
# likelihood for amended = 1.0
# likelihood for creation = 1.0
# likelihood for Lamar = 0.6666666666666666
# likelihood for previously = 1.0
# likelihood for adopted = 0.9
# likelihood for Without = 1.0
# likelihood for dissent = 1.0
# likelihood for senators = 1.0
# likelihood for A. = 1.0
# likelihood for R. = 0.9473684210526315
# likelihood for Schwartz = 1.0
# likelihood for Galveston = 1.0
# likelihood for mentally = 1.0
# likelihood for retarded = 1.0
# likelihood for Gulf = 1.0
# likelihood for Coast = 1.0
# likelihood for district = 1.0
# likelihood for Money = 1.0
# likelihood for meantime = 1.0
# likelihood for accept = 1.0
# likelihood for gifts = 1.0
# likelihood for donations = 1.0
# likelihood for site = 1.0
# likelihood for Two = 0.7647058823529411
# likelihood for revision = 1.0
# likelihood for Louis = 0.5714285714285714
# likelihood for Crump = 1.0
# likelihood for Saba = 1.0
# likelihood for 17,000 = 1.0
# likelihood for retailers = 1.0
# likelihood for group = 1.0
# likelihood for miscellaneous = 1.0
# likelihood for excise = 1.0
# likelihood for taxes = 1.0
# likelihood for eliminating = 1.0
# likelihood for requirement = 1.0
# likelihood for return = 0.6842105263157895
# likelihood for notarized = 1.0
# likelihood for Instead = 1.0
# likelihood for certificate = 1.0
# likelihood for correctness = 1.0
# likelihood for violation = 1.0
# likelihood for penalty = 1.0
# likelihood for plus = 1.0
# likelihood for $1,000 = 1.0
# likelihood for fine = 0.7058823529411765
# likelihood for series = 1.0
# likelihood for Research = 0.75
# likelihood for League = 1.0
# likelihood for Aikin = 1.0
# likelihood for Paris = 0.8
# likelihood for relieve = 1.0
# likelihood for estate = 1.0
# likelihood for brokers = 1.0
# likelihood for own = 0.9512195121951219
# likelihood for annual = 1.0
# likelihood for licensing = 1.0
# likelihood for fee = 1.0
# likelihood for $12 = 1.0
# likelihood for license = 0.875
# likelihood for Natural = 1.0
# likelihood for gas = 0.9
# likelihood for utility = 1.0
# likelihood for right = 0.5454545454545454
# likelihood for eminent = 1.0
# likelihood for domain = 1.0
# likelihood for Frank = 1.0
# likelihood for Owen = 1.0
# likelihood for 3 = 0.72
# likelihood for acquire = 1.0
# likelihood for sites = 1.0
# likelihood for underground = 0.5
# likelihood for storage = 1.0
# likelihood for reservoirs = 1.0
# likelihood for Marshall = 0.6666666666666666
# likelihood for Formby = 1.0
# likelihood for Plainview = 1.0
# likelihood for Commission = 1.0
# likelihood for suggested = 0.875
# likelihood for fill = 1.0
# likelihood for vacancies = 1.0
# likelihood for need = 0.7096774193548387
# likelihood for costly = 1.0
# likelihood for elections = 1.0
# likelihood for Formby's = 1.0
# likelihood for appointee = 1.0
# likelihood for selected = 0.75
# likelihood for composed = 1.0
# likelihood for lieutenant = 1.0
# likelihood for chief = 0.5
# likelihood for justice = 1.0
# likelihood for Supreme = 1.0
# likelihood for representatives = 1.0
# likelihood for decided = 0.75
# likelihood for taking = 0.9375
# likelihood for poll = 1.0
# likelihood for kind = 0.9
# likelihood for Texans = 1.0
# likelihood for prefer = 1.0
# likelihood for An = 1.0
# likelihood for adverse = 1.0
# likelihood for 81 = 1.0
# likelihood for 65 = 1.0
# likelihood for kept = 0.6875
# likelihood for Affairs = 1.0
# likelihood for referendum = 1.0
# likelihood for April = 0.9
# likelihood for 4 = 0.9230769230769231
# likelihood for U.S. = 0.7586206896551724
# likelihood for senator = 1.0
# likelihood for Wesley = 1.0
# likelihood for Roberts = 1.0
# likelihood for Seminole = 1.0
# likelihood for idea = 1.0
# likelihood for delay = 0.75
# likelihood for kill = 1.0
# likelihood for West = 0.6818181818181818
# likelihood for Texan = 1.0
# likelihood for reported = 0.5357142857142857
# likelihood for gotten = 1.0
# likelihood for Bill = 1.0
# likelihood for Hollowell = 1.0
# likelihood for Feb. = 0.6363636363636364
# likelihood for 22 = 0.8235294117647058
# likelihood for final = 1.0
# likelihood for legislative = 1.0
# likelihood for two-thirds = 0.75
# likelihood for majorities = 1.0
# likelihood for printed = 1.0
# likelihood for Opponents = 1.0
# likelihood for couldn't = 1.0
# likelihood for information = 1.0
# likelihood for proposals = 1.0
# likelihood for intelligent = 1.0
# likelihood for choice = 1.0
# likelihood for All = 0.9444444444444444
# likelihood for except = 1.0
# likelihood for absent = 1.0
# likelihood for Paradise = 1.0
# likelihood for lost = 0.5833333333333334
# likelihood for alleged = 1.0
# likelihood for water = 0.9090909090909091
# likelihood for needs = 0.5714285714285714
# likelihood for Texas' = 1.0
# likelihood for big = 0.9736842105263158
# likelihood for Cotten = 1.0
# likelihood for Weatherford = 1.0
# likelihood for insisted = 1.0
# likelihood for development = 1.0
# likelihood for Representatives = 1.0
# likelihood for effort = 1.0
# likelihood for Fort = 0.75
# likelihood for Worth = 1.0
# likelihood for cover = 0.75
# likelihood for places = 0.8
# likelihood for Wise = 1.0
# likelihood for hamlet = 1.0
# likelihood for 250 = 1.0
# likelihood for shouting = 1.0
# likelihood for ended = 0.5
# likelihood for 114 = 1.0
# likelihood for sending = 1.0
# likelihood for sponsored = 0.8333333333333334
# likelihood for Most = 0.8571428571428571
# likelihood for $5,000,000 = 1.0
# likelihood for $15,000,000 = 1.0
# likelihood for maximum = 0.8888888888888888
# likelihood for loan = 1.0
# likelihood for could = 1.0
# likelihood for project = 0.9615384615384616
# likelihood for construed = 1.0
# likelihood for large = 1.0
# likelihood for felt = 0.8
# likelihood for spent = 0.75
# likelihood for providing = 0.75
# likelihood for Statements = 1.0
# likelihood for paying = 1.0
# likelihood for benefit = 0.75
# likelihood for pending = 1.0
# likelihood for sway = 1.0
# likelihood for Cotten's = 1.0
# likelihood for attack = 0.8
# likelihood for bill's = 1.0
# likelihood for defenders = 1.0
# likelihood for mostly = 1.0
# likelihood for small-town = 1.0
# likelihood for Buchanan = 1.0
# likelihood for Dumas = 1.0
# likelihood for Eligio = 1.0
# likelihood for Kika = 1.0
# likelihood for De = 0.6363636363636364
# likelihood for La = 0.7142857142857143
# likelihood for Garza = 1.0
# likelihood for Mission = 1.0
# likelihood for F. = 1.0
# likelihood for Collins = 1.0
# likelihood for Newton = 1.0
# likelihood for Chapman = 1.0
# likelihood for Sulphur = 1.0
# likelihood for Springs = 1.0
# likelihood for poor = 1.0
# likelihood for boy's = 1.0
# likelihood for peanut = 1.0
# likelihood for serving = 0.75
# likelihood for reducing = 1.0
# likelihood for learning = 0.5714285714285714
# likelihood for educational = 1.0
# likelihood for methods = 1.0
# likelihood for C. = 0.96875
# likelihood for Grover = 1.0
# likelihood for teaches = 1.0
# likelihood for history = 1.0
# likelihood for 24 = 0.7
# likelihood for 12 = 0.9047619047619048
# likelihood for semester = 1.0
# likelihood for hours = 1.0
# likelihood for so-called = 1.0
# likelihood for teaching = 0.6666666666666666
# likelihood for required = 0.9090909090909091
# likelihood for junior = 0.75
# likelihood for senior = 0.7777777777777778
# likelihood for high = 0.8269230769230769
# likelihood for normal = 1.0
# likelihood for college = 1.0
# likelihood for 30 = 1.0
# likelihood for junior-senior = 1.0
# likelihood for teachers = 1.0
# likelihood for least = 1.0
# likelihood for credit = 0.8
# likelihood for subject = 1.0
# likelihood for remainder = 1.0
# likelihood for 4-year = 1.0
# likelihood for subjects = 1.0
# likelihood for person = 1.0
# likelihood for master's = 1.0
# likelihood for degree = 1.0
# likelihood for physics = 1.0
# likelihood for chemistry = 1.0
# likelihood for math = 1.0
# likelihood for English = 0.8333333333333334
# likelihood for permitted = 0.6
# likelihood for teach = 1.0
# likelihood for College = 0.95
# likelihood for Fifty-three = 1.0
# likelihood for 150 = 1.0
# likelihood for immediately = 1.0
# likelihood for joined = 0.7272727272727273
# likelihood for co-signers = 1.0
# likelihood for sp. = 1.0
# likelihood for regents = 1.0
# likelihood for Junior = 1.0
# likelihood for named = 0.8888888888888888
# likelihood for Dr. = 0.9761904761904762
# likelihood for Clarence = 1.0
# likelihood for Clark = 1.0
# likelihood for Hays = 1.0
# likelihood for Kan. = 1.0
# likelihood for school's = 1.0
# likelihood for president = 1.0
# likelihood for succeed = 1.0
# likelihood for McLemore = 1.0
# likelihood for retire = 1.0
# likelihood for close = 0.5
# likelihood for holds = 1.0
# likelihood for earned = 0.7142857142857143
# likelihood for Doctor = 1.0
# likelihood for University = 1.0
# likelihood for Oklahoma = 0.625
# likelihood for Master = 1.0
# likelihood for Science = 1.0
# likelihood for & = 0.5588235294117647
# likelihood for Bachelor = 1.0
# likelihood for Southwestern = 0.5
# likelihood for Okla. = 1.0
# likelihood for addition = 1.0
# likelihood for Rhode = 1.0
# likelihood for Island = 1.0
# likelihood for Massachusetts = 0.5555555555555556
# likelihood for Institute = 1.0
# likelihood for Technology = 1.0
# likelihood for captain = 1.0
# likelihood for basketball = 1.0
# likelihood for team = 1.0
# likelihood for football = 1.0
# likelihood for letterman = 1.0
# likelihood for served = 0.5294117647058824
# likelihood for athletic = 1.0
# likelihood for Raymondville = 1.0
# likelihood for High = 0.875
# likelihood for instructor = 1.0
# likelihood for associate = 0.75
# likelihood for professor = 1.0
# likelihood for border = 1.0
# likelihood for patrolman = 1.0
# likelihood for Signal = 1.0
# likelihood for Corps = 1.0
# likelihood for Army = 1.0
# likelihood for Denton = 0.5
# likelihood for Principals = 1.0
# likelihood for Independent = 1.0
# likelihood for re-elected = 1.0
# likelihood for 1961-62 = 1.0
# likelihood for recommendation = 1.0
# likelihood for Supt. = 1.0
# likelihood for Chester = 0.6
# likelihood for O. = 0.75
# likelihood for Strickland = 1.0
# likelihood for racial = 1.0
# likelihood for discrimination = 1.0
# likelihood for employment = 1.0
# likelihood for called = 0.5135135135135135
# likelihood for yesterday = 1.0
# likelihood for blue = 1.0
# likelihood for ribbon = 1.0
# likelihood for dependent = 1.0
# likelihood for culminating = 1.0
# likelihood for ADC = 1.0
# likelihood for Cook = 0.8
# likelihood for New = 0.946236559139785
# likelihood for York = 1.0
# likelihood for consulting = 1.0
# likelihood for firm = 0.9032258064516129
# likelihood for 10 = 0.972972972972973
# likelihood for range = 0.8333333333333334
# likelihood for soaring = 1.0
# likelihood for case = 0.9722222222222222
# likelihood for load = 1.0
# likelihood for serious = 1.0
# likelihood for causes = 0.6
# likelihood for family = 1.0
# likelihood for breakdown = 1.0
# likelihood for desertion = 1.0
# likelihood for dependency = 1.0
# likelihood for Must = 0.3333333333333333
# likelihood for solve = 0.6666666666666666
# likelihood for monthly = 1.0
# likelihood for 100,000 = 1.0
# likelihood for recipients = 1.0
# likelihood for 4.4 = 1.0
# likelihood for Virgil = 1.0
# likelihood for Martin = 1.0
# likelihood for Carson = 1.0
# likelihood for Pirie = 1.0
# likelihood for Co. = 1.0
# likelihood for We = 0.9666666666666667
# likelihood for problems = 1.0
# likelihood for forced = 0.75
# likelihood for depend = 1.0
# likelihood for subsistence = 1.0
# likelihood for volume = 1.0
# likelihood for cases = 0.9444444444444444
# likelihood for decrease = 1.0
# likelihood for community = 1.0
# likelihood for able = 1.0
# likelihood for deal = 0.8333333333333334
# likelihood for effectively = 1.0
# likelihood for Relatively = 1.0
# likelihood for limited = 0.9285714285714286
# likelihood for skills = 1.0
# likelihood for color = 1.0
# likelihood for underlying = 1.0
# likelihood for breakups = 1.0
# likelihood for Calls = 1.0
# likelihood for extension = 0.5
# likelihood for Other = 0.9333333333333333
# likelihood for Extension = 1.0
# likelihood for living = 0.8888888888888888
# likelihood for relatives = 1.0
# likelihood for parents = 1.0
# likelihood for preserving = 1.0
# likelihood for unity = 1.0
# likelihood for projects = 1.0
# likelihood for prevention = 1.0
# likelihood for illegitimacy = 1.0
# likelihood for Several = 1.0
# likelihood for defendants = 1.0
# likelihood for Summerdale = 1.0
# likelihood for police = 0.7419354838709677
# likelihood for burglary = 1.0
# likelihood for trial = 0.9523809523809523
# likelihood for statements = 1.0
# likelihood for indicating = 1.0
# likelihood for guilt = 1.0
# likelihood for arrest = 1.0
# likelihood for Parsons = 1.0
# likelihood for Criminal = 1.0
# likelihood for disclosure = 1.0
# likelihood for Bellows = 1.0
# likelihood for defense = 1.0
# ...
# likelihood for occurrence = 1.0
# likelihood for resort = 1.0
# likelihood for eject = 1.0
# likelihood for Lumumba's = 1.0
# likelihood for reconvention = 1.0
# likelihood for McCloy's = 1.0
# likelihood for reliance = 1.0
# likelihood for thorny = 1.0
# likelihood for Bizerte = 1.0
# likelihood for Tunis = 1.0
# likelihood for imbroglio = 1.0
# likelihood for quo = 1.0
# likelihood for Mediterranean = 1.0
# likelihood for Tunisian = 1.0
# likelihood for Bahi = 1.0
# likelihood for Ladgham = 1.0
# likelihood for irreconcilable = 1.0
# likelihood for Habib = 1.0
# likelihood for Bourguiba = 1.0
# likelihood for picks = 1.0
# likelihood for Uruguay = 1.0
# likelihood for Inter-American = 1.0
# likelihood for Main = 1.0
# likelihood for Alliance = 1.0
# likelihood for Progress = 0.5
# likelihood for Nationalist = 1.0
# likelihood for China's = 1.0
# likelihood for dapper = 1.0
# likelihood for diminutive = 1.0
# likelihood for Chen = 1.0
# likelihood for Cheng = 1.0
# likelihood for Chiang = 1.0
# likelihood for Kai-shek's = 1.0
# likelihood for emissary = 1.0
# likelihood for Outer = 1.0
# likelihood for Mongolia = 1.0
# likelihood for woo = 1.0
# likelihood for Peking = 1.0
# likelihood for abstention = 1.0
# likelihood for Mongolia's = 1.0
# likelihood for conferred = 1.0
# likelihood for emissaries = 1.0
# likelihood for Guatemala = 1.0
# likelihood for Nepal = 1.0
# likelihood for good-will = 1.0
# likelihood for Ivory = 1.0
# likelihood for skyjacked = 1.0
# likelihood for four-jet = 1.0
# likelihood for Boeing = 0.5
# likelihood for 707 = 0.75
# likelihood for stopovers = 1.0
# likelihood for Airlines = 1.0
# likelihood for night-coach = 1.0
# likelihood for Flight = 1.0
# likelihood for 1:35 = 1.0
# likelihood for Thirty-one = 1.0
# likelihood for teen-age = 1.0
# likelihood for 3:57 = 1.0
# likelihood for stewardess = 1.0
# likelihood for aisle = 1.0
# likelihood for bent = 1.0
# likelihood for stomach = 1.0
# likelihood for sick = 1.0
# likelihood for Salvador = 1.0
# likelihood for Desert = 1.0
# likelihood for Carnegey = 1.0
# likelihood for Rickards = 1.0
# likelihood for 52-year-old = 1.0
# likelihood for hijacked = 0.5
# likelihood for mid-flight = 1.0
# likelihood for Peruvian = 1.0
# likelihood for tri-motor = 1.0
# likelihood for Arequipa = 1.0
# likelihood for pirates = 1.0
# likelihood for Cuban-American = 1.0
# likelihood for Electra = 1.0
# likelihood for Newsweek = 1.0
# likelihood for Stalling = 1.0
# likelihood for guns = 1.0
# likelihood for elder = 1.0
# likelihood for radioed = 0.5
# likelihood for skyjackers = 1.0
# likelihood for refuel = 1.0
# likelihood for McCauley = 1.0
# likelihood for Sacramento = 1.0
# likelihood for recruits = 1.0
# likelihood for awoke = 1.0
# likelihood for nap = 1.0
# likelihood for nut = 1.0
# likelihood for recruiter = 1.0
# likelihood for volunteer = 1.0
# likelihood for hostages = 1.0
# likelihood for Mullen = 1.0
# likelihood for Pfc. = 1.0
# likelihood for Augustine = 1.0
# likelihood for Gilman = 1.0
# likelihood for boxer = 1.0
# likelihood for Immigration = 1.0
# likelihood for Border = 1.0
# likelihood for 4:18 = 1.0
# likelihood for sheriff's = 1.0
# likelihood for surged = 1.0
# likelihood for submachine = 1.0
# likelihood for ordinarily = 1.0
# likelihood for fuels = 1.0
# likelihood for consumed = 1.0
# likelihood for swap = 1.0
# likelihood for propeller-driven = 1.0
# likelihood for hijackers = 1.0
# likelihood for airplane = 1.0
# likelihood for Cuba's = 1.0
# likelihood for steal = 1.0
# likelihood for embargo = 1.0
# likelihood for shadows = 1.0
# likelihood for Mountains = 1.0
# likelihood for pry = 1.0
# likelihood for baggage = 1.0
# likelihood for luggage = 1.0
# likelihood for subsequently = 1.0
# likelihood for Bearden = 1.0
# likelihood for 50-year-old = 1.0
# likelihood for ex-convict = 1.0
# likelihood for Coolidge = 1.0
# likelihood for Cody = 1.0
# likelihood for high-school = 1.0
# likelihood for Tension = 1.0
# likelihood for Beardens = 1.0
# likelihood for slug = 1.0
# likelihood for Officer = 1.0
# likelihood for Simmons = 1.0
# likelihood for ultimatum = 1.0
# likelihood for take-off = 1.0
# likelihood for taxiing = 1.0
# likelihood for raced = 1.0
# likelihood for slugs = 1.0
# likelihood for flattened = 1.0
# likelihood for silenced = 1.0
# likelihood for inboard = 1.0
# likelihood for engines = 1.0
# likelihood for Ambulances = 1.0
# likelihood for 12:50 = 1.0
# likelihood for Crosby = 1.0
# likelihood for eased = 1.0
# likelihood for unarmed = 1.0
# likelihood for distracted = 1.0
# likelihood for stewardesses = 1.0
# likelihood for Toni = 1.0
# likelihood for Besset = 1.0
# likelihood for pocket = 1.0
# likelihood for Simmons' = 1.0
# likelihood for nodded = 1.0
# likelihood for Frog-marched = 1.0
# likelihood for $100,000 = 1.0
# likelihood for kidnapping = 1.0
# likelihood for transporting = 1.0
# likelihood for peddle = 1.0
# likelihood for 36-year-old = 1.0
# likelihood for Taking = 1.0
# likelihood for precedence = 1.0
# likelihood for unaccustomed = 1.0
# likelihood for unanimity = 1.0
# likelihood for 0 = 1.0
# likelihood for peacetime = 1.0
# likelihood for 225,000 = 1.0
# likelihood for requested = 1.0
# likelihood for 160,000 = 1.0
# likelihood for hold-back = 1.0
# likelihood for mutterers = 1.0
# likelihood for labeled = 1.0
# likelihood for prudently = 1.0
# likelihood for $46.7 = 1.0
# likelihood for tacked = 1.0
# likelihood for $754 = 1.0
# likelihood for B-52 = 1.0
# likelihood for long-range = 1.0
# likelihood for bombers = 1.0
# likelihood for Strategic = 1.0
# likelihood for Command = 1.0
# likelihood for 224-170 = 1.0
# likelihood for $5.2 = 1.0
# likelihood for Debate = 1.0
# likelihood for all-important = 1.0
# likelihood for foreign-aid = 1.0
# likelihood for Food = 1.0
# likelihood for stew = 1.0
# likelihood for Mulligatawny = 1.0
# likelihood for poor-mouth = 1.0
# likelihood for lowliest = 1.0
# likelihood for 1851 = 1.0
# likelihood for ceased = 1.0
# likelihood for enlivened = 1.0
# likelihood for Maine = 1.0
# likelihood for Idaho = 1.0
# likelihood for menu = 1.0
# likelihood for drab = 1.0
# likelihood for smelts = 1.0
# likelihood for soft-shell = 1.0
# likelihood for crabs = 1.0
# likelihood for grapefruit = 1.0
# likelihood for bean = 1.0
# likelihood for soup = 1.0
# likelihood for Dubois = 1.0
# likelihood for citizenry = 1.0
# likelihood for ventured = 1.0
# likelihood for haute = 1.0
# likelihood for cuisine = 1.0
# likelihood for $10,000-per-year = 1.0
# likelihood for French-born = 1.0
# likelihood for maitre = 1.0
# likelihood for d'hotel = 1.0
# likelihood for Holders = 1.0
# likelihood for toll-road = 1.0
# likelihood for turnpikes = 1.0
# likelihood for Long-term = 1.0
# likelihood for Higher = 1.0
# likelihood for toll = 1.0
# likelihood for Result = 1.0
# likelihood for payoff = 1.0
# likelihood for speculative = 1.0
# likelihood for Things = 1.0
# likelihood for streams = 1.0
# likelihood for speculations = 1.0
# likelihood for investments = 1.0
# likelihood for tending = 1.0
# likelihood for Poor's = 1.0
# likelihood for slipped = 1.0
# likelihood for bucked = 1.0
# likelihood for rises = 1.0
# likelihood for outnumber = 1.0
# likelihood for Tax-free = 1.0
# likelihood for more-than-ordinary = 1.0
# likelihood for risen = 1.0
# likelihood for unmarried = 1.0
# likelihood for investor = 1.0
# likelihood for $16,000 = 1.0
# likelihood for $32,000 = 1.0
# likelihood for Swelling = 1.0
# likelihood for 12-month = 1.0
# likelihood for happening = 1.0
# likelihood for Blyth = 1.0
# likelihood for lags = 1.0
# likelihood for Indication = 1.0
# likelihood for turnpike = 1.0
# likelihood for Turnpike = 1.0
# likelihood for slumped = 1.0
# likelihood for road's = 1.0
# likelihood for 186 = 1.0
# likelihood for 173 = 1.0
# likelihood for preceding = 1.0
# likelihood for Costs = 1.0
# likelihood for 121 = 1.0
# likelihood for Slow = 1.0
# likelihood for successes = 1.0
# likelihood for 187-mile = 1.0
# likelihood for Toll = 1.0
# likelihood for Success = 1.0
# likelihood for engineers' = 1.0
# likelihood for rosy = 1.0
# likelihood for toll-rate = 1.0
# likelihood for extensions = 1.0
# likelihood for tolls = 1.0
# likelihood for Richmond-Petersburg = 1.0
# likelihood for Easier = 1.0
# likelihood for access = 0.6666666666666666
# likelihood for motorists' = 1.0
# likelihood for illustration = 1.0
# likelihood for 62 = 1.0
# likelihood for Further = 1.0
# likelihood for Wichita = 1.0
# likelihood for Kans. = 1.0
# likelihood for deficiency = 1.0
# likelihood for opportunities = 1.0
# likelihood for Skyway = 1.0
# likelihood for planners = 1.0
# likelihood for default = 1.0
# likelihood for defaulted = 1.0
# likelihood for Already = 1.0
# likelihood for margins = 1.0
# likelihood for attracting = 1.0
# likelihood for break-even = 1.0
# likelihood for competitively = 1.0
# likelihood for Luther = 1.0
# likelihood for toured = 1.0
# likelihood for Italy's = 1.0
# likelihood for Fiat = 1.0
# likelihood for Olivetti = 1.0
# likelihood for typewriters = 1.0
# likelihood for calculating = 1.0
# likelihood for cabled = 1.0
# likelihood for Turin = 1.0
# likelihood for Follow = 1.0
# likelihood for Plan = 1.0
# likelihood for enables = 1.0
# likelihood for fraction = 1.0
# likelihood for skilled = 1.0
# likelihood for earns = 1.0
# likelihood for infrequent = 1.0
# likelihood for Underwood = 1.0
# likelihood for Underwood's = 1.0
# likelihood for exports = 1.0
# likelihood for layout = 1.0
# likelihood for design-conscious = 1.0
# likelihood for sales-conscious = 1.0
# likelihood for advertising-conscious = 1.0
# likelihood for inflow = 1.0
# likelihood for vigor = 1.0
# likelihood for textiles = 1.0
# likelihood for imports = 1.0
# likelihood for textile = 0.9090909090909091
# likelihood for Important = 1.0
# likelihood for textile-importing = 1.0
# likelihood for textile-exporting = 1.0
# likelihood for noting = 1.0
# likelihood for industrialized = 1.0
# likelihood for less-developed = 1.0
# likelihood for exporting = 1.0
# likelihood for Idea = 1.0
# likelihood for low-wage = 1.0
# likelihood for high-wage = 1.0
# likelihood for textile-producing = 1.0
# likelihood for curbing = 1.0
# likelihood for limiting = 1.0
# likelihood for Lancashire = 1.0
# likelihood for Pact = 1.0
# likelihood for None = 1.0
# likelihood for capture = 1.0
# likelihood for loudly = 1.0
# likelihood for protest = 1.0
# likelihood for Spanish = 1.0
# likelihood for Portuguese = 1.0
# likelihood for pour = 1.0
# likelihood for unrestrictedly = 1.0
# likelihood for Pakistanis = 1.0
# likelihood for chafing = 1.0
# likelihood for bilateral = 1.0
# likelihood for quotas = 1.0
# likelihood for Gradual = 1.0
# likelihood for stabilization = 1.0
# likelihood for clue = 1.0
# likelihood for Note = 1.0
# likelihood for modernization = 1.0
# likelihood for shrinkage = 1.0
# likelihood for transferring = 1.0
# likelihood for feasible = 1.0
# likelihood for Special = 1.0
# likelihood for Import = 1.0
# likelihood for forcing = 1.0
# likelihood for shrink = 1.0
# likelihood for What's = 1.0
# likelihood for handwriting = 1.0
# likelihood for highest-paid = 1.0
# likelihood for coal = 1.0
# likelihood for miners = 1.0
# likelihood for cheap = 1.0
# likelihood for steelmakers' = 1.0
# likelihood for mouths = 1.0
# likelihood for Wales = 0.5
# likelihood for steelmaker = 1.0
# likelihood for takings = 1.0
# likelihood for Welsh = 1.0
# likelihood for markets = 1.0
# likelihood for $2.80 = 1.0
# likelihood for ton = 1.0
# likelihood for cheaper = 1.0
# likelihood for rail = 1.0
# likelihood for mines = 1.0
# likelihood for mechanization = 1.0
# likelihood for seams = 1.0
# likelihood for attactive = 1.0
# likelihood for nationalized = 1.0
# likelihood for twisting = 1.0
# likelihood for Productivity = 1.0
# likelihood for Communist-led = 1.0
# likelihood for unprofitable = 1.0
# likelihood for borrower = 1.0
# likelihood for five-cent = 1.0
# likelihood for fiction = 1.0
# likelihood for rentals = 1.0
# likelihood for apologetically = 1.0
# likelihood for sorry = 1.0
# likelihood for Behind = 1.0
# likelihood for variations = 1.0
# likelihood for ever-present = 1.0
# likelihood for libraries = 1.0
# likelihood for grist = 1.0
# likelihood for 15,000 = 1.0
# likelihood for readers = 1.0
# likelihood for lovers = 1.0
# likelihood for nonfiction = 1.0
# likelihood for clientele = 1.0
# likelihood for diversified = 1.0
# likelihood for budgets = 1.0
# likelihood for hopelessly = 1.0
# likelihood for startlingly = 1.0
# likelihood for exceed = 1.0
# likelihood for librarian's = 1.0
# likelihood for richest = 1.0
# likelihood for plight = 1.0
# likelihood for proportionately = 1.0
# likelihood for Confronted = 1.0
# likelihood for limitations = 1.0
# likelihood for bounty = 1.0
# likelihood for contrasts = 1.0
# likelihood for density = 1.0
# likelihood for cross-section = 1.0
# likelihood for extreme = 1.0
# likelihood for upper = 1.0
# likelihood for sparsely = 1.0
# likelihood for populated = 1.0
# likelihood for Nassau = 0.5714285714285714
# likelihood for high-density = 1.0
# likelihood for ample = 1.0
# likelihood for thriving = 1.0
# likelihood for wary = 1.0
# likelihood for well-stocked = 1.0
# likelihood for cherish = 1.0
# likelihood for joining = 1.0
# likelihood for radical = 1.0
# likelihood for autonomy = 1.0
# likelihood for preserved = 1.0
# likelihood for maintains = 1.0
# likelihood for advantages = 1.0
# likelihood for librarians = 1.0
# likelihood for foresee = 1.0
# likelihood for distant = 1.0
# likelihood for co-op = 1.0
# likelihood for requires = 1.0
# likelihood for volumes = 1.0
# likelihood for nucleus = 1.0
# likelihood for develops = 1.0
# likelihood for thirty = 1.0
# likelihood for fifty = 1.0
# likelihood for capita = 1.0
# likelihood for inclusive = 1.0
# likelihood for recognizes = 1.0
# likelihood for broaden = 1.0
# likelihood for everyday = 1.0
# likelihood for Hempstead = 1.0
# likelihood for 1965 = 1.0
# likelihood for Basic = 1.0
# likelihood for tools = 1.0
# likelihood for backbone = 1.0
# likelihood for specialization = 1.0
# likelihood for microfilm = 1.0
# likelihood for founding = 1.0
# likelihood for periodicals = 1.0
# likelihood for interlibrary = 1.0
# likelihood for connected = 1.0
# likelihood for teletype = 1.0
# likelihood for truck = 1.0
# likelihood for canvas = 1.0
# likelihood for psychology = 1.0
# likelihood for religion = 1.0
# likelihood for Freeport = 1.0
# likelihood for biography = 1.0
# likelihood for centered = 1.0
# likelihood for Levittown = 1.0
# likelihood for Hewlett-Woodmere = 1.0
# likelihood for repository = 1.0
# likelihood for wholly = 1.0
# likelihood for quarter-century = 1.0
# likelihood for comprehensive = 1.0
# likelihood for saves = 1.0
# likelihood for bulk = 1.0
# likelihood for discounts = 1.0
# likelihood for bookkeeping = 1.0
# likelihood for billing = 1.0
# likelihood for Books = 1.0
# likelihood for resource = 1.0
# likelihood for Schools = 1.0
# likelihood for documentary = 1.0
# likelihood for catalogue = 1.0
# likelihood for classics = 1.0
# likelihood for Nanook = 1.0
# likelihood for Emperor's = 1.0
# likelihood for Nightingale = 1.0
# likelihood for Balloon = 1.0
# likelihood for Workshops = 1.0
# likelihood for system's = 1.0
# likelihood for understands = 1.0
# likelihood for responsibilities = 1.0
# likelihood for conducts = 1.0
# likelihood for well-planned = 1.0
# likelihood for book-review = 1.0
# likelihood for book-selection = 1.0
# likelihood for Sample = 1.0
# likelihood for copies = 1.0
# likelihood for evaluate = 1.0
# likelihood for Story = 1.0
# likelihood for pre-school = 1.0
# likelihood for grassroots = 1.0
# likelihood for prepares = 1.0
# likelihood for displays = 1.0
# likelihood for booklists = 1.0
# likelihood for brochures = 1.0
# likelihood for publishes = 1.0
# likelihood for Sum = 1.0
# likelihood for Substance = 1.0
# likelihood for newsletter = 1.0
# likelihood for governed = 1.0
# likelihood for geographically = 1.0
# likelihood for bear = 1.0
# likelihood for Librarians = 1.0
# likelihood for borne = 1.0
# likelihood for multiplying = 1.0
# likelihood for newcomers = 1.0
# likelihood for maligned = 1.0
# likelihood for teen-agers = 1.0
# likelihood for co-ops = 1.0
# likelihood for citizen = 1.0
# likelihood for advances = 1.0
# likelihood for educated = 1.0
# likelihood for discriminating = 1.0
# likelihood for slave = 1.0
# likelihood for spiritual = 1.0
# likelihood for restraint = 1.0
# likelihood for falls = 1.0
# likelihood for grows = 1.0
# likelihood for translate = 1.0
# likelihood for inadequacy = 1.0
# likelihood for vigorously = 1.0
# likelihood for 25,000,000 = 1.0
# likelihood for 50,000,000 = 1.0
# likelihood for 124 = 1.0
# likelihood for 1,509 = 1.0
# likelihood for 66 = 1.0
# likelihood for pupils = 1.0
# likelihood for render = 1.0
# likelihood for vitally = 1.0
# likelihood for 16-22 = 1.0
# likelihood for richer = 1.0
# likelihood for fuller = 1.0
#
# average correct = 0.9644662324868203

# %% [markdown]
# 18. Generate some statistics for tagged data to answer the following questions:
#
# a. What proportion of word types are always assigned the same part-of-speech tag?
#
# b. How many words are ambiguous, in the sense that they appear with at least two tags?
#
# c. What percentage of word ** tokens ** in the Brown Corpus involve these ambiguous words?

# %%
from nltk.corpus import brown
import nltk

#setting things up
brown_tagged_words = brown.tagged_words(categories='news')
cfd = nltk.ConditionalFreqDist(brown_tagged_words)
conditions = cfd.conditions()

# creates a new array of word types that only have one distinct word tag
mono_tags = [condition for condition in conditions if len(cfd[condition]) == 1]

# answers number one - the proportion of tags that have only one POS tag.
proportion_mono_tags = len(mono_tags) / len(conditions)
print(proportion_mono_tags)

# answers number two - the number of ambiguous words.
number_mono_tags = len(conditions) - len(mono_tags)
print(number_mono_tags)

# answers number three by calculating the number of ambiguous words in the total brown corpus with this small sample size. Gives you one percent.

total_brown_words = set(brown.words())
number_shared_words = [word for word in mono_tags if word in total_brown_words]
percen_brown = len(number_shared_words) / len(brown.words())
print(percen_brown)
# Out:
# 0.8802973461164374
# 1723
# 0.010912062776870663

# %% [markdown]
# 19. The evaluate() method works out how accurately the tagger performs on this
# text. For example, if the supplied tagged text was [('the', 'DT'), ('dog',
# 'NN')] and the tagger produced the output [('the', 'NN'), ('dog', 'NN')], then
# the score would be 0.5. Let’s try to figure out how the evaluation method works:
#
# a. A tagger t takes a list of words as input, and produces a list of tagged words
# as output. However, t.evaluate() is given correctly tagged text as its only
# parameter. What must it do with this input before performing the tagging?
#
# b. Once the tagger has created newly tagged text, how might the evaluate()
# method go about comparing it with the original tagged text and computing
# the accuracy score?
#
# c. Now examine the source code to see how the method is implemented. Inspect
# nltk.tag.api.__file__ to discover the location of the source code, and open
# this file using an editor (be sure to use the api.py file and not the compiled
# api.pyc binary file).

# %% [markdown]
# 20. Write code to search the Brown Corpus for particular words and phrases according to tags, to answer the following questions:
#
# a. Produce an alphabetically sorted list of the distinct words tagged as MD.
#
# b. Identify words that can be plural nouns or third person singular verbs (e.g.,
# deals, flies).
#
# c. Identify three-word prepositional phrases of the form IN + DET + NN (e.g.,
# in the lab).
#
# d. What is the ratio of masculine to feminine pronouns?

# %%
import nltk
nltk.download('brown')
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\universal_tagset.zip.
# True

# %%
from nltk.corpus import brown

# Extract words tagged as MD
md_words = set(word.lower() for word, tag in brown.tagged_words(tagset='universal') if tag == 'MD')

# Sort alphabetically
sorted_md_words = sorted(md_words)

print("Distinct words tagged as MD:")
print(sorted_md_words)
# Out:
# Distinct words tagged as MD:
# []

# %%
# Extract words tagged as NNS (plural nouns) or VBZ (third person singular verbs)
plural_nouns = set(word.lower() for word, tag in brown.tagged_words(tagset='universal') if tag == 'NNS')
third_person_singular_verbs = set(word.lower() for word, tag in brown.tagged_words(tagset='universal') if tag == 'VBZ')

# Find common words
common_words = plural_nouns.intersection(third_person_singular_verbs)

print("Words that can be plural nouns or third person singular verbs:")
print(common_words)
# Out:
# Words that can be plural nouns or third person singular verbs:
# set()

# %%
from nltk import pos_tag, word_tokenize
from nltk.corpus import reuters

# Load sentences from the Brown Corpus
sentences = brown.sents()

prepositional_phrases = []

# Loop through sentences to find IN + DET + NN patterns
for sentence in sentences:
    tagged_sentence = pos_tag(sentence, tagset='universal')
    for i in range(len(tagged_sentence) - 2):
        if tagged_sentence[i][1] == 'IN' and tagged_sentence[i+1][1] == 'DET' and tagged_sentence[i+2][1] == 'NN':
            phrase = ' '.join(word for word, _ in tagged_sentence[i:i+3])
            prepositional_phrases.append(phrase)

print("Three-word prepositional phrases (IN + DET + NN):")
print(prepositional_phrases[:10])  # Print a sample
# Out:
# Three-word prepositional phrases (IN + DET + NN):
# []

# %%
# Extract masculine and feminine pronouns
masculine_pronouns = set(['he', 'him', 'his', 'himself'])
feminine_pronouns = set(['she', 'her', 'hers', 'herself'])

# Count occurrences
masculine_count = sum(1 for word, tag in brown.tagged_words(tagset='universal') if word.lower() in masculine_pronouns)
feminine_count = sum(1 for word, tag in brown.tagged_words(tagset='universal') if word.lower() in feminine_pronouns)

# Calculate ratio
ratio = masculine_count / (feminine_count if feminine_count > 0 else 1)  # Avoid division by zero

print(f"Masculine pronouns count: {masculine_count}")
print(f"Feminine pronouns count: {feminine_count}")
print(f"Ratio of masculine to feminine pronouns: {ratio:.2f}")
# Out:
# Masculine pronouns count: 19766
# Feminine pronouns count: 6037
# Ratio of masculine to feminine pronouns: 3.27

# %% [markdown]
# 22. We defined the regexp_tagger that can be used as a fall-back tagger for unknown
# words. This tagger only checks for cardinal numbers. By testing for particular prefix
# or suffix strings, it should be possible to guess other tags. For example, we could
# tag any word that ends with -s as a plural noun. Define a regular expression tagger
# (using RegexpTagger()) that tests for at least five other patterns in the spelling of
# words. (Use inline documentation to explain the rules.)

# %%
import nltk
from nltk.tag import RegexpTagger
from nltk.corpus import brown

# Define regular expression patterns and their corresponding tags
patterns = [
    # Pattern to match words ending in -s (plural nouns)
    (r'.*s$', 'NNS'),  # NNS - plural noun

    # Pattern to match words ending in -ed (past tense verbs)
    (r'.*ed$', 'VBD'),  # VBD - past tense verb

    # Pattern to match words ending in -ing (present participles)
    (r'.*ing$', 'VBG'),  # VBG - gerund or present participle

    # Pattern to match words starting with un- (prefix indicating negation)
    (r'^un.*$', 'JJ'),  # JJ - adjective

    # Pattern to match words ending in -ly (adverbs)
    (r'.*ly$', 'RB')    # RB - adverb
]

# Create the regular expression tagger with the defined patterns
regexp_tagger = RegexpTagger(patterns)

# Example sentences for testing
sentences = [
    'He walks to the park quickly.',
    'The children were playing happily in the garden.',
    'She unlocked the door yesterday.',
    'The birds were flying high in the sky.',
    'This is an unusual problem.'
]

# Tokenize sentences and apply the regular expression tagger
for sentence in sentences:
    tokens = nltk.word_tokenize(sentence)
    tagged_sentence = regexp_tagger.tag(tokens)
    print("Original Sentence:", sentence)
    print("Tagged Sentence:", tagged_sentence)
    print()
# Out:
# Original Sentence: He walks to the park quickly.
# Tagged Sentence: [('He', None), ('walks', 'NNS'), ('to', None), ('the', None), ('park', None), ('quickly', 'RB'), ('.', None)]
#
# Original Sentence: The children were playing happily in the garden.
# Tagged Sentence: [('The', None), ('children', None), ('were', None), ('playing', 'VBG'), ('happily', 'RB'), ('in', None), ('the', None), ('garden', None), ('.', None)]
#
# Original Sentence: She unlocked the door yesterday.
# Tagged Sentence: [('She', None), ('unlocked', 'VBD'), ('the', None), ('door', None), ('yesterday', None), ('.', None)]
#
# Original Sentence: The birds were flying high in the sky.
# Tagged Sentence: [('The', None), ('birds', 'NNS'), ('were', None), ('flying', 'VBG'), ('high', None), ('in', None), ('the', None), ('sky', None), ('.', None)]
#
# Original Sentence: This is an unusual problem.
# Tagged Sentence: [('This', 'NNS'), ('is', 'NNS'), ('an', None), ('unusual', 'JJ'), ('problem', None), ('.', None)]

# %% [markdown]
# 23. Consider the regular expression tagger developed in the exercises in the previous
# section. Evaluate the tagger using its accuracy() method, and try to come up with
# ways to improve its performance. Discuss your findings. How does objective evaluation help in the development process?

# %%
import nltk
from nltk.tag import RegexpTagger
from nltk.corpus import brown
from nltk import accuracy

# Define regular expression patterns and their corresponding tags
patterns = [
    (r'.*s$', 'NNS'),  # Plural nouns
    (r'.*ed$', 'VBD'), # Past tense verbs
    (r'.*ing$', 'VBG'),# Present participles
    (r'^un.*$', 'JJ'), # Adjectives with prefix 'un'
    (r'.*ly$', 'RB')   # Adverbs
]

# Create the regular expression tagger with the defined patterns
regexp_tagger = RegexpTagger(patterns)

# Use Brown Corpus for evaluation
# Extract tagged words from the Brown Corpus
train_sents = brown.tagged_sents(categories='news')
test_sents = brown.tagged_sents(categories='editorial')

# Evaluate the tagger on the test set
accuracy_score = regexp_tagger.accuracy(test_sents)
print(f"Accuracy: {accuracy_score:.2f}")

# For detailed evaluation, print some example taggings
for sent in test_sents[:3]:  # Print a few sentences for manual inspection
    tokens, true_tags = zip(*sent)
    tagged_sentence = regexp_tagger.tag(tokens)
    print("Original Tags:", true_tags)
    print("Predicted Tags:", [tag for _, tag in tagged_sentence])
    print()
# Out:
# Accuracy: 0.08
# Original Tags: ('NN-HL', 'NN-HL', 'VBD-HL', 'AP-HL', 'NN-HL')
# Predicted Tags: ['RB', None, None, None, None]
#
# Original Tags: ('AT', 'JJ-TL', 'NN-TL', ',', 'WDT', 'VBZ', 'NR', ',', 'HVZ', 'VBN', 'IN', 'AT', 'NN', 'IN', 'NN', 'CC', 'NN', 'IN', 'AT', 'NN', 'PPS', 'VBD', '.')
# Predicted Tags: [None, None, 'RB', None, None, 'NNS', None, None, 'NNS', 'VBD', None, None, None, None, 'NNS', None, None, None, None, None, None, 'VBD', None]
#
# Original Tags: ('PPS', 'BEDZ', 'VBN', 'RB', 'IN', 'AT', 'NN', 'IN', 'AT', 'NNS', ',', 'AT', 'NN', 'WDT', 'BEDZ', 'VBN', 'RB', 'IN', 'NN', 'IN', 'AT', 'NN', 'IN', 'AT', 'NN', '*', 'TO', 'VB', 'VBG', 'NN', 'NN', '.')
# Predicted Tags: [None, 'NNS', 'VBD', 'RB', None, None, None, None, None, 'NNS', None, None, None, None, 'NNS', None, 'RB', None, None, None, None, None, None, None, None, None, None, None, 'VBG', None, None, None]

# %% [markdown]
# 24. How serious is the sparse data problem? Investigate the performance of n-gram
# taggers as n increases from 1 to 6. Tabulate the accuracy score. Estimate the training
# data required for these taggers, assuming a vocabulary size of 105 and a tagset size
# of 102.

# %%
import nltk
from nltk.corpus import brown
from nltk.tag import UnigramTagger, BigramTagger, TrigramTagger
from nltk.metrics import accuracy

# Load and prepare data
train_sents = brown.tagged_sents(categories='news')
test_sents = brown.tagged_sents(categories='editorial')

# Define a function to evaluate n-gram taggers
def evaluate_ngram_tagger(n, train_sents, test_sents):
    if n == 1:
        tagger = UnigramTagger(train_sents)
    elif n == 2:
        tagger = BigramTagger(train_sents)
    elif n == 3:
        tagger = TrigramTagger(train_sents)
    else:
        raise ValueError("n must be between 1 and 3")

    accuracy_score = tagger.evaluate(test_sents)
    return accuracy_score

# Evaluate taggers for n from 1 to 3
results = []
for n in range(1, 4):
    accuracy_score = evaluate_ngram_tagger(n, train_sents, test_sents)
    results.append((n, accuracy_score))

# Print results
print(f"{'N-gram Order':<12} {'Accuracy':<10}")
for n, acc in results:
    print(f"{n:<12} {acc:<10.4f}")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15288\752964277.py:21: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   accuracy_score = tagger.evaluate(test_sents)
# N-gram Order Accuracy
# 1            0.8137
# 2            0.1139
# 3            0.0673

# %% [markdown]
# 25. Obtain some tagged data for another language, and train and evaluate a variety
# of taggers on it. If the language is morphologically complex, or if there are any
# orthographic clues (e.g., capitalization) to word classes, consider developing a regular expression tagger for it (ordered after the unigram tagger, and before the default tagger). How does the accuracy of your tagger(s) compare with the same
# taggers run on English data? Discuss any issues you encounter in applying these
# methods to the language.

# %%
# !pip3 install nltk udapi-python
# Out:
# Requirement already satisfied: nltk in c:\users\dell\miniconda3\envs\vio\lib\site-packages (3.8.1)
# ERROR: Could not find a version that satisfies the requirement udapi-python (from versions: none)
# ERROR: No matching distribution found for udapi-python

# %%
import nltk
from nltk.corpus import treebank
from nltk.tag import UnigramTagger, BigramTagger, RegexpTagger
from nltk.metrics import accuracy
import re
from nltk.corpus.reader import TaggedCorpusReader

# 1. Obtain tagged data (for demonstration, we will use NLTK's treebank corpus)
# In practice, replace treebank.tagged_sents() with your own tagged data
tagged_sents = treebank.tagged_sents()

# Split the data into training and testing sets
train_data = tagged_sents[:3000]
test_data = tagged_sents[3000:]

# 2. Train and evaluate taggers

# Unigram Tagger
unigram_tagger = UnigramTagger(train_data)
unigram_accuracy = unigram_tagger.evaluate(test_data)
print(f'Unigram Tagger Accuracy: {unigram_accuracy:.4f}')

# Bigram Tagger (without backoff)
bigram_tagger = BigramTagger(train_data)
bigram_accuracy = bigram_tagger.evaluate(test_data)
print(f'Bigram Tagger Accuracy: {bigram_accuracy:.4f}')

# Regular Expression Tagger
patterns = [
    (r'.*ing$', 'VBG'),  # gerunds
    (r'.*ed$', 'VBD'),   # past tense verbs
    (r'.*es$', 'VBZ'),   # 3rd person singular present verbs
    (r'^-?[0-9]+(.[0-9]+)?$', 'CD'),  # cardinal numbers
    (r'.*\'s$', 'POS'),  # possessive nouns
]

regexp_tagger = RegexpTagger(patterns, backoff=unigram_tagger)
regexp_accuracy = regexp_tagger.evaluate(test_data)
print(f'Regexp Tagger Accuracy: {regexp_accuracy:.4f}')

# Evaluate on a custom regular expression tagger that checks for prefixes or suffixes
custom_patterns = [
    (r'.*mente$', 'RB'),   # adverbs ending in 'mente' (for Romance languages like Spanish)
    (r'.*ción$', 'NN'),    # nouns ending in 'ción'
    (r'.*idad$', 'NN'),    # nouns ending in 'idad'
    (r'.*ar$', 'VB'),      # infinitive verbs ending in 'ar'
    (r'^[A-Z].*', 'NNP'),  # proper nouns (capitalized words)
]

custom_regexp_tagger = RegexpTagger(custom_patterns, backoff=unigram_tagger)
custom_regexp_accuracy = custom_regexp_tagger.evaluate(test_data)
print(f'Custom Regexp Tagger Accuracy: {custom_regexp_accuracy:.4f}')

# 3. Compare with the taggers trained on English data
# Here, you would compare the accuracy of these taggers with their performance on another language dataset.

# 4. Discuss the results
# This part would involve analyzing the results, discussing issues like sparse data, and any challenges encountered.

# Note: Replace `treebank.tagged_sents()` with your own tagged data in practice.
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9716\3109640188.py:20: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   unigram_accuracy = unigram_tagger.evaluate(test_data)
# Unigram Tagger Accuracy: 0.8572
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9716\3109640188.py:25: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   bigram_accuracy = bigram_tagger.evaluate(test_data)
# Bigram Tagger Accuracy: 0.1132
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9716\3109640188.py:38: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   regexp_accuracy = regexp_tagger.evaluate(test_data)
# Regexp Tagger Accuracy: 0.8360
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9716\3109640188.py:51: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   custom_regexp_accuracy = custom_regexp_tagger.evaluate(test_data)
# Custom Regexp Tagger Accuracy: 0.8555

# %% [markdown]
# 28. Experiment with taggers using the simplified tagset (or make one of your own
# by discarding all but the first character of each tag name). Such a tagger has fewer
# distinctions to make, but much less information on which to base its work. Discuss
# your findings

# %% [markdown]
# 29. Recall the example of a bigram tagger which encountered a word it hadn’t seen
# during training, and tagged the rest of the sentence as None. It is possible for a
# bigram tagger to fail partway through a sentence even if it contains no unseen words
# (even if the sentence was used during training). In what circumstance can this
# happen? Can you write a program to find some examples of this?

# %%
import nltk
from nltk.corpus import brown
from nltk.tag import BigramTagger, UnigramTagger
from nltk.data import load

# Load the Brown corpus and split it into training and test sets
brown_tagged_sents = brown.tagged_sents(categories='news')
train_sents = brown_tagged_sents[:4000]
test_sents = brown_tagged_sents[4000:4050]

# Train a BigramTagger
bigram_tagger = BigramTagger(train_sents, backoff=UnigramTagger(train_sents))

# Function to find examples where the tagger fails
def find_broken_sentences(tagger, test_sents):
    broken_sentences = []
    for sent in test_sents:
        tagged_sent = tagger.tag([word for word, tag in sent])
        if None in [tag for word, tag in tagged_sent]:
            broken_sentences.append(sent)
    return broken_sentences

# Find and print examples where the bigram tagger fails
broken_sentences = find_broken_sentences(bigram_tagger, test_sents)
for sent in broken_sentences:
    print("Original:", sent)
    print("Tagged:  ", bigram_tagger.tag([word for word, tag in sent]))
    print()
# Out:
# Original: [('In', 'IN'), ("Ruth's", 'NP$'), ('day', 'NN'), ('--', '--'), ('and', 'CC'), ('until', 'IN'), ('this', 'DT'), ('year', 'NN'), ('--', '--'), ('the', 'AT'), ('schedule', 'NN'), ('was', 'BEDZ'), ('154', 'CD'), ('games', 'NNS'), ('.', '.')]
# Tagged:   [('In', 'IN'), ("Ruth's", 'NP$'), ('day', 'NN'), ('--', '--'), ('and', 'CC'), ('until', 'CS'), ('this', 'DT'), ('year', 'NN'), ('--', '--'), ('the', 'AT'), ('schedule', 'NN'), ('was', 'BEDZ'), ('154', None), ('games', 'NNS'), ('.', '.')]
#
# Original: [('Baseball', 'NN'), ('commissioner', 'NN'), ('Ford', 'NP'), ('Frick', 'NP'), ('has', 'HVZ'), ('ruled', 'VBN'), ('that', 'CS'), ("Ruth's", 'NP$'), ('record', 'NN'), ('will', 'MD'), ('remain', 'VB'), ('official', 'JJ'), ('unless', 'CS'), ('it', 'PPS'), ('is', 'BEZ'), ('broken', 'VBN'), ('in', 'IN'), ('154', 'CD'), ('games', 'NNS'), ('.', '.')]
# Tagged:   [('Baseball', 'NN-TL'), ('commissioner', 'NN'), ('Ford', 'NP'), ('Frick', 'NP'), ('has', 'HVZ'), ('ruled', 'VBN'), ('that', 'CS'), ("Ruth's", 'NP$'), ('record', 'NN'), ('will', 'MD'), ('remain', 'VB'), ('official', 'JJ'), ('unless', 'CS'), ('it', 'PPS'), ('is', 'BEZ'), ('broken', 'VBN'), ('in', 'IN'), ('154', None), ('games', 'NNS'), ('.', '.')]
#
# Original: [('``', '``'), ('Even', 'RB'), ('on', 'IN'), ('the', 'AT'), ('basis', 'NN'), ('of', 'IN'), ('154', 'CD'), ('games', 'NNS'), (',', ','), ('this', 'DT'), ('is', 'BEZ'), ('the', 'AT'), ('ideal', 'JJ'), ('situation', 'NN'), ("''", "''"), (',', ','), ('insists', 'VBZ'), ('Hank', 'NP'), ('Greenberg', 'NP'), (',', ','), ('now', 'RB'), ('vice-president', 'NN'), ('of', 'IN'), ('the', 'AT'), ('Chicago', 'NP-TL'), ('White', 'NN-TL'), ('Sox', 'NPS-TL'), ('.', '.')]
# Tagged:   [('``', '``'), ('Even', 'RB'), ('on', 'IN'), ('the', 'AT'), ('basis', 'NN'), ('of', 'IN'), ('154', None), ('games', 'NNS'), (',', ','), ('this', 'DT'), ('is', 'BEZ'), ('the', 'AT'), ('ideal', None), ('situation', 'NN'), ("''", "''"), (',', ','), ('insists', 'VBZ'), ('Hank', 'NP'), ('Greenberg', 'NP'), (',', ','), ('now', 'RB'), ('vice-president', 'NN'), ('of', 'IN'), ('the', 'AT'), ('Chicago', 'NP-TL'), ('White', 'NN-TL'), ('Sox', 'NPS-TL'), ('.', '.')]
#
# Original: [('``', '``'), ('It', 'PPS'), ('has', 'HVZ'), ('to', 'TO'), ('be', 'BE'), ('easier', 'JJR'), ('with', 'IN'), ('two', 'CD'), ('of', 'IN'), ('them', 'PPO'), ('.', '.')]
# Tagged:   [('``', '``'), ('It', 'PPS'), ('has', 'HVZ'), ('to', 'TO'), ('be', 'BE'), ('easier', None), ('with', 'IN'), ('two', 'CD'), ('of', 'IN'), ('them', 'PPO'), ('.', '.')]
#
# Original: [('Roommates', 'NNS-HL'), (':', ':-HL')]
# Tagged:   [('Roommates', None), (':', ':')]
#
# Original: [('Neither', 'CC'), ('Mantle', 'NP'), ('nor', 'CC'), ('Maris', 'NP'), (',', ','), ('understandably', 'RB'), (',', ','), ('will', 'MD'), ('predict', 'VB'), ('60', 'CD'), ('home', 'NN'), ('runs', 'NNS'), ('for', 'IN'), ('himself', 'PPL'), ('.', '.')]
# Tagged:   [('Neither', 'DTX'), ('Mantle', 'NP'), ('nor', 'CC'), ('Maris', 'NP'), (',', ','), ('understandably', None), (',', ','), ('will', 'MD'), ('predict', 'VB'), ('60', 'CD'), ('home', 'NN'), ('runs', 'NNS'), ('for', 'IN'), ('himself', 'PPL'), ('.', '.')]
#
# Original: [('Although', 'CS'), ('both', 'ABX'), ('concede', 'VB'), ('they', 'PPSS'), ('would', 'MD'), ('like', 'VB'), ('to', 'TO'), ('hit', 'VB'), ('60', 'CD'), (',', ','), ('they', 'PPSS'), ('stick', 'VB'), ('primarily', 'RB'), ('to', 'IN'), ('the', 'AT'), ('baseball', 'NN'), ("player's", 'NN$'), ('standard', 'JJ'), ('quote', 'NN'), (':', ':'), ('``', '``'), ('The', 'AT'), ('important', 'JJ'), ('thing', 'NN'), ('is', 'BEZ'), ('to', 'TO'), ('win', 'VB'), ('the', 'AT'), ('pennant', 'NN'), ("''", "''"), ('.', '.')]
# Tagged:   [('Although', 'CS'), ('both', 'ABX'), ('concede', None), ('they', 'PPSS'), ('would', 'MD'), ('like', 'VB'), ('to', 'TO'), ('hit', 'VB'), ('60', 'CD'), (',', ','), ('they', 'PPSS'), ('stick', 'VB'), ('primarily', None), ('to', 'TO'), ('the', 'AT'), ('baseball', 'NN'), ("player's", 'NN$'), ('standard', 'JJ'), ('quote', None), (':', ':'), ('``', '``'), ('The', 'AT'), ('important', 'JJ'), ('thing', 'NN'), ('is', 'BEZ'), ('to', 'TO'), ('win', 'VB'), ('the', 'AT'), ('pennant', 'NN'), ("''", "''"), ('.', '.')]
#
# Original: [('But', 'CC'), ('one', 'CD'), ('thing', 'NN'), ('is', 'BEZ'), ('for', 'IN'), ('certain', 'JJ'), (':', ':'), ('There', 'EX'), ('is', 'BEZ'), ('no', 'AT'), ('dissension', 'NN'), ('between', 'IN'), ('Mantle', 'NP'), (',', ','), ('the', 'AT'), ('American', 'JJ-TL'), ("League's", 'NN$-TL'), ('Most', 'QL-TL'), ('Valuable', 'JJ-TL'), ('Player', 'NN-TL'), ('in', 'IN'), ('1956', 'CD'), ('and', 'CC'), ('1957', 'CD'), (',', ','), ('and', 'CC'), ('Maris', 'NP'), (',', ','), ('the', 'AT'), ('MVP', 'NN'), ('in', 'IN'), ('1960', 'CD'), ('.', '.')]
# Tagged:   [('But', 'CC'), ('one', 'CD'), ('thing', 'NN'), ('is', 'BEZ'), ('for', 'IN'), ('certain', 'JJ'), (':', ':'), ('There', 'EX'), ('is', 'BEZ'), ('no', 'AT'), ('dissension', 'NN'), ('between', 'IN'), ('Mantle', 'NP'), (',', ','), ('the', 'AT'), ('American', 'JJ'), ("League's", 'NN$-TL'), ('Most', 'AP'), ('Valuable', None), ('Player', 'NP'), ('in', 'IN'), ('1956', 'CD'), ('and', 'CC'), ('1957', 'CD'), (',', ','), ('and', 'CC'), ('Maris', 'NP'), (',', ','), ('the', 'AT'), ('MVP', None), ('in', 'IN'), ('1960', 'CD'), ('.', '.')]
#
# Original: [('Each', 'DT'), ('enjoys', 'VBZ'), ('seeing', 'VBG'), ('the', 'AT'), ('other', 'AP'), ('hit', 'VB'), ('home', 'NN'), ('runs', 'NNS'), ('(', '('), ('``', '``'), ('I', 'PPSS'), ('hope', 'VB'), ('Roger', 'NP'), ('hits', 'VBZ'), ('80', 'CD'), ("''", "''"), (',', ','), ('Mantle', 'NP'), ('says', 'VBZ'), (')', ')'), (',', ','), ('and', 'CC'), ('each', 'DT'), ('enjoys', 'VBZ'), ('even', 'QL'), ('more', 'RBR'), ('seeing', 'VBG'), ('himself', 'PPL'), ('hit', 'VB'), ('home', 'NN'), ('runs', 'NNS'), ('(', '('), ('``', '``'), ('and', 'CC'), ('I', 'PPSS'), ('hope', 'VB'), ('I', 'PPSS'), ('hit', 'VB'), ('81', 'CD'), ("''", "''"), (')', ')'), ('.', '.')]
# Tagged:   [('Each', 'DT'), ('enjoys', None), ('seeing', None), ('the', 'AT'), ('other', 'AP'), ('hit', 'VB'), ('home', 'NR'), ('runs', 'NNS'), ('(', '('), ('``', '``'), ('I', 'PPSS'), ('hope', 'VB'), ('Roger', 'NP'), ('hits', 'NNS'), ('80', 'CD'), ("''", "''"), (',', ','), ('Mantle', 'NP'), ('says', 'VBZ'), (')', ')'), (',', ','), ('and', 'CC'), ('each', 'DT'), ('enjoys', None), ('even', 'RB'), ('more', 'RBR'), ('seeing', None), ('himself', 'PPL'), ('hit', 'VB'), ('home', 'NR'), ('runs', 'NNS'), ('(', '('), ('``', '``'), ('and', 'CC'), ('I', 'PPSS'), ('hope', 'VB'), ('I', 'PPSS'), ('hit', 'VB'), ('81', 'CD'), ("''", "''"), (')', ')'), ('.', '.')]
#
# Original: [('Mantle', 'NP'), (',', ','), ('Maris', 'NP'), (',', ','), ('and', 'CC'), ('Bob', 'NP'), ('Cerv', 'NP'), (',', ','), ('a', 'AT'), ('utility', 'NN'), ('outfielder', 'NN'), (',', ','), ('share', 'VB'), ('an', 'AT'), ('apartment', 'NN'), ('in', 'IN'), ('Jamaica', 'NP'), (',', ','), ('Long', 'JJ-TL'), ('Island', 'NN-TL'), (',', ','), ('not', '*'), ('far', 'RB'), ('from', 'IN'), ('New', 'JJ-TL'), ('York', 'NP-TL'), ('International', 'JJ-TL'), ('Airport', 'NN-TL'), ('.', '.')]
# Tagged:   [('Mantle', 'NP'), (',', ','), ('Maris', 'NP'), (',', ','), ('and', 'CC'), ('Bob', 'NP'), ('Cerv', None), (',', ','), ('a', 'AT'), ('utility', 'NN'), ('outfielder', 'NN'), (',', ','), ('share', 'NN'), ('an', 'AT'), ('apartment', 'NN'), ('in', 'IN'), ('Jamaica', 'NP'), (',', ','), ('Long', 'JJ-TL'), ('Island', 'NN-TL'), (',', ','), ('not', '*'), ('far', 'RB'), ('from', 'IN'), ('New', 'JJ-TL'), ('York', 'NP-TL'), ('International', 'JJ-TL'), ('Airport', None), ('.', '.')]
#
# Original: [('The', 'AT'), ('three', 'CD'), ('pay', 'VB'), ('$251', 'NNS'), ('a', 'AT'), ('month', 'NN'), ('for', 'IN'), ('four', 'CD'), ('rooms', 'NNS'), ('(', '('), ('kitchen', 'NN'), (',', ','), ('dining', 'VBG'), ('room', 'NN'), (',', ','), ('living', 'VBG'), ('room', 'NN'), (',', ','), ('and', 'CC'), ('bedroom', 'NN'), (')', ')'), (',', ','), ('with', 'IN'), ('air-conditioning', 'NN'), ('and', 'CC'), ('new', 'JJ'), ('modern', 'JJ'), ('furniture', 'NN'), ('.', '.')]
# Tagged:   [('The', 'AT'), ('three', 'CD'), ('pay', 'VB'), ('$251', None), ('a', 'AT'), ('month', 'NN'), ('for', 'IN'), ('four', 'CD'), ('rooms', 'NNS'), ('(', '('), ('kitchen', 'NN'), (',', ','), ('dining', 'VBG'), ('room', 'NN'), (',', ','), ('living', 'VBG'), ('room', 'NN'), (',', ','), ('and', 'CC'), ('bedroom', 'NN'), (')', ')'), (',', ','), ('with', 'IN'), ('air-conditioning', None), ('and', 'CC'), ('new', 'JJ'), ('modern', 'JJ'), ('furniture', 'NN'), ('.', '.')]
#
# Original: [('Mantle', 'NP'), ('and', 'CC'), ('Cerv', 'NP'), ('use', 'VB'), ('the', 'AT'), ('twin', 'NN'), ('beds', 'NNS'), ('in', 'IN'), ('the', 'AT'), ('bedroom', 'NN'), (';', '.'), (';', '.')]
# Tagged:   [('Mantle', 'NP'), ('and', 'CC'), ('Cerv', None), ('use', 'VB'), ('the', 'AT'), ('twin', 'NN'), ('beds', 'NNS'), ('in', 'IN'), ('the', 'AT'), ('bedroom', 'NN'), (';', '.'), (';', '.')]
#
# Original: [('Maris', 'NP'), ('sleeps', 'VBZ'), ('on', 'IN'), ('a', 'AT'), ('green', 'JJ'), ('studio', 'NN'), ('couch', 'NN'), ('in', 'IN'), ('the', 'AT'), ('living', 'VBG'), ('room', 'NN'), ('.', '.')]
# Tagged:   [('Maris', 'NP'), ('sleeps', None), ('on', 'IN'), ('a', 'AT'), ('green', 'NN'), ('studio', 'NN'), ('couch', None), ('in', 'IN'), ('the', 'AT'), ('living', 'VBG'), ('room', 'NN'), ('.', '.')]
#
# Original: [('They', 'PPSS'), ('divide', 'VB'), ('up', 'RP'), ('the', 'AT'), ('household', 'NN'), ('chores', 'NNS'), (':', ':'), ('Cerv', 'NP'), ('does', 'DOZ'), ('most', 'AP'), ('of', 'IN'), ('the', 'AT'), ('cooking', 'NN'), ('(', '('), ('breakfast', 'NN'), ('and', 'CC'), ('sandwich', 'NN'), ('snacks', 'NNS'), (',', ','), ('with', 'IN'), ('dinner', 'NN'), ('out', 'RP'), (')', ')'), (',', ','), ('Mantle', 'NP'), ('supplies', 'VBZ'), ('the', 'AT'), ('transportation', 'NN'), ('(', '('), ('a', 'AT'), ('white', 'JJ'), ('1961', 'CD'), ('Oldsmobile', 'NP'), ('convertible', 'NN'), (')', ')'), (',', ','), ('and', 'CC'), ('Maris', 'NP'), ('drives', 'VBZ'), ('the', 'AT'), ('25-minute', 'JJ'), ('course', 'NN'), ('from', 'IN'), ('the', 'AT'), ('apartment', 'NN'), ('house', 'NN'), ('to', 'IN'), ('Yankee', 'JJ-TL'), ('Stadium', 'NN-TL'), ('.', '.')]
# Tagged:   [('They', 'PPSS'), ('divide', None), ('up', 'RP'), ('the', 'AT'), ('household', 'NN'), ('chores', 'NNS'), (':', ':'), ('Cerv', None), ('does', 'DOZ'), ('most', 'QL'), ('of', 'IN'), ('the', 'AT'), ('cooking', None), ('(', '('), ('breakfast', None), ('and', 'CC'), ('sandwich', None), ('snacks', 'NNS'), (',', ','), ('with', 'IN'), ('dinner', 'NN'), ('out', 'RP'), (')', ')'), (',', ','), ('Mantle', 'NP'), ('supplies', 'NNS'), ('the', 'AT'), ('transportation', 'NN'), ('(', '('), ('a', 'AT'), ('white', 'JJ'), ('1961', 'CD'), ('Oldsmobile', None), ('convertible', 'JJ'), (')', ')'), (',', ','), ('and', 'CC'), ('Maris', 'NP'), ('drives', 'VBZ'), ('the', 'AT'), ('25-minute', None), ('course', 'NN'), ('from', 'IN'), ('the', 'AT'), ('apartment', 'NN'), ('house', 'NN'), ('to', 'TO'), ('Yankee', 'NP'), ('Stadium', 'NN-TL'), ('.', '.')]
#
# Original: [('Mantle', 'NP'), (',', ','), ('Maris', 'NP'), (',', ','), ('and', 'CC'), ('Cerv', 'NP'), ('probably', 'RB'), ('share', 'VB'), ('one', 'CD'), ('major-league', 'NN'), ('record', 'NN'), ('already', 'RB'), (':', ':'), ('Among', 'IN'), ('them', 'PPO'), (',', ','), ('they', 'PPSS'), ('have', 'HV'), ('fifteen', 'CD'), ('children', 'NNS'), ('--', '--'), ('eight', 'CD'), ('for', 'IN'), ('Cerv', 'NP'), (',', ','), ('four', 'CD'), ('for', 'IN'), ('Mantle', 'NP'), (',', ','), ('and', 'CC'), ('three', 'CD'), ('for', 'IN'), ('Maris', 'NP'), ('.', '.')]
# Tagged:   [('Mantle', 'NP'), (',', ','), ('Maris', 'NP'), (',', ','), ('and', 'CC'), ('Cerv', None), ('probably', 'RB'), ('share', 'NN'), ('one', 'CD'), ('major-league', 'NN'), ('record', 'NN'), ('already', 'RB'), (':', ':'), ('Among', 'IN'), ('them', 'PPO'), (',', ','), ('they', 'PPSS'), ('have', 'HV'), ('fifteen', 'CD'), ('children', 'NNS'), ('--', '--'), ('eight', 'CD'), ('for', 'IN'), ('Cerv', None), (',', ','), ('four', 'CD'), ('for', 'IN'), ('Mantle', 'NP'), (',', ','), ('and', 'CC'), ('three', 'CD'), ('for', 'IN'), ('Maris', 'NP'), ('.', '.')]
#
# Original: [('As', 'CS'), ('roommates', 'NNS'), (',', ','), ('teammates', 'NNS'), (',', ','), ('and', 'CC'), ('home-run', 'NN'), ('mates', 'NNS'), (',', ','), ('Mantle', 'NP'), (',', ','), ('29', 'CD'), (',', ','), ('who', 'WPS'), ('broke', 'VBD'), ('in', 'RP'), ('with', 'IN'), ('the', 'AT'), ('Yankees', 'NPS'), ('ten', 'CD'), ('years', 'NNS'), ('ago', 'RB'), (',', ','), ('and', 'CC'), ('Maris', 'NP'), (',', ','), ('26', 'CD'), (',', ','), ('who', 'WPS'), ('came', 'VBD'), ('to', 'IN'), ('the', 'AT'), ('Yankees', 'NPS'), ('from', 'IN'), ('Kansas', 'NP'), ('City', 'NN-TL'), ('two', 'CD'), ('years', 'NNS'), ('ago', 'RB'), (',', ','), ('have', 'HV'), ('strikingly', 'QL'), ('similar', 'JJ'), ('backgrounds', 'NNS'), ('.', '.')]
# Tagged:   [('As', 'CS'), ('roommates', None), (',', ','), ('teammates', 'NNS'), (',', ','), ('and', 'CC'), ('home-run', 'NN'), ('mates', 'NNS'), (',', ','), ('Mantle', 'NP'), (',', ','), ('29', 'CD'), (',', ','), ('who', 'WPS'), ('broke', 'VBD'), ('in', 'IN'), ('with', 'IN'), ('the', 'AT'), ('Yankees', 'NPS'), ('ten', 'CD'), ('years', 'NNS'), ('ago', 'RB'), (',', ','), ('and', 'CC'), ('Maris', 'NP'), (',', ','), ('26', 'CD'), (',', ','), ('who', 'WPS'), ('came', 'VBD'), ('to', 'TO'), ('the', 'AT'), ('Yankees', 'NPS'), ('from', 'IN'), ('Kansas', 'NP'), ('City', 'NN-TL'), ('two', 'CD'), ('years', 'NNS'), ('ago', 'RB'), (',', ','), ('have', 'HV'), ('strikingly', None), ('similar', 'JJ'), ('backgrounds', None), ('.', '.')]
#
# Original: [('Both', 'ABX'), ('were', 'BED'), ('scholastic', 'JJ'), ('stars', 'NNS'), ('in', 'IN'), ('football', 'NN'), (',', ','), ('basketball', 'NN'), (',', ','), ('and', 'CC'), ('baseball', 'NN'), ('(', '('), ('Mantle', 'NP'), ('in', 'IN'), ('Commerce', 'NN-TL'), (',', ','), ('Okla.', 'NP'), (',', ','), ('Maris', 'NP'), ('in', 'IN'), ('Fargo', 'NP'), (',', ','), ('N.D.', 'NP'), (')', ')'), (';', '.'), (';', '.')]
# Tagged:   [('Both', 'ABX'), ('were', 'BED'), ('scholastic', 'JJ'), ('stars', None), ('in', 'IN'), ('football', 'NN'), (',', ','), ('basketball', 'NN'), (',', ','), ('and', 'CC'), ('baseball', 'NN'), ('(', '('), ('Mantle', 'NP'), ('in', 'IN'), ('Commerce', 'NN-TL'), (',', ','), ('Okla.', 'NP'), (',', ','), ('Maris', 'NP'), ('in', 'IN'), ('Fargo', None), (',', ','), ('N.D.', None), (')', ')'), (';', '.'), (';', '.')]
#
# Original: [('as', 'CS'), ('halfbacks', 'NNS'), (',', ','), ('both', 'ABX'), ('came', 'VBD'), ('close', 'RB'), ('to', 'IN'), ('playing', 'VBG'), ('football', 'NN'), ('at', 'IN'), ('the', 'AT'), ('University', 'NN-TL'), ('of', 'IN-TL'), ('Oklahoma', 'NP-TL'), ('(', '('), ('``', '``'), ('Sometimes', 'RB'), ('in', 'IN'), ('the', 'AT'), ('minors', 'NNS'), ("''", "''"), (',', ','), ('Maris', 'NP'), ('recalls', 'VBZ'), (',', ','), ('``', '``'), ('I', 'PPSS'), ('wished', 'VBD'), ('I', 'PPSS'), ('had', 'HVD'), ('gone', 'VBN'), ('to', 'IN'), ('Oklahoma', 'NP'), ("''", "''"), (')', ')'), ('.', '.')]
# Tagged:   [('as', 'CS'), ('halfbacks', None), (',', ','), ('both', 'ABX'), ('came', 'VBD'), ('close', 'JJ'), ('to', 'TO'), ('playing', 'VBG'), ('football', 'NN'), ('at', 'IN'), ('the', 'AT'), ('University', 'NN-TL'), ('of', 'IN-TL'), ('Oklahoma', 'NP-TL'), ('(', '(-HL'), ('``', '``'), ('Sometimes', 'RB'), ('in', 'IN'), ('the', 'AT'), ('minors', None), ("''", "''"), (',', ','), ('Maris', 'NP'), ('recalls', None), (',', ','), ('``', '``'), ('I', 'PPSS'), ('wished', None), ('I', 'PPSS'), ('had', 'HVD'), ('gone', 'VBN'), ('to', 'TO'), ('Oklahoma', 'NP'), ("''", "''"), (')', ')'), ('.', '.')]
#
# Original: [('To', 'IN'), ('an', 'AT'), ('extent', 'NN'), (',', ','), ('the', 'AT'), ('two', 'CD'), ('even', 'RB'), ('look', 'VB'), ('alike', 'RB'), ('.', '.')]
# Tagged:   [('To', 'TO'), ('an', 'AT'), ('extent', None), (',', ','), ('the', 'AT'), ('two', 'CD'), ('even', 'RB'), ('look', 'VB'), ('alike', None), ('.', '.')]
#
# Original: [('Both', 'ABX'), ('have', 'HV'), ('blue', 'JJ'), ('eyes', 'NNS'), ('and', 'CC'), ('short', 'RB'), ('blond', 'JJ'), ('hair', 'NN'), ('.', '.')]
# Tagged:   [('Both', 'ABX'), ('have', 'HV'), ('blue', 'JJ'), ('eyes', 'NNS'), ('and', 'CC'), ('short', 'JJ'), ('blond', 'JJ'), ('hair', None), ('.', '.')]
#
# Original: [('Both', 'ABX'), ('are', 'BER'), ('6', 'CD'), ('feet', 'NNS'), ('tall', 'JJ'), ('and', 'CC'), ('weigh', 'VB'), ('between', 'IN'), ('195', 'CD'), ('and', 'CC'), ('200', 'CD'), ('pounds', 'NNS'), (',', ','), ('but', 'CC'), ('Mantle', 'NP'), (',', ','), ('incredibly', 'QL'), ('muscular', 'JJ'), ('(', '('), ('he', 'PPS'), ('has', 'HVZ'), ('a', 'AT'), ('17-1/2-inch', 'JJ'), ('neck', 'NN'), (')', ')'), (',', ','), ('looks', 'VBZ'), ('bigger', 'JJR'), ('.', '.')]
# Tagged:   [('Both', 'ABX'), ('are', 'BER'), ('6', 'CD'), ('feet', 'NNS'), ('tall', 'JJ'), ('and', 'CC'), ('weigh', None), ('between', 'IN'), ('195', 'CD'), ('and', 'CC'), ('200', 'CD'), ('pounds', 'NNS'), (',', ','), ('but', 'CC'), ('Mantle', 'NP'), (',', ','), ('incredibly', None), ('muscular', 'JJ'), ('(', '('), ('he', 'PPS'), ('has', 'HVZ'), ('a', 'AT'), ('17-1/2-inch', None), ('neck', 'NN'), (')', ')'), (',', ','), ('looks', 'VBZ'), ('bigger', 'JJR'), ('.', '.')]
#
# Original: [('With', 'IN'), ('their', 'PP$'), ('huge', 'JJ'), ('backs', 'NNS'), ('and', 'CC'), ('overdeveloped', 'VBN'), ('shoulders', 'NNS'), (',', ','), ('both', 'ABX'), ('must', 'MD'), ('have', 'HV'), ('their', 'PP$'), ('clothes', 'NNS'), ('made', 'VBN'), ('to', 'IN'), ('order', 'NN'), ('.', '.')]
# Tagged:   [('With', 'IN'), ('their', 'PP$'), ('huge', 'JJ'), ('backs', None), ('and', 'CC'), ('overdeveloped', None), ('shoulders', None), (',', ','), ('both', 'ABX'), ('must', 'MD'), ('have', 'HV'), ('their', 'PP$'), ('clothes', 'NNS'), ('made', 'VBN'), ('to', 'TO'), ('order', 'NN'), ('.', '.')]
#
# Original: [('Maris', 'NP'), ('purchases', 'VBZ'), ('$100', 'NNS'), ('suits', 'NNS'), ('from', 'IN'), ("Simpson's", 'NP$'), ('in', 'IN'), ('New', 'JJ-TL'), ('York', 'NP-TL'), ('.', '.')]
# Tagged:   [('Maris', 'NP'), ('purchases', None), ('$100', 'NNS'), ('suits', 'NNS'), ('from', 'IN'), ("Simpson's", None), ('in', 'IN'), ('New', 'JJ-TL'), ('York', 'NP-TL'), ('.', '.')]
#
# Original: [('Light', 'JJ-HL'), ('reading', 'NN-HL'), (':', ':-HL')]
# Tagged:   [('Light', None), ('reading', 'VBG'), (':', ':')]
#
# Original: [('Neither', 'CC'), ('Mantle', 'NP'), ('nor', 'CC'), ('Maris', 'NP'), ('need', 'MD'), ('fear', 'VB'), ('being', 'BEG'), ('classified', 'VBN'), ('an', 'AT'), ('intellectual', 'NN'), (',', ','), ('but', 'CC'), ('lately', 'RB'), ('Mantle', 'NP'), ('has', 'HVZ'), ('shown', 'VBN'), ('unusual', 'JJ'), ('devotion', 'NN'), ('to', 'IN'), ('an', 'AT'), ('intellectual', 'JJ'), ('opus', 'NN'), (',', ','), ('Henry', 'NP'), ("Miller's", 'NP$'), ('``', '``'), ('Tropic', 'NN-TL'), ('of', 'IN-TL'), ('Cancer', 'NP-TL'), ("''", "''"), ('.', '.')]
# Tagged:   [('Neither', 'DTX'), ('Mantle', 'NP'), ('nor', 'CC'), ('Maris', 'NP'), ('need', 'NN'), ('fear', 'VB'), ('being', 'BEG'), ('classified', None), ('an', 'AT'), ('intellectual', 'JJ'), (',', ','), ('but', 'CC'), ('lately', 'RB'), ('Mantle', 'NP'), ('has', 'HVZ'), ('shown', 'VBN'), ('unusual', 'JJ'), ('devotion', 'NN'), ('to', 'TO'), ('an', 'AT'), ('intellectual', 'JJ'), ('opus', None), (',', ','), ('Henry', 'NP'), ("Miller's", None), ('``', '``'), ('Tropic', None), ('of', 'IN'), ('Cancer', 'NN-TL'), ("''", "''"), ('.', '.')]
#
# Original: [('Mantle', 'NP'), ('so', 'RB'), ('appreciated', 'VBD'), ("Miller's", 'NP$'), ('delicate', 'JJ'), ('literary', 'JJ'), ('style', 'NN'), ('that', 'CS'), ('he', 'PPS'), ('broadened', 'VBD'), ("teammates'", 'NNS$'), ('minds', 'NNS'), ('by', 'IN'), ('reading', 'VBG'), ('sensitive', 'JJ'), ('passages', 'NNS'), ('aloud', 'RB'), ('during', 'IN'), ('road', 'NN'), ('trips', 'NNS'), ('.', '.')]
# Tagged:   [('Mantle', 'NP'), ('so', 'CS'), ('appreciated', 'VBD'), ("Miller's", None), ('delicate', 'JJ'), ('literary', None), ('style', 'NN'), ('that', 'CS'), ('he', 'PPS'), ('broadened', None), ("teammates'", None), ('minds', None), ('by', 'IN'), ('reading', 'VBG'), ('sensitive', 'JJ'), ('passages', None), ('aloud', None), ('during', 'IN'), ('road', 'NN'), ('trips', 'NNS'), ('.', '.')]
#
# Original: [('A', 'AT'), ('reporter', 'NN'), ('asked', 'VBD'), ('Maris', 'NP'), ('recently', 'RB'), ('.', '.')]
# Tagged:   [('A', 'AT'), ('reporter', None), ('asked', 'VBD'), ('Maris', 'NP'), ('recently', 'RB'), ('.', '.')]
#
# Original: [('This', 'DT'), ('is', 'BEZ'), ('no', 'AT'), ('surprising', 'JJ'), ('trait', 'NN'), ('for', 'IN'), ('a', 'AT'), ('ballplayer', 'NN'), ('.', '.')]
# Tagged:   [('This', 'DT'), ('is', 'BEZ'), ('no', 'AT'), ('surprising', None), ('trait', None), ('for', 'IN'), ('a', 'AT'), ('ballplayer', None), ('.', '.')]
#
# Original: [('What', 'WDT'), ('is', 'BEZ'), ('surprising', 'VBG'), ('and', 'CC'), ('pleasant', 'NN'), ('is', 'BEZ'), ('that', 'CS'), ('Mantle', 'NP'), ('and', 'CC'), ('Maris', 'NP'), (',', ','), ('under', 'IN'), ('constant', 'JJ'), ('pressure', 'NN'), ('from', 'IN'), ('writers', 'NNS'), ('and', 'CC'), ('photographers', 'NNS'), (',', ','), ('are', 'BER'), ('trying', 'VBG'), ('to', 'TO'), ('be', 'BE'), ('cooperative', 'JJ'), ('.', '.')]
# Tagged:   [('What', 'WDT'), ('is', 'BEZ'), ('surprising', None), ('and', 'CC'), ('pleasant', None), ('is', 'BEZ'), ('that', 'CS'), ('Mantle', 'NP'), ('and', 'CC'), ('Maris', 'NP'), (',', ','), ('under', 'IN'), ('constant', 'JJ'), ('pressure', 'NN'), ('from', 'IN'), ('writers', 'NNS'), ('and', 'CC'), ('photographers', None), (',', ','), ('are', 'BER'), ('trying', 'VBG'), ('to', 'TO'), ('be', 'BE'), ('cooperative', None), ('.', '.')]
#
# Original: [('But', 'CC'), ('last', 'AP'), ('week', 'NN'), (',', ','), ('when', 'WRB'), ('a', 'AT'), ('reporter', 'NN'), ('was', 'BEDZ'), ('standing', 'VBG'), ('near', 'IN'), ("Mantle's", 'NP$'), ('locker', 'NN'), (',', ','), ('Mickey', 'NP'), ('walked', 'VBD'), ('up', 'RP'), ('and', 'CC'), ('volunteered', 'VBD'), ('an', 'AT'), ('anecdote', 'NN'), ('.', '.')]
# Tagged:   [('But', 'CC'), ('last', 'AP'), ('week', 'NN'), (',', ','), ('when', 'WRB'), ('a', 'AT'), ('reporter', None), ('was', 'BEDZ'), ('standing', 'VBG'), ('near', 'IN'), ("Mantle's", 'NP$'), ('locker', None), (',', ','), ('Mickey', 'NP'), ('walked', 'VBD'), ('up', 'RP'), ('and', 'CC'), ('volunteered', None), ('an', 'AT'), ('anecdote', None), ('.', '.')]
#
# Original: [('He', 'PPS'), ('said', 'VBD'), (',', ','), ('pointing', 'VBG'), ('to', 'IN'), ('a', 'AT'), ('dark-haired', 'JJ'), ('11-year-old', 'JJ'), ('boy', 'NN'), ('.', '.')]
# Tagged:   [('He', 'PPS'), ('said', 'VBD'), (',', ','), ('pointing', 'VBG'), ('to', 'TO'), ('a', 'AT'), ('dark-haired', None), ('11-year-old', None), ('boy', 'NN'), ('.', '.')]
#
# Original: [('``', '``'), ("That's", 'DT+BEZ'), ('(', '('), ('Yogi', 'NP'), (')', ')'), ("Berra's", 'NP$'), ('.', '.')]
# Tagged:   [('``', '``'), ("That's", 'DT+BEZ'), ('(', '('), ('Yogi', 'NP'), (')', ')'), ("Berra's", None), ('.', '.')]
#
# Original: [('I', 'PPSS'), ('came', 'VBD'), ('back', 'RB'), (',', ','), ('sitting', 'VBG'), ('by', 'IN'), ('my', 'PP$'), ('locker', 'NN'), (',', ','), ('feeling', 'VBG'), ('real', 'QL'), ('low', 'JJ'), (',', ','), ('and', 'CC'), ('the', 'AT'), ('kid', 'NN'), ('walks', 'VBZ'), ('over', 'RP'), ('to', 'IN'), ('me', 'PPO'), (',', ','), ('looks', 'VBZ'), ('up', 'RP'), (',', ','), ('and', 'CC'), ('says', 'VBZ'), (':', ':'), ("'", "'"), ('You', 'PPSS'), ('stunk', 'VBD'), ("'", "'"), ("''", "''"), ('.', '.')]
# Tagged:   [('I', 'PPSS'), ('came', 'VBD'), ('back', 'RB'), (',', ','), ('sitting', 'VBG'), ('by', 'IN'), ('my', 'PP$'), ('locker', None), (',', ','), ('feeling', 'NN'), ('real', 'JJ'), ('low', 'RB'), (',', ','), ('and', 'CC'), ('the', 'AT'), ('kid', 'NN'), ('walks', 'VBZ'), ('over', 'IN'), ('to', 'IN'), ('me', 'PPO'), (',', ','), ('looks', 'VBZ'), ('up', 'RP'), (',', ','), ('and', 'CC'), ('says', 'VBZ'), (':', ':'), ("'", "'"), ('You', 'PPSS'), ('stunk', None), ("'", "'"), ("''", "''"), ('.', '.')]
#
# Original: [('Maris', 'NP'), (',', ','), ('in', 'IN'), ('talking', 'VBG'), ('to', 'IN'), ('reporters', 'NNS'), (',', ','), ('tries', 'VBZ'), ('to', 'TO'), ('answer', 'VB'), ('all', 'ABN'), ('questions', 'NNS'), ('candidly', 'RB'), ('and', 'CC'), ('fully', 'RB'), (',', ','), ('but', 'CC'), ('on', 'IN'), ('rare', 'JJ'), ('occasions', 'NNS'), (',', ','), ('he', 'PPS'), ('shuns', 'VBZ'), ('newsmen', 'NNS'), ('.', '.')]
# Tagged:   [('Maris', 'NP'), (',', ','), ('in', 'IN'), ('talking', 'VBG'), ('to', 'TO'), ('reporters', 'NNS'), (',', ','), ('tries', 'NNS'), ('to', 'TO'), ('answer', 'VB'), ('all', 'ABN'), ('questions', 'NNS'), ('candidly', None), ('and', 'CC'), ('fully', 'RB'), (',', ','), ('but', 'CC'), ('on', 'IN'), ('rare', 'JJ'), ('occasions', None), (',', ','), ('he', 'PPS'), ('shuns', None), ('newsmen', 'NNS'), ('.', '.')]
#
# Original: [('``', '``'), ('When', 'WRB'), ("I've", 'PPSS+HV'), ('made', 'VBN'), ('a', 'AT'), ('dumb', 'JJ'), ('play', 'NN'), ("''", "''"), (',', ','), ('he', 'PPS'), ('says', 'VBZ'), (',', ','), ('``', '``'), ('I', 'PPSS'), ("don't", 'DO*'), ('want', 'VB'), ('to', 'TO'), ('talk', 'VB'), ('to', 'IN'), ('anyone', 'PN'), ('.', '.')]
# Tagged:   [('``', '``'), ('When', 'WRB'), ("I've", 'PPSS+HV'), ('made', 'VBN'), ('a', 'AT'), ('dumb', None), ('play', 'VB'), ("''", "''"), (',', ','), ('he', 'PPS'), ('says', 'VBZ'), (',', ','), ('``', '``'), ('I', 'PPSS'), ("don't", 'DO*'), ('want', 'VB'), ('to', 'TO'), ('talk', 'VB'), ('to', 'TO'), ('anyone', 'PN'), ('.', '.')]
#
# Original: [("I'm", 'PPSS+BEM'), ('angry', 'JJ'), ("''", "''"), ('.', '.')]
# Tagged:   [("I'm", 'PPSS+BEM'), ('angry', None), ("''", "''"), ('.', '.')]
#
# Original: [('By', 'IN'), ('his', 'PP$'), ('own', 'JJ'), ('confession', 'NN'), (',', ','), ('Maris', 'NP'), ('is', 'BEZ'), ('an', 'AT'), ('angry', 'JJ'), ('young', 'JJ'), ('man', 'NN'), ('.', '.')]
# Tagged:   [('By', 'IN'), ('his', 'PP$'), ('own', 'JJ'), ('confession', 'NN'), (',', ','), ('Maris', 'NP'), ('is', 'BEZ'), ('an', 'AT'), ('angry', None), ('young', 'JJ'), ('man', 'NN'), ('.', '.')]
#
# Original: [('Benched', 'VBN'), ('at', 'IN'), ('Tulsa', 'NP'), ('in', 'IN'), ('1955', 'CD'), (',', ','), ('he', 'PPS'), ('told', 'VBD'), ('manager', 'NN'), ('Dutch', 'NP'), ('Meyer', 'NP'), (':', ':'), ('``', '``'), ('I', 'PPSS'), ("can't", 'MD*'), ('play', 'VB'), ('for', 'IN'), ('you', 'PPO'), ('.', '.')]
# Tagged:   [('Benched', None), ('at', 'IN'), ('Tulsa', None), ('in', 'IN'), ('1955', 'CD'), (',', ','), ('he', 'PPS'), ('told', 'VBD'), ('manager', 'NN'), ('Dutch', None), ('Meyer', 'NP'), (':', ':'), ('``', '``'), ('I', 'PPSS'), ("can't", 'MD*'), ('play', 'VB'), ('for', 'IN'), ('you', 'PPO'), ('.', '.')]
#
# Original: [('Send', 'VB'), ('me', 'PPO'), ('where', 'WRB'), ('I', 'PPSS'), ('can', 'MD'), ('play', 'VB'), ("''", "''"), ('.', '.')]
# Tagged:   [('Send', None), ('me', 'PPO'), ('where', 'WRB'), ('I', 'PPSS'), ('can', 'MD'), ('play', 'VB'), ("''", "''"), ('.', '.')]
#
# Original: [('(', '('), ('Meyer', 'NP'), ('sent', 'VBD'), ('him', 'PPO'), ('to', 'IN'), ('Reading', 'NP'), (',', ','), ('Pa.', 'NP'), ('.', '.')]
# Tagged:   [('(', '('), ('Meyer', 'NP'), ('sent', 'VBD'), ('him', 'PPO'), ('to', 'TO'), ('Reading', None), (',', ','), ('Pa.', 'NP'), ('.', '.')]

# %% [markdown]
# 30. Preprocess the Brown News data by replacing low-frequency words with UNK,
# but leaving the tags untouched. Now train and evaluate a bigram tagger on this
# data. How much does this help? What is the contribution of the unigram tagger
# and default tagger now?

# %%
import nltk
from nltk.corpus import brown
from nltk.probability import FreqDist
from nltk.tag import BigramTagger, UnigramTagger, DefaultTagger

# Step 1: Load the Brown corpus (News category)
brown_tagged_sents = brown.tagged_sents(categories='news')

# Step 2: Identify low-frequency words
word_freq = FreqDist(word.lower() for sent in brown_tagged_sents for word, tag in sent)
low_freq_threshold = 3  # Set a threshold for low-frequency words
low_freq_words = {word for word in word_freq if word_freq[word] < low_freq_threshold}

# Step 3: Replace low-frequency words with "UNK"
def replace_low_freq_words(tagged_sent, low_freq_words):
    return [(word if word.lower() not in low_freq_words else 'UNK', tag) for word, tag in tagged_sent]

brown_tagged_sents_unk = [replace_low_freq_words(sent, low_freq_words) for sent in brown_tagged_sents]

# Step 4: Split data into training and testing sets
train_sents = brown_tagged_sents_unk[:4000]
test_sents = brown_tagged_sents_unk[4000:4050]

# Step 5: Train taggers
default_tagger = DefaultTagger('NN')
unigram_tagger = UnigramTagger(train_sents, backoff=default_tagger)
bigram_tagger = BigramTagger(train_sents, backoff=unigram_tagger)

# Step 6: Evaluate the tagger
accuracy = bigram_tagger.evaluate(test_sents)
print(f"Bigram Tagger Accuracy with UNK: {accuracy:.4f}")
# Out:
# Bigram Tagger Accuracy with UNK: 0.8538
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9716\2145881456.py:30: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   accuracy = bigram_tagger.evaluate(test_sents)

# %% [markdown]
# 32. Consult the documentation for the Brill tagger demo function, using
# help(nltk.tag.brill.demo). Experiment with the tagger by setting different values
# for the parameters. Is there any trade-off between training time (corpus size) and
# performance?

# %%
import nltk
from nltk.tag import UnigramTagger, BigramTagger, brill, brill_trainer
from nltk.corpus import brown

# Load the Brown corpus (a subset for demonstration purposes)
train_sents = brown.tagged_sents(categories='news')[:2000]
test_sents = brown.tagged_sents(categories='news')[2000:2050]

# Train a backoff tagger (Unigram + Bigram)
unigram_tagger = UnigramTagger(train_sents)
bigram_tagger = BigramTagger(train_sents, backoff=unigram_tagger)

# Set up templates for the Brill tagger
templates = brill.fntbl37()

# Train the Brill tagger
trainer = brill_trainer.BrillTaggerTrainer(initial_tagger=bigram_tagger, templates=templates)
brill_tagger = trainer.train(train_sents, max_rules=200, min_score=2, min_acc=0.7)

# Evaluate the Brill tagger
accuracy = brill_tagger.evaluate(test_sents)
print(f"Brill Tagger Accuracy: {accuracy:.4f}")
# Out:
# Brill Tagger Accuracy: 0.7455
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9716\1971685602.py:21: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   accuracy = brill_tagger.evaluate(test_sents)

# %% [markdown]
# 33. Write code that builds a dictionary of dictionaries of sets. Use it to store the set
# of POS tags that can follow a given word having a given POS tag, i.e., wordi → tagi →
# tagi+1.

# %%
import nltk
from nltk.corpus import brown
from collections import defaultdict

# Ensure you have the Brown corpus
nltk.download('brown')

def build_pos_tag_dict(tagged_sents):
    """
    Build a dictionary of dictionaries of sets to store the POS tags that can follow
    a given word with a given POS tag.

    :param tagged_sents: List of tagged sentences
    :return: Dictionary of dictionaries of sets
    """
    pos_tag_dict = defaultdict(lambda: defaultdict(set))

    # Iterate over each sentence in the tagged corpus
    for sent in tagged_sents:
        # Iterate over each word and its tag in the sentence
        for i in range(len(sent) - 1):
            word1, tag1 = sent[i]
            word2, tag2 = sent[i + 1]
            pos_tag_dict[word1][tag1].add(tag2)

    return pos_tag_dict

# Load the Brown corpus tagged sentences
tagged_sents = brown.tagged_sents(categories='news')

# Build the dictionary
pos_tag_dict = build_pos_tag_dict(tagged_sents)

# Print some examples to verify
for word in list(pos_tag_dict.keys())[:5]:  # Just print the first 5 words for brevity
    print(f"Word: {word}")
    for tag in pos_tag_dict[word]:
        print(f"  Tag: {tag} -> Follows Tags: {pos_tag_dict[word][tag]}")
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# Word: The
#   Tag: AT -> Follows Tags: {'NP-TL', 'NPS', 'VBN-TL', 'JJ', 'CD', '``', 'NN', 'QL', 'NNS', 'NNS-TL', 'JJS', 'RB', 'NN-TL', 'NPS$', 'JJT', 'NN$-TL', 'NN$', 'NNS$', 'OD', 'VBG', 'VBN', 'AP', 'JJR', 'JJ-TL', 'NP', 'OD-TL', 'FW-JJ-TL', 'RB-TL', 'VBG-TL'}
#   Tag: AT-TL -> Follows Tags: {'NN-TL', 'NP-TL', 'NR-TL', 'JJ-TL', 'AP-TL', 'NN$-TL', 'NN', 'NP', 'NNS-TL'}
#   Tag: AT-HL -> Follows Tags: {'NP-HL', 'NN-HL'}
# Word: Fulton
#   Tag: NP-TL -> Follows Tags: {'NN-TL', 'JJ-TL'}
#   Tag: NP -> Follows Tags: {'NNS', 'NN$'}
# Word: County
#   Tag: NN-TL -> Follows Tags: {'NN-TL', 'NP-TL', ',', 'JJ', '.', 'JJ-TL', 'MD', 'VBD', 'NN', 'HVZ', 'VBG', 'CC', 'NNS', 'BEZ', 'NNS-TL', 'IN', 'RB', 'HV'}
# Word: Grand
#   Tag: JJ-TL -> Follows Tags: {'NN-TL', 'NNS-TL'}
#   Tag: FW-JJ-TL -> Follows Tags: {'FW-NN-TL'}
# Word: Jury
#   Tag: NN-TL -> Follows Tags: {'VBD', 'NNS'}

# %% [markdown]
# 34. There are 264 distinct words in the Brown Corpus having exactly three possible
# tags.
#
# a. Print a table with the integers 1..10 in one column, and the number of distinct
# words in the corpus having 1..10 distinct tags in the other column.
#
# b. For the word with the greatest number of distinct tags, print out sentences
# from the corpus containing the word, one for each possible tag.

# %%
import nltk
from nltk.corpus import brown
from collections import defaultdict

# Ensure you have the Brown corpus
nltk.download('brown')

def count_distinct_tags(tagged_sents):
    """
    Count distinct POS tags for each word and summarize counts for different numbers of distinct tags.

    :param tagged_sents: List of tagged sentences
    :return: A dictionary mapping number of distinct tags to count of words
    """
    word_tags = defaultdict(set)

    # Iterate over each sentence in the tagged corpus
    for sent in tagged_sents:
        # Iterate over each word and its tag in the sentence
        for word, tag in sent:
            word_tags[word].add(tag)

    # Count how many words have exactly n distinct tags
    tag_counts = defaultdict(int)
    for tags in word_tags.values():
        tag_counts[len(tags)] += 1

    return tag_counts, word_tags

def find_word_with_max_tags(word_tags):
    """
    Find the word with the maximum number of distinct tags.

    :param word_tags: Dictionary mapping words to their distinct tags
    :return: Word with the maximum number of distinct tags
    """
    max_word = max(word_tags, key=lambda w: len(word_tags[w]))
    return max_word

def print_sentences_for_word(word, tagged_sents):
    """
    Print sentences from the corpus containing the word for each of its possible tags.

    :param word: The word to find in the sentences
    :param tagged_sents: List of tagged sentences
    """
    tags_for_word = set()
    sentences_with_word = defaultdict(list)

    # Collect sentences containing the word and their tags
    for sent in tagged_sents:
        if any(w == word for w, _ in sent):
            for w, tag in sent:
                if w == word:
                    tags_for_word.add(tag)
                    sentences_with_word[tag].append(sent)

    # Print sentences for each tag
    for tag in tags_for_word:
        print(f"Tag: {tag}")
        for sent in sentences_with_word[tag]:
            print(' '.join([w for w, t in sent]))
        print()

# Load the Brown corpus tagged sentences
tagged_sents = brown.tagged_sents(categories='news')

# Count distinct tags and get the mapping
tag_counts, word_tags = count_distinct_tags(tagged_sents)

# Print the table for integers 1..10
print("Number of Distinct Tags | Count of Words")
for i in range(1, 11):
    print(f"{i:22} | {tag_counts.get(i, 0)}")

# Get the word with the maximum number of distinct tags
max_word = find_word_with_max_tags(word_tags)

# Print sentences for the word with the maximum number of distinct tags
print(f"Word with the greatest number of distinct tags: {max_word}")
print_sentences_for_word(max_word, tagged_sents)
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# Number of Distinct Tags | Count of Words
#                      1 | 12671
#                      2 | 1478
#                      3 | 204
#                      4 | 32
#                      5 | 8
#                      6 | 1
#                      7 | 0
#                      8 | 0
#                      9 | 0
#                     10 | 0
# Word with the greatest number of distinct tags: to
# Tag: NPS
# Also noted are the marriages of Elizabeth Browning , daughter of the George L. Brownings , to Austin C. Smith Jr. ; ;
#
# Tag: TO-HL
# Three groups to meet
# ' know enough to sue '
# Refuses to grant bail
# ' had to know peddlers '
# ' intend to attend '
# Nothing to fear
#
# Tag: TO
# The September-October term jury had been charged by Fulton Superior Court Judge Durwood Pye to investigate reports of possible `` irregularities '' in the hard-fought primary which was won by Mayor-nominate Ivan Allen Jr. .
# It recommended that Fulton legislators act `` to have these laws studied and revised to the end of modernizing and improving them '' .
# However , the jury said it believes `` these two offices should be combined to achieve greater efficiency and reduce the cost of administration '' .
# It urged that the city `` take steps to remedy '' this problem .
# `` This is one of the major items in the Fulton County general assistance program '' , the jury said , but the State Welfare Department `` has seen fit to distribute these funds through the welfare departments of all the counties in the state with the exception of Fulton County , which receives none of this money .
# `` Failure to do this will continue to place a disproportionate burden '' on Fulton taxpayers .
# `` Failure to do this will continue to place a disproportionate burden '' on Fulton taxpayers .
# `` These actions should serve to protect in fact and in effect the court's wards from undue costs and its appointed and elected servants from unmeritorious criticisms '' , the jury said .
# Fulton legislators `` work with city officials to pass enabling legislation that will permit the establishment of a fair and equitable '' pension plan for city employes .
# Georgia Republicans are getting strong encouragement to enter a candidate in the 1962 governor's race , a top official said Wednesday .
# State Party Chairman James W. Dorsey added that enthusiasm was picking up for a state rally to be held Sept. 8 in Savannah at which newly elected Texas Sen. John Tower will be the featured speaker .
# Under this law annual grants are given to systems in substantial amounts .
# A small library may cherish its independence and established ways , and resist joining in a cooperative movement that sometimes seems radical to older members of the board .
# All services are given without cost to members .
# So obvious are these advantages that nearly 95 per cent of the population of New York State now has access to a system , and enthusiastic librarians foresee the day , not too distant , when all the libraries in the state will belong to a co-op .
# So obvious are these advantages that nearly 95 per cent of the population of New York State now has access to a system , and enthusiastic librarians foresee the day , not too distant , when all the libraries in the state will belong to a co-op .
# Each system develops differently , according to the area it serves , but the universal goal is to pool the resources of a given area for maximum efficiency .
# The basic state grant is thirty cents for each person served , and there is a further book incentive grant that provides an extra twenty cents up to fifty cents per capita , if a library spends a certain number of dollars .
# On microfilm , headquarters also has a file of the New York Times from its founding in 1851 to the present day , as well as bound volumes of important periodicals .
# The entire headquarters collection is available to the patrons of all members on interlibrary loans .
# It is connected by teletype with the State Library in Albany , which will supply any book to a system that the system itself cannot provide .
# The books are carried around by truck in canvas bags from headquarters to the other libraries .
# Public libraries in Nassau County have been lending books to each other by mail for a quarter-century , but the system enables this process to operate on an organized and far more comprehensive basis .
# Local libraries find , too , that the new plan saves tax dollars because books can be bought through the system , and since the system buys in bulk it is able to obtain larger discounts than would be available to an individual library .
# The system passes on these savings to its members .
# Schools and community groups turn to the headquarters film library for documentary , art , and experimental films to show at libraries that sponsor local programs , and to organizations in member communities .
# Schools and community groups turn to the headquarters film library for documentary , art , and experimental films to show at libraries that sponsor local programs , and to organizations in member communities .
# In addition to the interlibrary loan service and the children's program , headquarters has a public relations director who seeks to get wider grassroots support for quality library service in the county ; ;
# and it publishes Sum And Substance , a monthly newsletter , which reports the system's activities to the staffs and trustees of member libraries .
# Education must not be limited to our youth but must be a continuing process through our entire lives , for it is only through knowledge that we , as a nation , can cope with the dangers that threaten our society .
# The desire and ability to read are important aspects of our cultural life .
# We must not permit our society to become a slave to the scientific age , as might well happen without the cultural and spiritual restraint that comes from the development of the human mind through wisdom absorbed from the written word .
# The problem grows in intensity each year as man's knowledge , and his capacity to translate such knowledge to the written word , continue to expand .
# In every aspect of service -- to the public , to children in schools , to colleges and universities -- the library of today is failing to render vitally needed services .
# In every aspect of service -- to the public , to children in schools , to colleges and universities -- the library of today is failing to render vitally needed services .
# In every aspect of service -- to the public , to children in schools , to colleges and universities -- the library of today is failing to render vitally needed services .
#
# Tag: IN-TL
# On the clock given him was the inscription , `` For Outstanding Contribution to Billiken Basketball , 1960-61 '' .
# At a reception for new members of Congress , Oregon Democrat Maurine Neuberger , taking the Senate seat held by her husband Richard until his death last March , got a brotherly buss from Democratic Elder Statesman Adlai Stevenson , U.S. Ambassador-designate to the U.N. .

# %% [markdown]
# 35. Write a program to classify contexts involving the word must according to the
# tag of the following word. Can this be used to discriminate between the epistemic
# and deontic uses of must?

# %%
import nltk
from nltk.corpus import brown
from collections import defaultdict, Counter

# Ensure you have the Brown corpus
nltk.download('brown')

def classify_must_contexts(tagged_sents):
    """
    Classify contexts involving the word 'must' based on the tag of the following word.

    :param tagged_sents: List of tagged sentences
    :return: A Counter object with tags of the word following 'must'
    """
    following_tags = Counter()

    for sent in tagged_sents:
        # Iterate over each word and its tag in the sentence
        for i, (word, tag) in enumerate(sent):
            if word.lower() == 'must' and i + 1 < len(sent):
                next_word, next_tag = sent[i + 1]
                following_tags[next_tag] += 1

    return following_tags

def analyze_and_classify(tags_count):
    """
    Analyze the tags that follow 'must' and classify the contexts.
    
    :param tags_count: Counter object with tags of the word following 'must'
    :return: Classification of the contexts
    """
    # Common tags that might follow 'must'
    # You might need to adjust these based on empirical analysis or linguistic knowledge
    epistemic_tags = {'VB', 'VBP', 'VBZ'}  # Verb forms
    deontic_tags = {'NN', 'NNS', 'NNP'}    # Noun forms
    
    # Analyze and classify
    classification = {
        'Epistemic': 0,
        'Deontic': 0,
        'Unclassified': 0
    }
    
    for tag, count in tags_count.items():
        if tag in epistemic_tags:
            classification['Epistemic'] += count
        elif tag in deontic_tags:
            classification['Deontic'] += count
        else:
            classification['Unclassified'] += count
    
    return classification

# Load the Brown corpus tagged sentences
tagged_sents = brown.tagged_sents(categories='news')

# Classify contexts involving 'must'
tags_count = classify_must_contexts(tagged_sents)

# Analyze and classify the contexts
classification = analyze_and_classify(tags_count)

# Print the results
print("Tag Counts Following 'must':")
for tag, count in tags_count.items():
    print(f"{tag}: {count}")

print("\nClassification of Contexts:")
for context, count in classification.items():
    print(f"{context}: {count}")
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# Tag Counts Following 'must':
# BE: 17
# VB: 23
# VB-HL: 1
# HV: 5
# *: 3
# VB-TL: 1
# IN: 1
# '': 1
# RB: 1
#
# Classification of Contexts:
# Epistemic: 23
# Deontic: 0
# Unclassified: 30

# %% [markdown]
# 36. Create a regular expression tagger and various unigram and n-gram taggers,
# incorporating backoff, and train them on part of the Brown Corpus.
#
# a. Create three different combinations of the taggers. Test the accuracy of each
# combined tagger. Which combination works best?
#
# b. Try varying the size of the training corpus. How does it affect your results?

# %%
import nltk
from nltk.corpus import brown
from nltk.tag import UnigramTagger, BigramTagger, TrigramTagger, RegexpTagger, DefaultTagger
from nltk.tag import ClassifierBasedTagger
from nltk.classify import apply_features
from nltk.classify import NaiveBayesClassifier
from nltk.tag import hmm

# Ensure you have the Brown corpus
nltk.download('brown')

# Load the Brown Corpus and split into train and test sets
tagged_sents = brown.tagged_sents(categories='news')
train_sents = tagged_sents[:int(len(tagged_sents) * 0.8)]
test_sents = tagged_sents[int(len(tagged_sents) * 0.8):]

# Define different taggers
def create_taggers(train_sents):
    # Regular Expression Tagger
    regexp_tagger = RegexpTagger(
        [('.*ed$', 'VBD'), 
         ('.*es$', 'VBZ'), 
         ('.*ing$', 'VBG'), 
         ('.*s$', 'NNS'),
         ('.*\'s$', 'VBZ'),
         ('^.*$', 'NN')], 
        backoff=DefaultTagger('NN')
    )
    
    # Unigram Tagger
    unigram_tagger = UnigramTagger(train_sents, backoff=regexp_tagger)
    
    # Bigram Tagger
    bigram_tagger = BigramTagger(train_sents, backoff=unigram_tagger)
    
    # Trigram Tagger
    trigram_tagger = TrigramTagger(train_sents, backoff=bigram_tagger)
    
    return regexp_tagger, unigram_tagger, bigram_tagger, trigram_tagger

# Function to evaluate a tagger
def evaluate_tagger(tagger, test_sents):
    accuracy = tagger.evaluate(test_sents)
    return accuracy

# Train and evaluate different tagger combinations
def evaluate_combinations(train_sents, test_sents):
    # Create taggers
    regexp_tagger, unigram_tagger, bigram_tagger, trigram_tagger = create_taggers(train_sents)
    
    # Evaluate each tagger
    print("Evaluating individual taggers:")
    print(f"Regexp Tagger Accuracy: {evaluate_tagger(regexp_tagger, test_sents)}")
    print(f"Unigram Tagger Accuracy: {evaluate_tagger(unigram_tagger, test_sents)}")
    print(f"Bigram Tagger Accuracy: {evaluate_tagger(bigram_tagger, test_sents)}")
    print(f"Trigram Tagger Accuracy: {evaluate_tagger(trigram_tagger, test_sents)}")
    
    # Combined Taggers
    combined_tagger_1 = TrigramTagger(train_sents, backoff=bigram_tagger)
    combined_tagger_2 = BigramTagger(train_sents, backoff=unigram_tagger)
    combined_tagger_3 = UnigramTagger(train_sents, backoff=regexp_tagger)
    
    print("\nEvaluating combined taggers:")
    print(f"Combined Tagger 1 (Trigram with Bigram Backoff) Accuracy: {evaluate_tagger(combined_tagger_1, test_sents)}")
    print(f"Combined Tagger 2 (Bigram with Unigram Backoff) Accuracy: {evaluate_tagger(combined_tagger_2, test_sents)}")
    print(f"Combined Tagger 3 (Unigram with Regexp Backoff) Accuracy: {evaluate_tagger(combined_tagger_3, test_sents)}")

# Run evaluation
evaluate_combinations(train_sents, test_sents)

# Vary training corpus size
def evaluate_with_varying_sizes(tagged_sents):
    sizes = [0.1, 0.2, 0.4, 0.6, 0.8]
    
    for size in sizes:
        split_index = int(len(tagged_sents) * size)
        train_sents = tagged_sents[:split_index]
        test_sents = tagged_sents[split_index:]
        
        print(f"\nEvaluating with training size: {size * 100}%")
        evaluate_combinations(train_sents, test_sents)

# Run evaluation with varying training corpus sizes
evaluate_with_varying_sizes(tagged_sents)
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# Evaluating individual taggers:
# Regexp Tagger Accuracy: 0.1797774459270678
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9716\3540285435.py:43: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   accuracy = tagger.evaluate(test_sents)
# Unigram Tagger Accuracy: 0.8451274146153476
# Bigram Tagger Accuracy: 0.8544727588034106
# Trigram Tagger Accuracy: 0.8521123368177658
#
# Evaluating combined taggers:
# Combined Tagger 1 (Trigram with Bigram Backoff) Accuracy: 0.8521123368177658
# Combined Tagger 2 (Bigram with Unigram Backoff) Accuracy: 0.8544727588034106
# Combined Tagger 3 (Unigram with Regexp Backoff) Accuracy: 0.8451274146153476
#
# Evaluating with training size: 10.0%
# Evaluating individual taggers:
# Regexp Tagger Accuracy: 0.18318127638717152
# Unigram Tagger Accuracy: 0.7541578941505419
# Bigram Tagger Accuracy: 0.7576112020853524
# Trigram Tagger Accuracy: 0.7574552462431352
#
# Evaluating combined taggers:
# Combined Tagger 1 (Trigram with Bigram Backoff) Accuracy: 0.7574552462431352
# Combined Tagger 2 (Bigram with Unigram Backoff) Accuracy: 0.7576112020853524
# Combined Tagger 3 (Unigram with Regexp Backoff) Accuracy: 0.7541578941505419
#
# Evaluating with training size: 20.0%
# Evaluating individual taggers:
# Regexp Tagger Accuracy: 0.18221883739512584
# Unigram Tagger Accuracy: 0.7785657211346384
# Bigram Tagger Accuracy: 0.7828730523371954
# Trigram Tagger Accuracy: 0.782423591689972
#
# Evaluating combined taggers:
# Combined Tagger 1 (Trigram with Bigram Backoff) Accuracy: 0.782423591689972
# Combined Tagger 2 (Bigram with Unigram Backoff) Accuracy: 0.7828730523371954
# Combined Tagger 3 (Unigram with Regexp Backoff) Accuracy: 0.7785657211346384
#
# Evaluating with training size: 40.0%
# Evaluating individual taggers:
# Regexp Tagger Accuracy: 0.18571405070163027
# Unigram Tagger Accuracy: 0.8156184710546663
# Bigram Tagger Accuracy: 0.8212446740256962
# Trigram Tagger Accuracy: 0.8210472633951338
#
# Evaluating combined taggers:
# Combined Tagger 1 (Trigram with Bigram Backoff) Accuracy: 0.8210472633951338
# Combined Tagger 2 (Bigram with Unigram Backoff) Accuracy: 0.8212446740256962
# Combined Tagger 3 (Unigram with Regexp Backoff) Accuracy: 0.8156184710546663
#
# Evaluating with training size: 60.0%
# Evaluating individual taggers:
# Regexp Tagger Accuracy: 0.1814057288601138
# Unigram Tagger Accuracy: 0.8347557386698058
# Bigram Tagger Accuracy: 0.8420639591916814
# Trigram Tagger Accuracy: 0.8415734745928978
#
# Evaluating combined taggers:
# Combined Tagger 1 (Trigram with Bigram Backoff) Accuracy: 0.8415734745928978
# Combined Tagger 2 (Bigram with Unigram Backoff) Accuracy: 0.8420639591916814
# Combined Tagger 3 (Unigram with Regexp Backoff) Accuracy: 0.8347557386698058
#
# Evaluating with training size: 80.0%
# Evaluating individual taggers:
# Regexp Tagger Accuracy: 0.1797774459270678
# Unigram Tagger Accuracy: 0.8451274146153476
# Bigram Tagger Accuracy: 0.8544727588034106
# Trigram Tagger Accuracy: 0.8521123368177658
#
# Evaluating combined taggers:
# Combined Tagger 1 (Trigram with Bigram Backoff) Accuracy: 0.8521123368177658
# Combined Tagger 2 (Bigram with Unigram Backoff) Accuracy: 0.8544727588034106
# Combined Tagger 3 (Unigram with Regexp Backoff) Accuracy: 0.8451274146153476

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# 37. Our approach for tagging an unknown word has been to consider the letters of
# the word (using RegexpTagger()), or to ignore the word altogether and tag it as a
# noun (using nltk.DefaultTagger()). These methods will not do well for texts having new words that are not nouns. Consider the sentence I like to blog on Kim’s
# blog. If blog is a new word, then looking at the previous tag (TO versus NP$) would
# probably be helpful, i.e., we need a default tagger that is sensitive to the preceding
# tag.
#
# a. Create a new kind of unigram tagger that looks at the tag of the previous word,
# and ignores the current word. (The best way to do this is to modify the source
# code for UnigramTagger(), which presumes knowledge of object-oriented programming in Python.)
#
# b. Add this tagger to the sequence of backoff taggers (including ordinary trigram
# and bigram taggers that look at words), right before the usual default tagger.
#
# c. Evaluate the contribution of this new unigram tagger

# %%
import nltk
from nltk.tag import UnigramTagger, DefaultTagger, BigramTagger, TrigramTagger, RegexpTagger
from nltk.corpus import brown

# Custom PreviousTagUnigramTagger class
class PreviousTagUnigramTagger:
    def __init__(self, train_sents, backoff=None):
        self.backoff = backoff
        self.tagdict = self._train(train_sents)

    def _train(self, train_sents):
        tagdict = {}
        for sent in train_sents:
            prev_tag = 'START'
            for word, tag in sent:
                if (prev_tag, word) not in tagdict:
                    tagdict[(prev_tag, word)] = tag
                prev_tag = tag
        return tagdict

    def tag(self, sentence):
        tagged = []
        prev_tag = 'START'
        for word in sentence:
            tag = self.tagdict.get((prev_tag, word), 'NN')  # Default to 'NN' if not in tagdict
            tagged.append((word, tag))
            prev_tag = tag
        if self.backoff:
            tagged = self.backoff.tag([word for word, _ in tagged])
        return tagged

    def evaluate(self, test_sents):
        correct = 0
        total = 0
        for sent in test_sents:
            ref_tags = [tag for _, tag in sent]
            tagged = self.tag([word for word, _ in sent])
            tagged_tags = [tag for _, tag in tagged]
            correct += sum([1 for ref, tag in zip(ref_tags, tagged_tags) if ref == tag])
            total += len(sent)
        return correct / total

# Load the Brown Corpus and split into train and test sets
tagged_sents = brown.tagged_sents(categories='news')
train_sents = tagged_sents[:int(len(tagged_sents) * 0.8)]
test_sents = tagged_sents[int(len(tagged_sents) * 0.8):]

# Create other taggers
regexp_tagger = RegexpTagger(
    [(r'.*ed$', 'VBD'), 
     (r'.*es$', 'VBZ'), 
     (r'.*ing$', 'VBG'), 
     (r'.*s$', 'NNS')], 
    backoff=DefaultTagger('NN')
)

unigram_tagger = UnigramTagger(train_sents, backoff=regexp_tagger)
bigram_tagger = BigramTagger(train_sents, backoff=unigram_tagger)
trigram_tagger = TrigramTagger(train_sents, backoff=bigram_tagger)

# Create the custom PreviousTagUnigramTagger and combine it with other taggers
prev_tag_tagger = PreviousTagUnigramTagger(train_sents, backoff=trigram_tagger)

# Evaluate the taggers
def evaluate_tagger(tagger, test_sents):
    accuracy = tagger.evaluate(test_sents)
    return accuracy

# Evaluate with the combined tagger including PreviousTagUnigramTagger
print("Evaluating combined taggers with PreviousTagUnigramTagger included:")
print(f"Accuracy: {evaluate_tagger(prev_tag_tagger, test_sents)}")

# Evaluate with just the existing taggers (without PreviousTagUnigramTagger)
basic_tagger = TrigramTagger(train_sents, backoff=bigram_tagger)
print("\nEvaluating with existing taggers (without PreviousTagUnigramTagger):")
print(f"Accuracy: {evaluate_tagger(basic_tagger, test_sents)}")
# Out:
# Evaluating combined taggers with PreviousTagUnigramTagger included:
# Accuracy: 0.8521123368177658
#
# Evaluating with existing taggers (without PreviousTagUnigramTagger):
# Accuracy: 0.8521123368177658
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9716\3233445279.py:66: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   accuracy = tagger.evaluate(test_sents)

# %% [markdown]
# 39. Use some of the estimation techniques in nltk.probability, such as Lidstone or
# Laplace estimation, to develop a statistical tagger that does a better job than ngram backoff taggers in cases where contexts encountered during testing were not
# seen during training.

# %%
import nltk
from nltk.corpus import treebank
from nltk.tag import UnigramTagger, BigramTagger, TrigramTagger, RegexpTagger
from nltk.tag import brill, brill_trainer
from nltk.probability import LidstoneProbDist, LaplaceProbDist, ConditionalFreqDist, ConditionalProbDist

# Load treebank data
train_sents = treebank.tagged_sents()[:3000]  # Adjust as needed
test_sents = treebank.tagged_sents()[3000:]   # Adjust as needed

# Create frequency distributions
def create_conditional_prob_dist(tagged_sents, estimator):
    cfd = ConditionalFreqDist(
        (tag, word) for sent in tagged_sents for word, tag in sent
    )
    cpfd = ConditionalProbDist(
        cfd, estimator, bins=1000
    )
    return cpfd

# Define smoothing methods
def lidstone_estimator():
    return LidstoneProbDist(create_conditional_prob_dist(train_sents, LidstoneProbDist), 0.2)

def laplace_estimator():
    return LaplaceProbDist(create_conditional_prob_dist(train_sents, LaplaceProbDist))

# Define and train taggers with smoothing
def train_lidstone_taggers():
    unigram_tagger = UnigramTagger(train_sents)
    bigram_tagger = BigramTagger(train_sents, backoff=unigram_tagger)
    trigram_tagger = TrigramTagger(train_sents, backoff=bigram_tagger)
    return unigram_tagger, bigram_tagger, trigram_tagger

def train_laplace_taggers():
    unigram_tagger = UnigramTagger(train_sents)
    bigram_tagger = BigramTagger(train_sents, backoff=unigram_tagger)
    trigram_tagger = TrigramTagger(train_sents, backoff=bigram_tagger)
    return unigram_tagger, bigram_tagger, trigram_tagger

# Train taggers with Lidstone and Laplace estimators
lidstone_taggers = train_lidstone_taggers()
laplace_taggers = train_laplace_taggers()

# Evaluate individual taggers
def evaluate_taggers(tagger_list):
    accuracies = {}
    for tagger_name, tagger in tagger_list.items():
        accuracy = tagger.evaluate(test_sents)
        accuracies[tagger_name] = accuracy
    return accuracies

# Evaluate Lidstone and Laplace taggers
lidstone_accuracies = evaluate_taggers({
    "Lidstone Unigram": lidstone_taggers[0],
    "Lidstone Bigram": lidstone_taggers[1],
    "Lidstone Trigram": lidstone_taggers[2]
})

laplace_accuracies = evaluate_taggers({
    "Laplace Unigram": laplace_taggers[0],
    "Laplace Bigram": laplace_taggers[1],
    "Laplace Trigram": laplace_taggers[2]
})

# Print accuracies
print("Lidstone Tagger Accuracies:")
for name, accuracy in lidstone_accuracies.items():
    print(f"{name} Accuracy: {accuracy:.4f}")

print("\nLaplace Tagger Accuracies:")
for name, accuracy in laplace_accuracies.items():
    print(f"{name} Accuracy: {accuracy:.4f}")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9716\4137505005.py:49: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   accuracy = tagger.evaluate(test_sents)
# Lidstone Tagger Accuracies:
# Lidstone Unigram Accuracy: 0.8572
# Lidstone Bigram Accuracy: 0.8648
# Lidstone Trigram Accuracy: 0.8647
#
# Laplace Tagger Accuracies:
# Laplace Unigram Accuracy: 0.8572
# Laplace Bigram Accuracy: 0.8648
# Laplace Trigram Accuracy: 0.8647
